# %% [markdown]
# - -> exp046
# - control

# %%
# %load_ext autotime
# %load_ext autoreload

# %%
import os

is_kaggle_notebook = os.path.exists("/kaggle/input")

# 必要パッケージをインストール
if is_kaggle_notebook:
    # !pip install /kaggle/input/rdkit-2025-3-3-cp311/rdkit-2025.3.3-cp311-cp311-manylinux_2_28_x86_64.whl
    # !pip install /kaggle/input/torch-geometric-2-6-1/torch_geometric-2.6.1-py3-none-any.whl

# %%
import copy
import json
import os
import sys
import warnings
from pathlib import Path

import wandb

import lightgbm as lgb
import numpy as np
import pandas as pd
import torch
from rdkit import rdBase
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GroupKFold, KFold, ShuffleSplit
from tqdm.auto import tqdm

from sklearn.decomposition import TruncatedSVD
from scipy import sparse

rdBase.DisableLog("rdApp.warning")
warnings.filterwarnings("ignore")

wandb.login()
# Out:
# wandb: Currently logged in as: ko_ya346 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
pr_number = 1
exp = "exp048"
debug = False
ignore_3D = False
ignore_3d_stats = True
select_feature = True
data_exp = "exp048"
notes = "lgb control"

# %%
# %autoreload 2

if is_kaggle_notebook:
    module_path = f"/kaggle/input/myproject-pr-{pr_number:04}"
    # !mkdir src
    # !cp -r $module_path/* src/
    src_path = "./"
else:
    src_path = "../"

sys.path.append(src_path)

from src.data import load_data, add_descriptors, add_descriptors_mordred, add_external_data, make_smile_canonical, add_maccs, add_augumented_gmm, add_graph_features, add_count_atoms
from src.model import train_lgb_for_target, save_lgb_model
from src.utils import NULL_FOR_SUBMISSION, generate_scaffold, score, add_scaffold_kfold, scaffold_cv_split, get_useless_cols
from src.utils.upload_kaggle_dataset import (
    create_kaggle_dataset_metadata,
    upload_kaggle_dataset,
)

# %%
model_name = "lgb"

config = {
    "debug": debug,
    "n_splits": 3,
    "num_epochs": 1000,
    "batch_size": 128,
    "drop_ratio": 0.5,
    "force_update_train": True,
    "augumented_gmm": False,
    "is_complement": True,
    "remove_external_cv": True,
}

dataset_title = f"model-{exp}"
dataset_id = f"koya346/{dataset_title}"

if is_kaggle_notebook:
    config["debug"] = False

if config["debug"]:
    config["n_splits"] = 2
    config["num_epochs"] = 10

targets = ["Tg", "FFV", "Tc", "Density", "Rg"]
org_target_cols = [f"org_{target}" for target in targets]        

# TODO: 学習パラメータ定義
params = {
    "objective": "regression",
    "metric": "mae",
    "verbosity": -1,
    "learning_rate": 0.01,
    "max_depth": 7,
    "seed": 42,
    "subsample": 0.7,
    "colsample_bytree": 0.6,
    "num_boost_round": 20000,
}

config.update(params)
pre_params = copy.deepcopy(params)
pre_params["num_boost_round"] = 300

# %%
wandb_name = f"{exp}_{model_name}" if not config["debug"] else f"{exp}_{model_name}_debug"
wandb.init(project="opp2025", name=wandb_name, config=config)
wandb.log({"Notes": notes})

# ---------------------------
# メイン処理
# ---------------------------
if config["debug"]:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp / "debug"
else:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp

model_output_path = output_path / "model_cv"
if not os.path.exists(model_output_path):
    os.makedirs(model_output_path)

if is_kaggle_notebook:
    # kaggle notebook
    data_dir = Path("/kaggle/input")
else:
    # local
    data_dir = Path("/home/kouya-takahashi/kaggle/opp2025/data/raw")

# 学習データ用意
train_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / data_exp

if os.path.exists(train_path / "train.csv") and not config["force_update_train"]:
    train = pd.read_csv(train_path / "train.csv")
else:
    train, _ = load_data(data_dir)
    # 外部データ判定用に元の目的変数を保持しておく
    # 外部データ判定は scaffold_cv_split 内で行う
    for target in targets:
        train[f"org_{target}"] = train[target]
    

    train["org_SMILES"] = train["SMILES"]
    train["SMILES"] = train["SMILES"].apply(make_smile_canonical)
    if config["debug"]:
        # 各ターゲットが欠損していないデータを30 件ずつ取り出す
        tmp_dfs = []
        for target in targets:
            cond = train[target].notnull()
            tmp_dfs.append(train[cond].iloc[:30])
        train = pd.concat(tmp_dfs).reset_index(drop=True)
    else:
        print(train.shape)
        external_data_dict = [
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset3.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset1.csv",
                "col": "Tc",
                "rename_d": {"TC_mean": "Tc"},
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset4.csv",
                "col": "FFV",
            },
            {
                "ex_path": data_dir / "tg-smiles-pid-polymer-class/TgSS_enriched_cleaned.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_dnst1.xlsx",
                "col": "Density",
                "rename_d": {"density(g/cm3)": "Density"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_tg3.xlsx",
                "col": "Tg",
                "rename_d": {"Tg [K]": "Tg"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/JCIM_sup_bigsmiles.csv",
                "col": "Tg",
                "rename_d": {"Tg (C)": "Tg"}, 
            },
        ]
        for d in external_data_dict:
            print(f"ex_path: {str(d['ex_path'])}")
            train = add_external_data(
                df=train,
                ex_path=d.get("ex_path"),
                col=d.get("col"),
                rename_d=d.get("rename_d"),
                is_complement=config["is_complement"]
            )
            print("after train.shape: ", train.shape)

    train["is_external"] = train["id"].isnull()
    train = add_maccs(train)

    # rdkit の記述子, morgan finger print
    train = add_descriptors(train, radius=2, fp_size=1024)
    train = add_descriptors_mordred(train, num_confs=10, ignore_3D=ignore_3D, ignore_3d_stats=ignore_3d_stats)

    new_cols = []
    seen = {}
    for col in train.columns:
        if col in seen:
            seen[col] += 1
            new_cols.append(f"{col}_{seen[col]}")
        else:
            seen[col] = 0
            new_cols.append(col)
    
    train.columns = new_cols
    
    # グラフ特徴量
    train = add_graph_features(train)
    train = add_count_atoms(train)
    
    train["id"] = np.arange(len(train))
    features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns
    for col in features:
        if train[col].dtype == "object":
            train[col] = pd.to_numeric(train[col], errors="coerce")
    useless_cols = get_useless_cols(train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1))
    
    train = train.drop(useless_cols, axis=1)
    
    os.makedirs(output_path, exist_ok=True)
    train.to_csv(output_path / "train.csv", index=False)
    print("Saved train.csv")

# 不要なビット列を除去
bit_cols = []
remove_cols = []

for col in train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns:
    if len(train[col].unique()) != 2:
        continue
    if np.all(train[col].unique() == np.array([0, 1])):
        bit_cols.append(col)
        p = train[col].mean()
        if p > 0.01 and p < 0.99:
            continue
        remove_cols.append(col)
print("bit cols: ", len(bit_cols))
print("remove cols: ", len(remove_cols))

train = train.drop(remove_cols, axis=1)

# 計算済の fold を突合
folds = pd.read_csv("/home/kouya-takahashi/kaggle/opp2025/data/preprocess/fold/folds.csv")
train = train.merge(folds[["SMILES", "fold"]], how="left", on="SMILES")

features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "fold", "is_external"], axis=1).columns
print(len(features))
oof_dfs = []

loss_table_wandb = wandb.Table(["exp", "model_name", "fold", "target", "mae", "mse"])
all_loss_tables = []
mae_dict = {}
all_models = {}

for idx, target_col in enumerate(targets):
    loss_tables = []
    print(f"\n=== Training for target: {target_col} ===")

    df_train = train[train[target_col].notnull()].reset_index(drop=True)
    X = df_train[features]
    y = df_train[target_col]
    oof = np.full(len(X), np.nan, dtype=float)
    
    models = []

    for fold, tr_idx, val_idx in scaffold_cv_split(df_train, target=target_col, n_splits=config["n_splits"], remove_external=config["remove_external_cv"]):
        if len(tr_idx) == 0 or len(val_idx) == 0:
            print(f"Skip fold... tr_idx: {len(tr_idx)}, val_idx: {len(val_idx)}")
            continue
        loss_table = {}
        print(f"fold: {fold + 1}")

        if select_feature:
            hits = np.zeros(X.shape[1], dtype=int)
    
            rs = ShuffleSplit(n_splits=3, train_size=0.9, random_state=42)
            for idx, (tr_in, va_in) in enumerate(rs.split(tr_idx)):
                X_tr_in, X_va_in = X.iloc[tr_in][features], X.iloc[va_in][features]
                y_tr_in, y_va_in = y.iloc[tr_in], y.iloc[va_in]
                dtrain_in = lgb.Dataset(X_tr_in, label=y_tr_in)
                dvalid_in = lgb.Dataset(X_va_in, label=y_va_in)
                model = lgb.train(
                    params,
                    dtrain_in,
                    valid_sets=[dtrain_in, dvalid_in],
                    callbacks=[
                        lgb.early_stopping(stopping_rounds=50),
                        lgb.log_evaluation(200)
                    ]
                )
                rank = model.feature_importance("gain").argsort()[::-1]
                topk = set(rank[:int(0.3 * len(rank))])
                hits[list(topk)] += 1
            keep = hits >= 2
            use_features = features[keep]
        else:
            use_features = features
        print(len(use_features))        

        # 特徴量選択して valid データとともに学習
        X_train, X_val = X.iloc[tr_idx][use_features], X.iloc[val_idx][use_features]
        y_train, y_val = y.iloc[tr_idx], y.iloc[val_idx]

        if config["augumented_gmm"]:
            X_train, y_train = add_augumented_gmm(X_train, y_train)    
        
        dtrain = lgb.Dataset(X_train, label=y_train)
        dval = lgb.Dataset(X_val, label=y_val, reference=dtrain)

        model = lgb.train(
            params,
            dtrain,
            valid_sets=[dtrain, dval],
            callbacks=[
                lgb.early_stopping(stopping_rounds=50),
                lgb.log_evaluation(200)
            ]
        )

        save_lgb_model(model, str(model_output_path / f"model_{target_col}_{fold}.txt"))

        pred = model.predict(X_val, num_iteration=model.best_iteration)
        oof[val_idx] = pred

        mse = mean_squared_error(y_val, pred)
        mae = mean_absolute_error(y_val, pred)
        print(f"fold: {fold}, target: {target_col}, mae: {mae}")
        loss_table["fold"] = fold
        loss_table["target"] = target_col
        loss_table["mae"] = mae
        loss_table["mse"] = mse

        loss_tables.append(loss_table)
        models.append(model)

    # 評価に使うのは元データのみ
    cond = (~np.isnan(oof)) & (df_train[f"org_{target_col}"].notnull())
    y_true = y[cond]
    y_pred = oof[cond]
    score_mse = mean_squared_error(y_true, y_pred)
    score_mae = mean_absolute_error(y_true, y_pred)
    print(f"RMSE for {target_col}: {score_mse:.4f}")
    print(f"MAE for {target_col}: {score_mae:.4f}")
    mae_dict[target_col] = score_mae

    for loss_table in loss_tables:
        loss_table_wandb.add_data(exp, model_name, loss_table["fold"], loss_table["target"], loss_table["mae"], loss_table["mse"])
    all_loss_tables += loss_tables

    oof_df = pd.DataFrame({
        "id": df_train["id"].values,
        target_col: oof
    })
    oof_dfs.append(oof_df)   

    all_models[target_col] = models

wandb.log({"fold_target_losses": loss_table_wandb})
# target 毎の 平均 mae を記録
for target in targets:
    key_name = f"{target}_mean_mae"
    mae_values = mae_dict[target]
    # mae_values = [d["mae"] for d in all_loss_tables if d["target"] == target]
    wandb.log({key_name: np.mean(mae_values)})

# CV 計算
cond = ~train["is_external"]
oof_df = pd.DataFrame()

# 元の目的変数も入れておく
for target in targets:
    oof_df[f"org_{target}"] = train.loc[cond, f"org_{target}"]

oof_df["id"] = train.loc[cond, "id"]

# 正規化前の SMILES
oof_df["SMILES"] = train.loc[cond, "org_SMILES"]

for i_oof in oof_dfs:
    oof_df = oof_df.merge(i_oof, on="id", how="left")

# # 予測しなかった部分は null にしておく
# for target in targets:
#     oof_df.loc[oof_df[target] == 0, target] = np.nan

oof_df.to_csv(output_path / "oof.csv", index=False)

solution = train.loc[cond, ["id"] + org_target_cols].copy()
solution.columns = ["id"] + targets

# solution = solution.fillna(NULL_FOR_SUBMISSION)

# oof_df = oof_df.fillna(NULL_FOR_SUBMISSION)

# 評価
final_score = score(
    solution=solution,
    submission=oof_df,
)
print(f"\n📊 Final OOF Score (wMAE): {final_score:.6f}")
wandb.log({"wMAE": final_score})

# target 毎の best_iteration を保存する。保存したモデルには記録されてなかった
best_iterations = {}
for target in targets:
    target_best_iterations = [model.best_iteration for model in all_models[target]]
    best_iterations[target] = target_best_iterations
print(best_iterations)

with open(output_path / "best_iterations.json", "w") as f:
    json.dump(best_iterations, f)
# Out:
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/kouya-takahashi/kaggle/opp2025/notebook/wandb/run-20250826_230357-ripdzf7t</code>
# Syncing run <strong><a href='https://wandb.ai/ko_ya346/opp2025/runs/ripdzf7t' target="_blank">exp048_lgb</a></strong> to <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">https://wandb.ai/ko_ya346/opp2025</a>
#  View run at <a href='https://wandb.ai/ko_ya346/opp2025/runs/ripdzf7t' target="_blank">https://wandb.ai/ko_ya346/opp2025/runs/ripdzf7t</a>
# (7973, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/neurips-open-polymer-prediction-2025/train_supplement/dataset3.csv
# after train.shape:  (8019, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/neurips-open-polymer-prediction-2025/train_supplement/dataset1.csv
# after train.shape:  (8148, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/neurips-open-polymer-prediction-2025/train_supplement/dataset4.csv
# after train.shape:  (8972, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/tg-smiles-pid-polymer-class/TgSS_enriched_cleaned.csv
# after train.shape:  (10343, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/smiles-extra-data/data_dnst1.xlsx
# after train.shape:  (10819, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/smiles-extra-data/data_tg3.xlsx
# after train.shape:  (11314, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/smiles-extra-data/JCIM_sup_bigsmiles.csv
# after train.shape:  (11326, 13)
# Generating maccs:   0%|          | 0/11326 [00:00<?, ?it/s]
# Generating descriptors:   0%|          | 0/11326 [00:00<?, ?it/s]
# Unique=1 col: ['maccs_0', 'maccs_1', 'maccs_2', 'maccs_4', 'maccs_5', 'maccs_6', 'maccs_7', 'maccs_9', 'SMR_VSA8', 'SlogP_VSA9', 'fr_isothiocyan', 'fr_prisulfonamd']
# Highly correlated cols:  ['maccs_40', 'maccs_55', 'maccs_56', 'maccs_58', 'maccs_60', 'maccs_61', 'maccs_63', 'maccs_64', 'maccs_71', 'maccs_105', 'maccs_117', 'maccs_134', 'maccs_135', 'maccs_143', 'maccs_147', 'MaxAbsEStateIndex', 'HeavyAtomMolWt', 'ExactMolWt', 'NumValenceElectrons', 'FpDensityMorgan2', 'FpDensityMorgan3', 'Chi0', 'Chi0n', 'Chi0v', 'Chi1', 'Chi1n', 'Chi1v', 'Chi2n', 'Chi2v', 'Chi3n', 'Chi3v', 'Chi4n', 'Chi4v', 'HallKierAlpha', 'Kappa1', 'LabuteASA', 'SlogP_VSA6', 'VSA_EState6', 'HeavyAtomCount', 'NOCount', 'NumAromaticCarbocycles', 'NumAromaticRings', 'NumHDonors', 'MolMR', 'fr_Al_OH_noTert', 'fr_COO2', 'fr_C_O_noCOO', 'fr_Nhpyrrole', 'fr_benzene', 'fr_diazo', 'fr_halogen', 'fr_nitrile', 'fr_nitro', 'fr_nitro_arom', 'fr_phenol', 'fr_phenol_noOrthoHbond', 'fr_phos_ester', 'mfp_vec33', 'mfp_vec80', 'mfp_vec226', 'mfp_vec294', 'mfp_vec356', 'mfp_vec695', 'mfp_vec849', 'mfp_vec935', 'mfp_vec939', 'avg_shortest_path', 'num_cycle', 'num_c', 'num_F', 'num_positive_ions', 'num_negative_ions']
# Saved train.csv
# bit cols:  1117
# remove cols:  479
# 837
#
# === Training for target: Tg ===
# train rows: 5476, valid rows: 191, ignore rows: 2577
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1:
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0294381	valid_1's l1: 0.0348266
# [400]	training's l1: 0.0232895	valid_1's l1: 0.0330506
# [600]	training's l1: 0.0201419	valid_1's l1: 0.0323968
# [800]	training's l1: 0.0179123	valid_1's l1: 0.0320067
# Early stopping, best iteration is:
# [924]	training's l1: 0.0168897	valid_1's l1: 0.0316719
# fold: 0, target: Tc, mae: 0.03167194801570588
# train rows: 640, valid rows: 187, ignore rows: 39
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.023069	valid_1's l1: 0.0305759
# [400]	training's l1: 0.0164984	valid_1's l1: 0.0254706
# Early stopping, best iteration is:
# [456]	training's l1: 0.0157843	valid_1's l1: 0.0252357
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0231103	valid_1's l1: 0.0269724
# [400]	training's l1: 0.016625	valid_1's l1: 0.0253879
# Early stopping, best iteration is:
# [352]	training's l1: 0.017369	valid_1's l1: 0.0253039
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0225369	valid_1's l1: 0.034073
# [400]	training's l1: 0.0158744	valid_1's l1: 0.0297655
# [600]	training's l1: 0.0142148	valid_1's l1: 0.0289637
# Early stopping, best iteration is:
# [740]	training's l1: 0.0133739	valid_1's l1: 0.0287987
# 246
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0259603	valid_1's l1: 0.0371077
# [400]	training's l1: 0.0200549	valid_1's l1: 0.0319097
# [600]	training's l1: 0.0180996	valid_1's l1: 0.0308959
# [800]	training's l1: 0.0167769	valid_1's l1: 0.0306761
# Early stopping, best iteration is:
# [791]	training's l1: 0.0168309	valid_1's l1: 0.0306596
# fold: 1, target: Tc, mae: 0.03065960134129868
# train rows: 700, valid rows: 114, ignore rows: 52
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0226025	valid_1's l1: 0.0261049
# [400]	training's l1: 0.0162474	valid_1's l1: 0.0244376
# [600]	training's l1: 0.0144258	valid_1's l1: 0.0241218
# [800]	training's l1: 0.0133145	valid_1's l1: 0.0238175
# [1000]	training's l1: 0.0124054	valid_1's l1: 0.023719
# Early stopping, best iteration is:
# [954]	training's l1: 0.012578	valid_1's l1: 0.023693
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0223072	valid_1's l1: 0.0266676
# Early stopping, best iteration is:
# [221]	training's l1: 0.0209794	valid_1's l1: 0.0265032
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0224427	valid_1's l1: 0.0301616
# Early stopping, best iteration is:
# [285]	training's l1: 0.0184759	valid_1's l1: 0.0294643
# 240
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0224896	valid_1's l1: 0.0491015
# [400]	training's l1: 0.0162012	valid_1's l1: 0.0450742
# [600]	training's l1: 0.0143089	valid_1's l1: 0.0448398
# Early stopping, best iteration is:
# [622]	training's l1: 0.014128	valid_1's l1: 0.0447903
# fold: 2, target: Tc, mae: 0.04479034318721376
# RMSE for Tc: 0.0022
# MAE for Tc: 0.0334
#
# === Training for target: Density ===
# train rows: 639, valid rows: 340, ignore rows: 267
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0330301	valid_1's l1: 0.0290125
# [400]	training's l1: 0.0213452	valid_1's l1: 0.0258467
# Early stopping, best iteration is:
# [448]	training's l1: 0.0204601	valid_1's l1: 0.0257012
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0323418	valid_1's l1: 0.0372563
# [400]	training's l1: 0.0208012	valid_1's l1: 0.0325449
# Early stopping, best iteration is:
# [359]	training's l1: 0.021786	valid_1's l1: 0.0324039
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1:
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0343399	valid_1's l1: 0.0522136
# [400]	training's l1: 0.0216487	valid_1's l1: 0.0437262
# [600]	training's l1: 0.0187981	valid_1's l1: 0.0426894
# [800]	training's l1: 0.0168894	valid_1's l1: 0.0416952
# [1000]	training's l1: 0.0154436	valid_1's l1: 0.0410003
# [1200]	training's l1: 0.0142604	valid_1's l1: 0.0404929
# [1400]	training's l1: 0.0131771	valid_1's l1: 0.0398237
# [1600]	training's l1: 0.0121254	valid_1's l1: 0.0394806
# [1800]	training's l1: 0.0112499	valid_1's l1: 0.0392495
# [2000]	training's l1: 0.0104165	valid_1's l1: 0.0390695
# [2200]	training's l1: 0.00971607	valid_1's l1: 0.0389104
# Early stopping, best iteration is:
# [2256]	training's l1: 0.00951615	valid_1's l1: 0.0388784
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0347414	valid_1's l1: 0.0531853
# [400]	training's l1: 0.0227713	valid_1's l1: 0.0379683
# [600]	training's l1: 0.0199108	valid_1's l1: 0.0342464
# [800]	training's l1: 0.0180655	valid_1's l1: 0.0325967
# [1000]	training's l1: 0.016449	valid_1's l1: 0.0317373
# [1200]	training's l1: 0.0150844	valid_1's l1: 0.0314051
# [1400]	training's l1: 0.0138979	valid_1's l1: 0.031159
# Early stopping, best iteration is:
# [1511]	training's l1: 0.0132876	valid_1's l1: 0.0310108
# 256
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0401137	valid_1's l1: 0.0612013
# [400]	training's l1: 0.0228216	valid_1's l1: 0.0578689
# [600]	training's l1: 0.019579	valid_1's l1: 0.0562079
# Early stopping, best iteration is:
# [642]	training's l1: 0.0190463	valid_1's l1: 0.0560557
# fold: 2, target: Density, mae: 0.056055691504520576
# RMSE for Density: 0.0098
# MAE for Density: 0.0565
#
# === Training for target: Rg ===
# train rows: 272, valid rows: 342, ignore rows: 0
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.50622	valid_1's l1: 1.792
# Early stopping, best iteration is:
# [283]	training's l1: 1.26729	valid_1's l1: 1.72267
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.51775	valid_1's l1: 1.61413
# Early stopping, best iteration is:
# [304]	training's l1: 1.22607	valid_1's l1: 1.52379
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.45327	valid_1's l1: 2.05659
# Early stopping, best iteration is:
# [202]	training's l1: 1.44634	valid_1's l1: 2.0547
# 253
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.46848	valid_1's l1: 2.33133
# [400]	training's l1: 1.02898	valid_1's l1: 2.0155
# [600]	training's l1: 0.813084	valid_1's l1: 1.97018
# Early stopping, best iteration is:
# [638]	training's l1: 0.780944	valid_1's l1: 1.96805
# fold: 0, target: Rg, mae: 1.9680529690151216
# train rows: 459, valid rows: 155, ignore rows: 0
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.34693	valid_1's l1: 2.1603
# Early stopping, best iteration is:
# [314]	training's l1: 1.05926	valid_1's l1: 2.03891
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.38848	valid_1's l1: 1.62794
# [400]	training's l1: 1.02011	valid_1's l1: 1.45505
# Early stopping, best iteration is:
# [369]	training's l1: 1.05262	valid_1's l1: 1.45007
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.40304	valid_1's l1: 1.61031
# [400]	training's l1: 1.01978	valid_1's l1: 1.51822
# [600]	training's l1: 0.870138	valid_1's l1: 1.49052
# Early stopping, best iteration is:
# [561]	training's l1: 0.893333	valid_1's l1: 1.48565
# 259
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.41237	valid_1's l1: 1.96701
# [400]	training's l1: 1.0261	valid_1's l1: 1.77382
# Early stopping, best iteration is:
# [541]	training's l1: 0.932026	valid_1's l1: 1.75723
# fold: 1, target: Rg, mae: 1.7572256660845398
# train rows: 497, valid rows: 117, ignore rows: 0
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.3648	valid_1's l1: 1.99092
# [400]	training's l1: 1.00198	valid_1's l1: 1.85813
# [600]	training's l1: 0.843937	valid_1's l1: 1.81834
# Early stopping, best iteration is:
# [662]	training's l1: 0.805514	valid_1's l1: 1.81168
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.36684	valid_1's l1: 2.16277
# [400]	training's l1: 1.02842	valid_1's l1: 1.91591
# [600]	training's l1: 0.879534	valid_1's l1: 1.86956
# [800]	training's l1: 0.775289	valid_1's l1: 1.82978
# [1000]	training's l1: 0.689348	valid_1's l1: 1.79508
# [1200]	training's l1: 0.624609	valid_1's l1: 1.76998
# [1400]	training's l1: 0.568236	valid_1's l1: 1.75638
# [1600]	training's l1: 0.518336	valid_1's l1: 1.74718
# [1800]	training's l1: 0.471145	valid_1's l1: 1.73699
# [2000]	training's l1: 0.433041	valid_1's l1: 1.7282
# [2200]	training's l1: 0.399697	valid_1's l1: 1.7202
# [2400]	training's l1: 0.367731	valid_1's l1: 1.71077
# Early stopping, best iteration is:
# [2426]	training's l1: 0.36469	valid_1's l1: 1.71009
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.35847	valid_1's l1: 1.95772
# [400]	training's l1: 0.996875	valid_1's l1: 1.83503
# Early stopping, best iteration is:
# [542]	training's l1: 0.882759	valid_1's l1: 1.80934
# 256
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.27512	valid_1's l1: 2.75647
# [400]	training's l1: 0.930945	valid_1's l1: 2.54176
# [600]	training's l1: 0.821665	valid_1's l1: 2.51905
# [800]	training's l1: 0.725079	valid_1's l1: 2.49459
# Early stopping, best iteration is:
# [886]	training's l1: 0.692998	valid_1's l1: 2.48679
# fold: 2, target: Rg, mae: 2.4867874935805214
# RMSE for Rg: 8.3910
# MAE for Rg: 2.0137
#
# 📊 Final OOF Score (wMAE): 0.060280
# {'Tg': [936, 913, 955], 'FFV': [761, 6204, 4398], 'Tc': [924, 791, 622], 'Density': [491, 463, 642], 'Rg': [638, 541, 886]}

# %%
w = {'Tg': [936, 913, 955], 'FFV': [761, 6204, 4398], 'Tc': [924, 791, 622], 'Density': [491, 463, 642], 'Rg': [638, 541, 886]}
exp = [1, 2, 3]

weight_d = {}
for target in ["Tg", "Tc", "Rg", "FFV", "Density"]:
    weights = w[target]
    d = {}
    for idx, e in enumerate(exp):
        d[e] = weights[idx]
    weight_d[target] = d
print(weight_d)
# Out:
# {'Tg': {1: 936, 2: 913, 3: 955}, 'Tc': {1: 924, 2: 791, 3: 622}, 'Rg': {1: 638, 2: 541, 3: 886}, 'FFV': {1: 761, 2: 6204, 3: 4398}, 'Density': {1: 491, 2: 463, 3: 642}}
