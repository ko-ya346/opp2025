# %% [markdown]
# - -> exp048
# - 特徴量の名称が一意になるように修正

# %%
# %load_ext autotime
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os

is_kaggle_notebook = os.path.exists("/kaggle/input")

# 必要パッケージをインストール
if is_kaggle_notebook:
    # !pip install /kaggle/input/rdkit-2025-3-3-cp311/rdkit-2025.3.3-cp311-cp311-manylinux_2_28_x86_64.whl
    # !pip install /kaggle/input/torch-geometric-2-6-1/torch_geometric-2.6.1-py3-none-any.whl

# %%
import copy
import json
import os
import sys
import warnings
from pathlib import Path

import wandb

import lightgbm as lgb
import numpy as np
import pandas as pd
import torch
from rdkit import rdBase
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GroupKFold, KFold, ShuffleSplit
from tqdm.auto import tqdm

from sklearn.decomposition import TruncatedSVD
from scipy import sparse

rdBase.DisableLog("rdApp.warning")
warnings.filterwarnings("ignore")

wandb.login()
# Out:
# True

# %%
pr_number = 1
exp = "exp051"
debug = False
ignore_3D = True
ignore_3d_stats = True
select_feature = True
data_exp = "exp051"
notes = "特徴量の名称一意化"

# %%
# %autoreload 2

if is_kaggle_notebook:
    module_path = f"/kaggle/input/myproject-pr-{pr_number:04}"
    # !mkdir src
    # !cp -r $module_path/* src/
    src_path = "./"
else:
    src_path = "../"

sys.path.append(src_path)

from src.data import load_data, add_descriptors, add_descriptors_mordred, add_external_data, make_smile_canonical, add_maccs, add_augumented_gmm, add_graph_features, add_count_atoms
from src.model import train_lgb_for_target, save_lgb_model
from src.utils import NULL_FOR_SUBMISSION, generate_scaffold, score, add_scaffold_kfold, scaffold_cv_split, get_useless_cols
from src.utils.upload_kaggle_dataset import (
    create_kaggle_dataset_metadata,
    upload_kaggle_dataset,
)

# %%
model_name = "lgb"

config = {
    "debug": debug,
    "n_splits": 3,
    "num_epochs": 1000,
    "batch_size": 128,
    "drop_ratio": 0.5,
    "force_update_train": False,
    "augumented_gmm": False,
    "is_complement": True,
    "remove_external_cv": True,
}

dataset_title = f"model-{exp}"
dataset_id = f"koya346/{dataset_title}"

if is_kaggle_notebook:
    config["debug"] = False

if config["debug"]:
    config["n_splits"] = 2
    config["num_epochs"] = 10

targets = ["Tg", "FFV", "Tc", "Density", "Rg"]
org_target_cols = [f"org_{target}" for target in targets]        

# TODO: 学習パラメータ定義
params = {
    "objective": "regression",
    "metric": "mae",
    "verbosity": -1,
    "learning_rate": 0.01,
    "max_depth": 7,
    "seed": 42,
    "subsample": 0.7,
    "colsample_bytree": 0.6,
    "num_boost_round": 20000,
}

config.update(params)
pre_params = copy.deepcopy(params)
pre_params["num_boost_round"] = 300

# %%
wandb_name = f"{exp}_{model_name}" if not config["debug"] else f"{exp}_{model_name}_debug"
wandb.init(project="opp2025", name=wandb_name, config=config)
wandb.log({"Notes": notes})

# ---------------------------
# メイン処理
# ---------------------------
if config["debug"]:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp / "debug"
else:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp

model_output_path = output_path / "model_cv"
if not os.path.exists(model_output_path):
    os.makedirs(model_output_path)

if is_kaggle_notebook:
    # kaggle notebook
    data_dir = Path("/kaggle/input")
else:
    # local
    data_dir = Path("/home/kouya-takahashi/kaggle/opp2025/data/raw")

# 学習データ用意
train_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / data_exp

if os.path.exists(train_path / "train.csv") and not config["force_update_train"]:
    train = pd.read_csv(train_path / "train.csv")
else:
    train, _ = load_data(data_dir)
    # 外部データ判定用に元の目的変数を保持しておく
    # 外部データ判定は scaffold_cv_split 内で行う
    for target in targets:
        train[f"org_{target}"] = train[target]
    

    train["org_SMILES"] = train["SMILES"]
    train["SMILES"] = train["SMILES"].apply(make_smile_canonical)
    if config["debug"]:
        # 各ターゲットが欠損していないデータを30 件ずつ取り出す
        tmp_dfs = []
        for target in targets:
            cond = train[target].notnull()
            tmp_dfs.append(train[cond].iloc[:30])
        train = pd.concat(tmp_dfs).reset_index(drop=True)
    else:
        print(train.shape)
        external_data_dict = [
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset3.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset1.csv",
                "col": "Tc",
                "rename_d": {"TC_mean": "Tc"},
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset4.csv",
                "col": "FFV",
            },
            {
                "ex_path": data_dir / "tg-smiles-pid-polymer-class/TgSS_enriched_cleaned.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_dnst1.xlsx",
                "col": "Density",
                "rename_d": {"density(g/cm3)": "Density"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_tg3.xlsx",
                "col": "Tg",
                "rename_d": {"Tg [K]": "Tg"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/JCIM_sup_bigsmiles.csv",
                "col": "Tg",
                "rename_d": {"Tg (C)": "Tg"}, 
            },
        ]
        for d in external_data_dict:
            print(f"ex_path: {str(d['ex_path'])}")
            train = add_external_data(
                df=train,
                ex_path=d.get("ex_path"),
                col=d.get("col"),
                rename_d=d.get("rename_d"),
                is_complement=config["is_complement"]
            )
            print("after train.shape: ", train.shape)

    train["is_external"] = train["id"].isnull()
    train["id"] = np.arange(len(train))
    
    maccs = add_maccs(train[["id", "SMILES"]]).drop("SMILES", axis=1)
    maccs = maccs.add_prefix("maccs_")
    maccs = maccs.rename(columns={"maccs_id": "id"})
    
    # rdkit の記述子, morgan finger print
    desc = add_descriptors(train[["id", "SMILES"]], radius=2, fp_size=1024).drop("SMILES", axis=1)
    desc = desc.add_prefix("desc_")
    desc = desc.rename(columns={"desc_id": "id"})
    
    desc_mordred = add_descriptors_mordred(train[["id", "SMILES"]], num_confs=10, ignore_3D=ignore_3D, ignore_3d_stats=ignore_3d_stats).drop("SMILES", axis=1)
    desc_mordred = desc_mordred.add_prefix("desc_mordred_")
    desc_mordred = desc_mordred.rename(columns={"desc_mordred_id": "id"})
    
    graph_features = add_graph_features(train[["id", "SMILES"]])
    graph_features = graph_features.add_prefix("graph_features_")
    graph_features = graph_features.rename(columns={"graph_features_id": "id"})
    
    cnt_atoms = add_count_atoms(train[["id", "SMILES"]])
    cnt_atoms = cnt_atoms.add_prefix("cnt_atoms_")
    cnt_atoms = cnt_atoms.rename(columns={"cnt_atoms_id": "id"})
    
    for df in [maccs, desc, desc_mordred, graph_features, cnt_atoms]:
        train = train.merge(df, on="id")

    features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns
    for col in features:
        if train[col].dtype == "object":
            train[col] = pd.to_numeric(train[col], errors="coerce")
    useless_cols = get_useless_cols(train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1))
    
    train = train.drop(useless_cols, axis=1)
    
    os.makedirs(output_path, exist_ok=True)
    train.to_csv(output_path / "train.csv", index=False)
    print("Saved train.csv")

# 不要なビット列を除去
bit_cols = []
remove_cols = []

for col in train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns:
    if len(train[col].unique()) != 2:
        continue
    if np.all(train[col].unique() == np.array([0, 1])):
        bit_cols.append(col)
        p = train[col].mean()
        if p > 0.01 and p < 0.99:
            continue
        remove_cols.append(col)
print("bit cols: ", len(bit_cols))
print("remove cols: ", len(remove_cols))

train = train.drop(remove_cols, axis=1)

# 計算済の fold を突合
folds = pd.read_csv("/home/kouya-takahashi/kaggle/opp2025/data/preprocess/fold/folds.csv")
train = train.merge(folds[["SMILES", "fold"]], how="left", on="SMILES")

features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "fold", "is_external"], axis=1).columns
print(len(features))
oof_dfs = []

loss_table_wandb = wandb.Table(["exp", "model_name", "fold", "target", "mae", "mse"])
all_loss_tables = []
mae_dict = {}
all_models = {}

for idx, target_col in enumerate(targets):
    loss_tables = []
    print(f"\n=== Training for target: {target_col} ===")

    df_train = train[train[target_col].notnull()].reset_index(drop=True)
    X = df_train[features]
    y = df_train[target_col]
    oof = np.full(len(X), np.nan, dtype=float)
    
    models = []

    for fold, tr_idx, val_idx in scaffold_cv_split(df_train, target=target_col, n_splits=config["n_splits"], remove_external=config["remove_external_cv"]):
        if len(tr_idx) == 0 or len(val_idx) == 0:
            print(f"Skip fold... tr_idx: {len(tr_idx)}, val_idx: {len(val_idx)}")
            continue
        loss_table = {}
        print(f"fold: {fold + 1}")

        if select_feature:
            hits = np.zeros(X.shape[1], dtype=int)
    
            rs = ShuffleSplit(n_splits=3, train_size=0.9, random_state=42)
            for idx, (tr_in, va_in) in enumerate(rs.split(tr_idx)):
                X_tr_in, X_va_in = X.iloc[tr_in][features], X.iloc[va_in][features]
                y_tr_in, y_va_in = y.iloc[tr_in], y.iloc[va_in]
                dtrain_in = lgb.Dataset(X_tr_in, label=y_tr_in)
                dvalid_in = lgb.Dataset(X_va_in, label=y_va_in)
                model = lgb.train(
                    params,
                    dtrain_in,
                    valid_sets=[dtrain_in, dvalid_in],
                    callbacks=[
                        lgb.early_stopping(stopping_rounds=50),
                        lgb.log_evaluation(200)
                    ]
                )
                rank = model.feature_importance("gain").argsort()[::-1]
                topk = set(rank[:int(0.3 * len(rank))])
                hits[list(topk)] += 1
            keep = hits >= 2
            use_features = features[keep]
        else:
            use_features = features
        print(len(use_features))        

        # 特徴量選択して valid データとともに学習
        X_train, X_val = X.iloc[tr_idx][use_features], X.iloc[val_idx][use_features]
        y_train, y_val = y.iloc[tr_idx], y.iloc[val_idx]

        if config["augumented_gmm"]:
            X_train, y_train = add_augumented_gmm(X_train, y_train)    
        
        dtrain = lgb.Dataset(X_train, label=y_train)
        dval = lgb.Dataset(X_val, label=y_val, reference=dtrain)

        model = lgb.train(
            params,
            dtrain,
            valid_sets=[dtrain, dval],
            callbacks=[
                lgb.early_stopping(stopping_rounds=50),
                lgb.log_evaluation(200)
            ]
        )

        save_lgb_model(model, str(model_output_path / f"model_{target_col}_{fold}.txt"))

        pred = model.predict(X_val, num_iteration=model.best_iteration)
        oof[val_idx] = pred

        mse = mean_squared_error(y_val, pred)
        mae = mean_absolute_error(y_val, pred)
        print(f"fold: {fold}, target: {target_col}, mae: {mae}")
        loss_table["fold"] = fold
        loss_table["target"] = target_col
        loss_table["mae"] = mae
        loss_table["mse"] = mse

        loss_tables.append(loss_table)
        models.append(model)

    # 評価に使うのは元データのみ
    cond = (~np.isnan(oof)) & (df_train[f"org_{target_col}"].notnull())
    y_true = y[cond]
    y_pred = oof[cond]
    score_mse = mean_squared_error(y_true, y_pred)
    score_mae = mean_absolute_error(y_true, y_pred)
    print(f"RMSE for {target_col}: {score_mse:.4f}")
    print(f"MAE for {target_col}: {score_mae:.4f}")
    mae_dict[target_col] = score_mae

    for loss_table in loss_tables:
        loss_table_wandb.add_data(exp, model_name, loss_table["fold"], loss_table["target"], loss_table["mae"], loss_table["mse"])
    all_loss_tables += loss_tables

    oof_df = pd.DataFrame({
        "id": df_train["id"].values,
        target_col: oof
    })
    oof_dfs.append(oof_df)   

    all_models[target_col] = models

wandb.log({"fold_target_losses": loss_table_wandb})
# target 毎の 平均 mae を記録
for target in targets:
    key_name = f"{target}_mean_mae"
    mae_values = mae_dict[target]
    # mae_values = [d["mae"] for d in all_loss_tables if d["target"] == target]
    wandb.log({key_name: np.mean(mae_values)})

# CV 計算
cond = ~train["is_external"]
oof_df = pd.DataFrame()

# 元の目的変数も入れておく
for target in targets:
    oof_df[f"org_{target}"] = train.loc[cond, f"org_{target}"]

oof_df["id"] = train.loc[cond, "id"]

# 正規化前の SMILES
oof_df["SMILES"] = train.loc[cond, "org_SMILES"]

for i_oof in oof_dfs:
    oof_df = oof_df.merge(i_oof, on="id", how="left")

# # 予測しなかった部分は null にしておく
# for target in targets:
#     oof_df.loc[oof_df[target] == 0, target] = np.nan

oof_df.to_csv(output_path / "oof.csv", index=False)

solution = train.loc[cond, ["id"] + org_target_cols].copy()
solution.columns = ["id"] + targets

# solution = solution.fillna(NULL_FOR_SUBMISSION)

# oof_df = oof_df.fillna(NULL_FOR_SUBMISSION)

# 評価
final_score = score(
    solution=solution,
    submission=oof_df,
)
print(f"\n📊 Final OOF Score (wMAE): {final_score:.6f}")
wandb.log({"wMAE": final_score})

# target 毎の best_iteration を保存する。保存したモデルには記録されてなかった
best_iterations = {}
for target in targets:
    target_best_iterations = [model.best_iteration for model in all_models[target]]
    best_iterations[target] = target_best_iterations
print(best_iterations)

with open(output_path / "best_iterations.json", "w") as f:
    json.dump(best_iterations, f)
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Notes</td><td>特徴量の名称一意化</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">exp051_lgb_debug</strong> at: <a href='https://wandb.ai/ko_ya346/opp2025/runs/6hz2d0k0' target="_blank">https://wandb.ai/ko_ya346/opp2025/runs/6hz2d0k0</a><br> View project at: <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">https://wandb.ai/ko_ya346/opp2025</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250901_143140-6hz2d0k0/logs</code>
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/kouya-takahashi/kaggle/opp2025/notebook/wandb/run-20250901_143159-godyonul</code>
# Syncing run <strong><a href='https://wandb.ai/ko_ya346/opp2025/runs/godyonul' target="_blank">exp051_lgb</a></strong> to <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">https://wandb.ai/ko_ya346/opp2025</a>
#  View run at <a href='https://wandb.ai/ko_ya346/opp2025/runs/godyonul' target="_blank">https://wandb.ai/ko_ya346/opp2025/runs/godyonul</a>
# (7973, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/neurips-open-polymer-prediction-2025/train_supplement/dataset3.csv
# after train.shape:  (8019, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/neurips-open-polymer-prediction-2025/train_supplement/dataset1.csv
# after train.shape:  (8148, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/neurips-open-polymer-prediction-2025/train_supplement/dataset4.csv
# after train.shape:  (8972, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/tg-smiles-pid-polymer-class/TgSS_enriched_cleaned.csv
# after train.shape:  (10343, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/smiles-extra-data/data_dnst1.xlsx
# after train.shape:  (10819, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/smiles-extra-data/data_tg3.xlsx
# after train.shape:  (11314, 13)
# ex_path: /home/kouya-takahashi/kaggle/opp2025/data/raw/smiles-extra-data/JCIM_sup_bigsmiles.csv
# after train.shape:  (11326, 13)
# Generating maccs:   0%|          | 0/11326 [00:00<?, ?it/s]
# Generating descriptors:   0%|          | 0/11326 [00:00<?, ?it/s]
# mordred desc:   0%|          | 0/11326 [00:00<?, ?it/s]
 'desc_mordred_n11AHRing', 'desc_mordred_n4FRing', 'desc_mordred_n5FRing', 'desc_mordred_n6FRing', 'desc_mordred_n4FHRing', 'desc_mordred_n5FHRing', 'desc_mordred_n6FHRing', 'desc_mordred_n4FaRing', 'desc_mordred_n5FaRing', 'desc_mordred_n6FaRing', 'desc_mordred_n7FaRing', 'desc_mordred_n11FaRing', 'desc_mordred_n4FaHRing', 'desc_mordred_n5FaHRing', 'desc_mordred_n6FaHRing', 'desc_mordred_n7FaHRing', 'desc_mordred_n11FaHRing', 'desc_mordred_n4FARing', 'desc_mordred_n5FARing', 'desc_mordred_n6FARing', 'desc_mordred_n4FAHRing', 'desc_mordred_n5FAHRing', 'desc_mordred_n6FAHRing']
# Highly correlated cols:  ['maccs_maccs_40', 'maccs_maccs_55', 'maccs_maccs_56', 'maccs_maccs_58', 'maccs_maccs_60', 'maccs_maccs_61', 'maccs_maccs_63', 'maccs_maccs_64', 'maccs_maccs_71', 'maccs_maccs_105', 'maccs_maccs_117', 'maccs_maccs_134', 'maccs_maccs_135', 'maccs_maccs_143', 'maccs_maccs_147', 'desc_MaxAbsEStateIndex', 'desc_HeavyAtomMolWt', 'desc_ExactMolWt', 'desc_NumValenceElectrons', 'desc_FpDensityMorgan2', 'desc_FpDensityMorgan3', 'desc_Chi0', 'desc_Chi0n', 'desc_Chi0v', 'desc_Chi1', 'desc_Chi1n', 'desc_Chi1v', 'desc_Chi2n', 'desc_Chi2v', 'desc_Chi3n', 'desc_Chi3v', 'desc_Chi4n', 'desc_Chi4v', 'desc_HallKierAlpha', 'desc_Kappa1', 'desc_LabuteASA', 'desc_SlogP_VSA6', 'desc_VSA_EState6', 'desc_HeavyAtomCount', 'desc_NOCount', 'desc_NumAromaticCarbocycles', 'desc_NumAromaticRings', 'desc_NumHDonors', 'desc_MolMR', 'desc_fr_Al_OH_noTert', 'desc_fr_COO2', 'desc_fr_C_O_noCOO', 'desc_fr_Nhpyrrole', 'desc_fr_benzene', 'desc_fr_diazo', 'desc_fr_halogen', 'desc_fr_nitrile', 'desc_fr_nitro', 'desc_fr_nitro_arom', 'desc_fr_phenol', 'desc_fr_phenol_noOrthoHbond', 'desc_fr_phos_ester', 'desc_mfp_vec33', 'desc_mfp_vec80', 'desc_mfp_vec226', 'desc_mfp_vec294', 'desc_mfp_vec356', 'desc_mfp_vec695', 'desc_mfp_vec849', 'desc_mfp_vec935', 'desc_mfp_vec939', 'desc_mordred_ABC', 'desc_mordred_ABCGG', 'desc_mordred_SpAbs_A', 'desc_mordred_SpDiam_A', 'desc_mordred_SpAD_A', 'desc_mordred_VE2_A', 'desc_mordred_VE3_A', 'desc_mordred_VR2_A', 'desc_mordred_nAromAtom', 'desc_mordred_nAromBond', 'desc_mordred_nAtom', 'desc_mordred_nHeavyAtom', 'desc_mordred_nHetero', 'desc_mordred_nB', 'desc_mordred_nC', 'desc_mordred_nF', 'desc_mordred_nX', 'desc_mordred_ATS1dv', 'desc_mordred_ATS2dv', 'desc_mordred_ATS3dv', 'desc_mordred_ATS4dv', 'desc_mordred_ATS5dv', 'desc_mordred_ATS6dv', 'desc_mordred_ATS7dv', 'desc_mordred_ATS8dv', 'desc_mordred_ATS0d', 'desc_mordred_ATS1d', 'desc_mordred_ATS2d', 'desc_mordred_ATS3d', 'desc_mordred_ATS4d', 'desc_mordred_ATS5d', 'desc_mordred_ATS6d', 'desc_mordred_ATS7d', 'desc_mordred_ATS8d', 'desc_mordred_ATS1Z', 'desc_mordred_ATS2Z', 'desc_mordred_ATS3Z', 'desc_mordred_ATS4Z', 'desc_mordred_ATS5Z', 'desc_mordred_ATS6Z', 'desc_mordred_ATS7Z', 'desc_mordred_ATS8Z', 'desc_mordred_AATS2dv', 'desc_mordred_AATS3dv', 'desc_mordred_AATS4dv', 'desc_mordred_AATS1d', 'desc_mordred_AATS3d', 'desc_mordred_AATS4d', 'desc_mordred_ATSC0dv', 'desc_mordred_ATSC0d', 'desc_mordred_MATS7d', 'desc_mordred_MATS8d', 'desc_mordred_BCUTd-1h', 'desc_mordred_BCUTZ-1l', 'desc_mordred_BalabanJ', 'desc_mordred_BertzCT', 'desc_mordred_nBonds', 'desc_mordred_nBondsO', 'desc_mordred_nBondsS', 'desc_mordred_nBondsA', 'desc_mordred_nBondsM', 'desc_mordred_nBondsKS', 'desc_mordred_nBondsKD', 'desc_mordred_C2SP2', 'desc_mordred_HybRatio', 'desc_mordred_FCSP3', 'desc_mordred_Xch-7d', 'desc_mordred_Xch-3dv', 'desc_mordred_Xch-4dv', 'desc_mordred_Xpc-4d', 'desc_mordred_Xpc-5d', 'desc_mordred_Xpc-6d', 'desc_mordred_Xp-0d', 'desc_mordred_Xp-1d', 'desc_mordred_Xp-2d', 'desc_mordred_Xp-3d', 'desc_mordred_Xp-4d', 'desc_mordred_Xp-5d', 'desc_mordred_Xp-6d', 'desc_mordred_Xp-7d', 'desc_mordred_AXp-0d', 'desc_mordred_AXp-5d', 'desc_mordred_AXp-6d', 'desc_mordred_AXp-7d', 'desc_mordred_SZ', 'desc_mordred_MZ', 'desc_mordred_SpAbs_Dt', 'desc_mordred_SpMax_Dt', 'desc_mordred_SpDiam_Dt', 'desc_mordred_SpAD_Dt', 'desc_mordred_LogEE_Dt', 'desc_mordred_VE1_Dt', 'desc_mordred_VE2_Dt', 'desc_mordred_VE3_Dt', 'desc_mordred_VR1_Dt', 'desc_mordred_VR2_Dt', 'desc_mordred_VR3_Dt', 'desc_mordred_SpAbs_D', 'desc_mordred_SpMax_D', 'desc_mordred_SpDiam_D', 'desc_mordred_SpAD_D', 'desc_mordred_LogEE_D', 'desc_mordred_VE1_D', 'desc_mordred_VE2_D', 'desc_mordred_VE3_D', 'desc_mordred_VR1_D', 'desc_mordred_VR2_D', 'desc_mordred_VR3_D', 'desc_mordred_NsssB', 'desc_mordred_NtCH', 'desc_mordred_NaaCH', 'desc_mordred_NsNH2', 'desc_mordred_NssNH', 'desc_mordred_NaaNH', 'desc_mordred_NtN', 'desc_mordred_NddsN', 'desc_mordred_NssssN', 'desc_mordred_NsF', 'desc_mordred_NdsssP', 'desc_mordred_NsSH' ...
# Saved train.csv
# bit cols:  1138
# remove cols:  500
# 1175
#
# === Training for target: Tg ===
# train rows: 5476, valid rows: 191, ignore rows: 2577
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1:
# [5600]	training's l1: 0.00176673	valid_1's l1: 0.0060046
# [5800]	training's l1: 0.00171043	valid_1's l1: 0.00599805
# [6000]	training's l1: 0.00165369	valid_1's l1: 0.00599195
# [6200]	training's l1: 0.0016023	valid_1's l1: 0.00598842
# [6400]	training's l1: 0.00155252	valid_1's l1: 0.00598335
# [6600]	training's l1: 0.00150619	valid_1's l1: 0.00597666
# [6800]	training's l1: 0.00145704	valid_1's l1: 0.00597149
# [7000]	training's l1: 0.00141341	valid_1's l1: 0.00596837
# [7200]	training's l1: 0.00137279	valid_1's l1: 0.00596471
# [7400]	training's l1: 0.00133011	valid_1's l1: 0.00596079
# [7600]	training's l1: 0.00129294	valid_1's l1: 0.00595771
# Early stopping, best iteration is:
# [7736]	training's l1: 0.00126333	valid_1's l1: 0.00595565
# fold: 2, target: FFV, mae: 0.005955648342584902
# RMSE for FFV: 0.0002
# MAE for FFV: 0.0077
#
# === Training for target: Tc ===
# train rows: 392, valid rows: 436, ignore rows: 38
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0211305	valid_1's l1: 0.0291345
# [400]	training's l1: 0.0132286	valid_1's l1: 0.0266915
# Early stopping, best iteration is:
# [374]	training's l1: 0.0137535	valid_1's l1: 0.0266221
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0211546	valid_1's l1: 0.0337516
# Early stopping, best iteration is:
# [251]	training's l1: 0.0177374	valid_1's l1: 0.032027
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0208094	valid_1's l1: 0.0340661
# [400]	training's l1: 0.0128325	valid_1's l1: 0.0314756
# Early stopping, best iteration is:
# [415]	training's l1: 0.0125842	valid_1's l1: 0.0314404
# 341
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0261698	valid_1's l1: 0.0334076
# Early stopping, best iteration is:
# [206]	training's l1: 0.0257789	valid_1's l1: 0.0333113
# fold: 0, target: Tc, mae: 0.033311347275379884
# train rows: 640, valid rows: 187, ignore rows: 39
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0200977	valid_1's l1: 0.0305097
# [400]	training's l1: 0.0128717	valid_1's l1: 0.027456
# [600]	training's l1: 0.0110038	valid_1's l1: 0.0272396
# Early stopping, best iteration is:
# [555]	training's l1: 0.011334	valid_1's l1: 0.0272304
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0204096	valid_1's l1: 0.026354
# [400]	training's l1: 0.0129859	valid_1's l1: 0.0244337
# Early stopping, best iteration is:
# [396]	training's l1: 0.013039	valid_1's l1: 0.0244093
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0196847	valid_1's l1: 0.0328466
# [400]	training's l1: 0.0123958	valid_1's l1: 0.0287244
# [600]	training's l1: 0.0103853	valid_1's l1: 0.0280716
# Early stopping, best iteration is:
# [634]	training's l1: 0.0101542	valid_1's l1: 0.0280261
# 348
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0237894	valid_1's l1: 0.033618
# [400]	training's l1: 0.0172943	valid_1's l1: 0.0319589
# Early stopping, best iteration is:
# [410]	training's l1: 0.0171365	valid_1's l1: 0.0319051
# fold: 1, target: Tc, mae: 0.031905146742078165
# train rows: 700, valid rows: 114, ignore rows: 52
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0200799	valid_1's l1: 0.0251498
# Early stopping, best iteration is:
# [331]	training's l1: 0.014346	valid_1's l1: 0.0228373
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0198749	valid_1's l1: 0.0251312
# Early stopping, best iteration is:
# [252]	training's l1: 0.0166496	valid_1's l1: 0.0245226
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0197206	valid_1's l1: 0.0300925
# Early stopping, best iteration is:
# [293]	training's l1: 0.0150276	valid_1's l1: 0.0290264
# 341
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0195161	valid_1's l1: 0.0471722
# [400]	training's l1: 0.0126069	valid_1's l1: 0.0447247
# Early stopping, best iteration is:
# [400]	training's l1: 0.0126069	valid_1's l1: 0.0447247
# fold: 2, target: Tc, mae: 0.04472474737528107
# RMSE for Tc: 0.0022
# MAE for Tc: 0.0347
#
# === Training for target: Density ===
# train rows: 639, valid rows: 340, ignore rows: 267
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0252501	valid_1's l1: 0.0255669
# [400]	training's l1: 0.013466	valid_1's l1: 0.0213514
# [600]	training's l1: 0.0110162	valid_1's l1: 0.0209796
# [800]	training's l1: 0.00932592	valid_1's l1: 0.0207331
# [1000]	training's l1: 0.0080758	valid_1's l1: 0.0203775
# [1200]	training's l1: 0.00704005	valid_1's l1: 0.0201606
# Early stopping, best iteration is:
# [1213]	training's l1: 0.00697648	valid_1's l1: 0.020148
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0251616	valid_1's l1: 0.0283626
# [400]	training's l1: 0.0133033	valid_1's l1: 0.0228847
# Early stopping, best iteration is:
# [395]	training's l1: 0.0133879	valid_1's l1: 0.0228233
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0254061	valid_1's l1: 0.0266909
# [400]	training's l1: 0.013629	valid_1's l1: 0.0228517
# [600]	training's l1: 0.0109585	valid_1's l1: 0.0222324
# [800]	training's l1: 0.00908562	valid_1's l1: 0.0216942
# [1000]	training's l1: 0.00781722	valid_1's l1: 0.0212899
# [1200]	training's l1: 0.00685622	valid_1's l1: 0.0209771
# Early stopping, best iteration is:
# [1317]	training's l1: 0.00632969	valid_1's l1: 0.0207914
# 344
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0334487	valid_1's l1: 0.0591436
# [400]	training's l1: 0.016502	valid_1's l1: 0.047026
# [600]	training's l1: 0.0133339	valid_1's l1: 0.0463491
# Early stopping, best iteration is:
# [575]	training's l1: 0.0136166	valid_1's l1: 0.0462537
# fold: 0, target: Density, mae: 0.0462536832834749
# train rows: 884, valid rows: 155, ignore rows: 207
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0275649	valid_1's l1: 0.0410113
# [400]	training's l1: 0.0163133	valid_1's l1: 0.0334552
# Early stopping, best iteration is:
# [506]	training's l1: 0.014729	valid_1's l1: 0.032944
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0279324	valid_1's l1: 0.0338682
# [400]	training's l1: 0.016766	valid_1's l1: 0.0236982
# Early stopping, best iteration is:
# [497]	training's l1: 0.0151616	valid_1's l1: 0.0230199
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0270391	valid_1's l1: 0.0444533
# [400]	training's l1: 0.0152672	valid_1's l1: 0.0380723
# [600]	training's l1: 0.0127705	valid_1's l1: 0.0368246
# [800]	training's l1: 0.0111872	valid_1's l1: 0.0361732
# Early stopping, best iteration is:
# [804]	training's l1: 0.0111594	valid_1's l1: 0.036172
# 342
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1:
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.35119	valid_1's l1: 1.6707
# [400]	training's l1: 0.872004	valid_1's l1: 1.47173
# [600]	training's l1: 0.636037	valid_1's l1: 1.38694
# [800]	training's l1: 0.489096	valid_1's l1: 1.34258
# Early stopping, best iteration is:
# [757]	training's l1: 0.517391	valid_1's l1: 1.34031
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.33848	valid_1's l1: 2.12386
# [400]	training's l1: 0.843666	valid_1's l1: 2.05973
# Early stopping, best iteration is:
# [360]	training's l1: 0.906165	valid_1's l1: 2.05533
# 349
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.32504	valid_1's l1: 2.41024
# [400]	training's l1: 0.827681	valid_1's l1: 2.09658
# [600]	training's l1: 0.615501	valid_1's l1: 2.07513
# Early stopping, best iteration is:
# [721]	training's l1: 0.521088	valid_1's l1: 2.06752
# fold: 0, target: Rg, mae: 2.067519258773295
# train rows: 459, valid rows: 155, ignore rows: 0
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.15684	valid_1's l1: 2.12692
# [400]	training's l1: 0.738321	valid_1's l1: 1.98736
# Early stopping, best iteration is:
# [450]	training's l1: 0.69472	valid_1's l1: 1.98444
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.20473	valid_1's l1: 1.45902
# [400]	training's l1: 0.76875	valid_1's l1: 1.20767
# Early stopping, best iteration is:
# [536]	training's l1: 0.652016	valid_1's l1: 1.20123
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.18109	valid_1's l1: 1.73752
# [400]	training's l1: 0.741325	valid_1's l1: 1.6242
# Early stopping, best iteration is:
# [362]	training's l1: 0.780693	valid_1's l1: 1.62158
# 327
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.23634	valid_1's l1: 1.91625
# [400]	training's l1: 0.793275	valid_1's l1: 1.75328
# [600]	training's l1: 0.647215	valid_1's l1: 1.7106
# Early stopping, best iteration is:
# [689]	training's l1: 0.60071	valid_1's l1: 1.70039
# fold: 1, target: Rg, mae: 1.7003897591223072
# train rows: 497, valid rows: 117, ignore rows: 0
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.19479	valid_1's l1: 1.9389
# [400]	training's l1: 0.792848	valid_1's l1: 1.71475
# [600]	training's l1: 0.643433	valid_1's l1: 1.67724
# Early stopping, best iteration is:
# [678]	training's l1: 0.603237	valid_1's l1: 1.66949
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.18849	valid_1's l1: 2.06977
# [400]	training's l1: 0.779022	valid_1's l1: 1.74893
# [600]	training's l1: 0.643171	valid_1's l1: 1.66267
# [800]	training's l1: 0.54994	valid_1's l1: 1.61664
# [1000]	training's l1: 0.478836	valid_1's l1: 1.59699
# Early stopping, best iteration is:
# [1038]	training's l1: 0.465648	valid_1's l1: 1.59479
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.18039	valid_1's l1: 1.97812
# Early stopping, best iteration is:
# [304]	training's l1: 0.890687	valid_1's l1: 1.85306
# 339
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.15289	valid_1's l1: 2.6163
# [400]	training's l1: 0.755574	valid_1's l1: 2.45361
# Early stopping, best iteration is:
# [376]	training's l1: 0.774723	valid_1's l1: 2.44991
# fold: 2, target: Rg, mae: 2.4499128006408837
# RMSE for Rg: 8.2117
# MAE for Rg: 2.0477
#
# 📊 Final OOF Score (wMAE): 0.057563
# {'Tg': [578, 348, 1160], 'FFV': [1441, 6534, 7736], 'Tc': [206, 410, 400], 'Density': [575, 1200, 815], 'Rg': [721, 689, 376]}
