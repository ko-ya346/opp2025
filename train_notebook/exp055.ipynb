# %% [markdown]
# - -> exp054
# - 主鎖の抽出に失敗したら空

# %%
# %load_ext autotime
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os

is_kaggle_notebook = os.path.exists("/kaggle/input")

# 必要パッケージをインストール
if is_kaggle_notebook:
    # !pip install /kaggle/input/rdkit-2025-3-3-cp311/rdkit-2025.3.3-cp311-cp311-manylinux_2_28_x86_64.whl
    # !pip install /kaggle/input/torch-geometric-2-6-1/torch_geometric-2.6.1-py3-none-any.whl

# %%
import copy
import json
import os
import sys
import warnings
from pathlib import Path

import wandb

import lightgbm as lgb
import numpy as np
import pandas as pd
import torch
from rdkit import rdBase
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GroupKFold, KFold, ShuffleSplit
from tqdm.auto import tqdm

from sklearn.decomposition import TruncatedSVD
from scipy import sparse

rdBase.DisableLog("rdApp.warning")
warnings.filterwarnings("ignore")

wandb.login()
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# True

# %%
pr_number = 1
debug = True
exp = "exp055"
data_exp = "exp055"
notes = "主鎖の抽出に失敗したら空"
ignore_3D = True
ignore_3d_stats = True
select_feature = True
remove_asterisk = False

feature_top_ratio = 0.3

# %%
# %autoreload 2

if is_kaggle_notebook:
    module_path = f"/kaggle/input/myproject-pr-{pr_number:04}"
    # !mkdir src
    # !cp -r $module_path/* src/
    src_path = "./"
else:
    src_path = "../"

sys.path.append(src_path)

from src.data import load_data, add_descriptors, add_descriptors_mordred, add_external_data, make_smile_canonical, add_maccs, add_augumented_gmm, add_graph_features, add_count_atoms
from src.model import train_lgb_for_target, save_lgb_model
from src.utils import NULL_FOR_SUBMISSION, generate_scaffold, score, add_scaffold_kfold, scaffold_cv_split, get_useless_cols, extract_main_chain_smiles_from_star, cap_stars_with_H
from src.utils.upload_kaggle_dataset import (
    create_kaggle_dataset_metadata,
    upload_kaggle_dataset,
)

# %%
model_name = "lgb"

config = {
    "debug": debug,
    "n_splits": 3,
    "num_epochs": 1000,
    "batch_size": 128,
    "drop_ratio": 0.5,
    "force_update_train": False,
    "augumented_gmm": False,
    "is_complement": True,
    "remove_external_cv": True,
}

dataset_title = f"model-{exp}"
dataset_id = f"koya346/{dataset_title}"

if is_kaggle_notebook:
    config["debug"] = False

if config["debug"]:
    config["n_splits"] = 2
    config["num_epochs"] = 10

targets = ["Tg", "FFV", "Tc", "Density", "Rg"]
org_target_cols = [f"org_{target}" for target in targets]        

# TODO: 学習パラメータ定義
params = {
    "objective": "regression",
    "metric": "mae",
    "verbosity": -1,
    "learning_rate": 0.01,
    "max_depth": 7,
    "seed": 42,
    "subsample": 0.7,
    "colsample_bytree": 0.6,
    "num_boost_round": 20000,
}

config.update(params)
pre_params = copy.deepcopy(params)
pre_params["num_boost_round"] = 300

# %%
# ---------------------------
# メイン処理
# ---------------------------
if config["debug"]:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp / "debug"
else:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp

model_output_path = output_path / "model_cv"
if not os.path.exists(model_output_path):
    os.makedirs(model_output_path)

if is_kaggle_notebook:
    # kaggle notebook
    data_dir = Path("/kaggle/input")
else:
    # local
    data_dir = Path("/home/kouya-takahashi/kaggle/opp2025/data/raw")


train_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / data_exp
# 学習データ用意

if os.path.exists(train_path / "train.csv") and not config["force_update_train"]:
    train = pd.read_csv(train_path / "train.csv")
else:
    train, _ = load_data(data_dir)
    # 外部データ判定用に元の目的変数を保持しておく
    # 外部データ判定は scaffold_cv_split 内で行う
    for target in targets:
        train[f"org_{target}"] = train[target]
    

    train["org_SMILES"] = train["SMILES"]
    train["SMILES"] = train["SMILES"].apply(make_smile_canonical)
    if config["debug"]:
        # 各ターゲットが欠損していないデータを30 件ずつ取り出す
        tmp_dfs = []
        for target in targets:
            cond = train[target].notnull()
            tmp_dfs.append(train[cond].iloc[:30])
        train = pd.concat(tmp_dfs).reset_index(drop=True)
    else:
        print(train.shape)
        external_data_dict = [
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset3.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset1.csv",
                "col": "Tc",
                "rename_d": {"TC_mean": "Tc"},
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset4.csv",
                "col": "FFV",
            },
            {
                "ex_path": data_dir / "tg-smiles-pid-polymer-class/TgSS_enriched_cleaned.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_dnst1.xlsx",
                "col": "Density",
                "rename_d": {"density(g/cm3)": "Density"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_tg3.xlsx",
                "col": "Tg",
                "rename_d": {"Tg [K]": "Tg"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/JCIM_sup_bigsmiles.csv",
                "col": "Tg",
                "rename_d": {"Tg (C)": "Tg"}, 
            },
        ]
        for d in external_data_dict:
            print(f"ex_path: {str(d['ex_path'])}")
            train = add_external_data(
                df=train,
                ex_path=d.get("ex_path"),
                col=d.get("col"),
                rename_d=d.get("rename_d"),
                is_complement=config["is_complement"]
            )
            print("after train.shape: ", train.shape)

    train["is_external"] = train["id"].isnull()
    train["id"] = np.arange(len(train))
    train["SMILES_cap"] = train["SMILES"].apply(cap_stars_with_H)
    
    main_smiles = []
    cnt_error = 0
    for smiles in train["SMILES"].values:
        try:
            main_smiles.append(extract_main_chain_smiles_from_star(smiles))
        except Exception as e:
            # print(f"{smiles}: {e}")
            cnt_error += 1
            main_smiles.append("")
            # main_smiles.append(smiles)
    print(f"cnt error extract main chain: {cnt_error}")
    
    train["main_SMILES"] = main_smiles
    if config["debug"]:
        train.loc[[1, 10], "main_SMILES"] = ""

    train.loc[train["main_SMILES"] == "", "main_SMILES"] = np.nan
    if remove_asterisk:
        cols = ["SMILES_cap", "main_SMILES"]
    else:
        cols = ["SMILES", "main_SMILES"]

    # SMILES, main_SMILESそれぞれで特徴量を生成する
    for smiles_col in ["SMILES", "main_SMILES"]:
        prefix = ""
        if smiles_col == "main_SMILES":
            prefix = "main_"
        
        cond = train[smiles_col].notnull()
        maccs = add_maccs(train.loc[cond, ["id", smiles_col]], col=smiles_col).drop(smiles_col, axis=1)
        maccs = maccs.add_prefix(f"{prefix}maccs_")
        maccs = maccs.rename(columns={f"{prefix}maccs_id": "id"})

        desc = add_descriptors(train.loc[cond, ["id", smiles_col]], radius=2, fp_size=1024, col=smiles_col).drop(smiles_col, axis=1)
        desc = desc.add_prefix(f"{prefix}desc_")
        desc = desc.rename(columns={f"{prefix}desc_id": "id"})

        desc_mordred = add_descriptors_mordred(train.loc[cond, ["id", smiles_col]], num_confs=10, ignore_3D=ignore_3D, ignore_3d_stats=ignore_3d_stats, col=smiles_col).drop(smiles_col, axis=1)
        desc_mordred = desc_mordred.add_prefix("desc_mordred_")
        desc_mordred = desc_mordred.rename(columns={"desc_mordred_id": "id"})
        
        graph_features = add_graph_features(train.loc[cond, ["id", smiles_col]], col=smiles_col).drop(smiles_col, axis=1)
        graph_features = graph_features.add_prefix("graph_features_")
        graph_features = graph_features.rename(columns={"graph_features_id": "id"})
        
        cnt_atoms = add_count_atoms(train.loc[cond, ["id", smiles_col]], col=smiles_col).drop(smiles_col, axis=1)
        cnt_atoms = cnt_atoms.add_prefix("cnt_atoms_")
        cnt_atoms = cnt_atoms.rename(columns={"cnt_atoms_id": "id"})
        
        for df in [maccs, desc, desc_mordred, graph_features, cnt_atoms]:
            train = train.merge(df, how="left", on="id")
        
        print(train.shape)

    train["has_main_smiles"] = train["main_SMILES"].notnull()
    train = train.drop(["main_SMILES", "SMILES_cap"], axis=1)
    features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns
    for col in features:
        if train[col].dtype == "object":
            train[col] = pd.to_numeric(train[col], errors="coerce")
    useless_cols = get_useless_cols(train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1))
    
    train = train.drop(useless_cols, axis=1)
    
    os.makedirs(output_path, exist_ok=True)
    train.to_csv(output_path / "train.csv", index=False)
    print("Saved train.csv")

# 不要なビット列を除去
bit_cols = []
remove_cols = []

for col in train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns:
    if len(train[col].unique()) != 2:
        continue
    if np.all(train[col].unique() == np.array([0, 1])):
        bit_cols.append(col)
        p = train[col].mean()
        if p > 0.01 and p < 0.99:
            continue
        remove_cols.append(col)
print("bit cols: ", len(bit_cols))
print("remove cols: ", len(remove_cols))

train = train.drop(remove_cols, axis=1)

# 計算済の fold を突合
folds = pd.read_csv("/home/kouya-takahashi/kaggle/opp2025/data/preprocess/fold/folds.csv")
train = train.merge(folds[["SMILES", "fold"]], how="left", on="SMILES")

features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "fold", "is_external"], axis=1).columns
print(len(features))
oof_dfs = []

# loss_table_wandb = wandb.Table(["exp", "model_name", "fold", "target", "mae", "mse"])
all_loss_tables = []
mae_dict = {}
all_models = {}

for idx, target_col in enumerate(targets):
    loss_tables = []
    print(f"\n=== Training for target: {target_col} ===")

    df_train = train[train[target_col].notnull()].reset_index(drop=True)
    X = df_train[features]
    y = df_train[target_col]
    oof = np.full(len(X), np.nan, dtype=float)
    
    models = []

    for fold, tr_idx, val_idx in scaffold_cv_split(df_train, target=target_col, n_splits=config["n_splits"], remove_external=config["remove_external_cv"]):
        if len(tr_idx) == 0 or len(val_idx) == 0:
            print(f"Skip fold... tr_idx: {len(tr_idx)}, val_idx: {len(val_idx)}")
            continue
        loss_table = {}
        print(f"fold: {fold + 1}")

        if select_feature:
            hits = np.zeros(X.shape[1], dtype=int)
    
            rs = ShuffleSplit(n_splits=3, train_size=0.9, random_state=42)
            for idx, (tr_in, va_in) in enumerate(rs.split(tr_idx)):
                X_tr_in, X_va_in = X.iloc[tr_in][features], X.iloc[va_in][features]
                y_tr_in, y_va_in = y.iloc[tr_in], y.iloc[va_in]
                # valid から外部データ除外
                cond_valid = df_train.iloc[va_in][f"org_{target_col}"].notnull()
                X_va_in = X_va_in[cond_valid]
                y_va_in = y_va_in[cond_valid]
                
                dtrain_in = lgb.Dataset(X_tr_in, label=y_tr_in)
                dvalid_in = lgb.Dataset(X_va_in, label=y_va_in)
                model = lgb.train(
                    params,
                    dtrain_in,
                    valid_sets=[dtrain_in, dvalid_in],
                    callbacks=[
                        lgb.early_stopping(stopping_rounds=50),
                        lgb.log_evaluation(200)
                    ]
                )
                rank = model.feature_importance("gain").argsort()[::-1]
                topk = set(rank[:int(0.3 * len(rank))])
                hits[list(topk)] += 1
            keep = hits >= 2
            use_features = features[keep]
        else:
            use_features = features
        print(len(use_features))        

        # 特徴量選択して valid データとともに学習
        X_train, X_val = X.iloc[tr_idx][use_features], X.iloc[val_idx][use_features]
        y_train, y_val = y.iloc[tr_idx], y.iloc[val_idx]

        if config["augumented_gmm"]:
            X_train, y_train = add_augumented_gmm(X_train, y_train)    
        
        dtrain = lgb.Dataset(X_train, label=y_train)
        dval = lgb.Dataset(X_val, label=y_val, reference=dtrain)

        model = lgb.train(
            params,
            dtrain,
            valid_sets=[dtrain, dval],
            callbacks=[
                lgb.early_stopping(stopping_rounds=50),
                lgb.log_evaluation(200)
            ]
        )

        save_lgb_model(model, str(model_output_path / f"model_{target_col}_{fold}.txt"))

        pred = model.predict(X_val, num_iteration=model.best_iteration)
        oof[val_idx] = pred

        mse = mean_squared_error(y_val, pred)
        mae = mean_absolute_error(y_val, pred)
        print(f"fold: {fold}, target: {target_col}, mae: {mae}")
        # loss_table["fold"] = fold
        # loss_table["target"] = target_col
        # loss_table["mae"] = mae
        # loss_table["mse"] = mse

        # loss_tables.append(loss_table)
        models.append(model)

    # 評価に使うのは元データのみ
    cond = (~np.isnan(oof)) & (df_train[f"org_{target_col}"].notnull())
    y_true = y[cond]
    y_pred = oof[cond]
    score_mse = mean_squared_error(y_true, y_pred)
    score_mae = mean_absolute_error(y_true, y_pred)
    print(f"RMSE for {target_col}: {score_mse:.4f}")
    print(f"MAE for {target_col}: {score_mae:.4f}")
    mae_dict[target_col] = score_mae

    # for loss_table in loss_tables:
    #     loss_table_wandb.add_data(exp, model_name, loss_table["fold"], loss_table["target"], loss_table["mae"], loss_table["mse"])
    # all_loss_tables += loss_tables

    oof_df = pd.DataFrame({
        "id": df_train["id"].values,
        target_col: oof
    })
    oof_dfs.append(oof_df)   

    all_models[target_col] = models


wandb_name = f"{exp}_{model_name}" if not config["debug"] else f"{exp}_{model_name}_debug"
wandb.init(project="opp2025", name=wandb_name, config=config)
wandb.log({"Notes": notes})


# wandb.log({"fold_target_losses": loss_table_wandb})
# target 毎の 平均 mae を記録
for target in targets:
    key_name = f"{target}_mean_mae"
    mae_values = mae_dict[target]
    # mae_values = [d["mae"] for d in all_loss_tables if d["target"] == target]
    wandb.log({key_name: np.mean(mae_values)})

# CV 計算
cond = ~train["is_external"]
oof_df = pd.DataFrame()

# 元の目的変数も入れておく
for target in targets:
    oof_df[f"org_{target}"] = train.loc[cond, f"org_{target}"]

oof_df["id"] = train.loc[cond, "id"]

# 正規化前の SMILES
oof_df["SMILES"] = train.loc[cond, "org_SMILES"]

for i_oof in oof_dfs:
    oof_df = oof_df.merge(i_oof, on="id", how="left")

# # 予測しなかった部分は null にしておく
# for target in targets:
#     oof_df.loc[oof_df[target] == 0, target] = np.nan

oof_df.to_csv(output_path / "oof.csv", index=False)

solution = train.loc[cond, ["id"] + org_target_cols].copy()
solution.columns = ["id"] + targets

# solution = solution.fillna(NULL_FOR_SUBMISSION)

# oof_df = oof_df.fillna(NULL_FOR_SUBMISSION)

# 評価
final_score = score(
    solution=solution,
    submission=oof_df,
)
print(f"\n📊 Final OOF Score (wMAE): {final_score:.6f}")
wandb.log({"wMAE": final_score})

# target 毎の best_iteration を保存する。保存したモデルには記録されてなかった
best_iterations = {}
for target in targets:
    target_best_iterations = [model.best_iteration for model in all_models[target]]
    best_iterations[target] = target_best_iterations
print(best_iterations)

with open(output_path / "best_iterations.json", "w") as f:
    json.dump(best_iterations, f)
# Out:
# *=C=C=C(COS(=O)(=O)c1ccc(OC)cc1)C(=*)COS(=O)(=O)c1ccc(OC)cc1: Explicit valence for atom # 0 H, 2, is greater than permitted
# cnt error extract main chain: 0
# Generating maccs:   0%|          | 0/150 [00:00<?, ?it/s]
# Generating descriptors:   0%|          | 0/150 [00:00<?, ?it/s]
# mordred desc:   0%|          | 0/150 [00:00<?, ?it/s]
# (150, 3039)
# Generating maccs:   0%|          | 0/148 [00:00<?, ?it/s]
# Generating descriptors:   0%|          | 0/148 [00:00<?, ?it/s]
# mordred desc:   0%|          | 0/148 [00:00<?, ?it/s]
# (150, 6062)
# Unique=1 col: ['maccs_maccs_0', 'maccs_maccs_1', 'maccs_maccs_2', 'maccs_maccs_3', 'maccs_maccs_4', 'maccs_maccs_5', 'maccs_maccs_6', 'maccs_maccs_7', 'maccs_maccs_8', 'maccs_maccs_9', 'maccs_maccs_10', 'maccs_maccs_11', 'maccs_maccs_12', 'maccs_maccs_13', 'maccs_maccs_15', 'maccs_maccs_16', 'maccs_maccs_18', 'maccs_maccs_19', 'maccs_maccs_20', 'maccs_maccs_22', 'maccs_maccs_25', 'maccs_maccs_26', 'maccs_maccs_27', 'maccs_maccs_28', 'maccs_maccs_30', 'maccs_maccs_31', 'maccs_maccs_34', 'maccs_maccs_35', 'maccs_maccs_44', 'maccs_maccs_68', 'maccs_maccs_166', 'desc_NumRadicalElectrons', 'desc_PEOE_VSA11', 'desc_PEOE_VSA4', 'desc_PEOE_VSA5', 'desc_SMR_VSA8', 'desc_SlogP_VSA9', 'desc_fr_Al_OH', 'desc_fr_Al_OH_noTert', 'desc_fr_C_S', 'desc_fr_HOCCN', 'desc_fr_N_O', 'desc_fr_Ndealkylation1', 'desc_fr_Ndealkylation2', 'desc_fr_SH', 'desc_fr_aldehyde', 'desc_fr_amidine', 'desc_fr_azide', 'desc_fr_azo', 'desc_fr_barbitur', 'desc_fr_benzodiazepine', 'desc_fr_diazo', 'desc_fr_dihydropyridine', 'desc_fr_epoxide', 'desc_fr_guanido', 'desc_fr_hdrzine', 'desc_fr_hdrzone', 'desc_fr_imidazole', 'desc_fr_isocyan', 'desc_fr_isothiocyan', 'desc_fr_lactam', 'desc_fr_lactone', 'desc_fr_morpholine', 'desc_fr_nitroso', 'desc_fr_oxazole', 'desc_fr_oxime', 'desc_fr_phos_acid', 'desc_fr_phos_ester', 'desc_fr_piperzine', 'desc_fr_priamide', 'desc_fr_prisulfonamd', 'desc_fr_quatN', 'desc_fr_sulfonamd', 'desc_fr_term_acetylene', 'desc_fr_tetrazole', 'desc_fr_thiocyan', 'desc_mfp_vec6', 'desc_mfp_vec12', 'desc_mfp_vec16', 'desc_mfp_vec17', 'desc_mfp_vec18', 'desc_mfp_vec22', 'desc_mfp_vec27', 'desc_mfp_vec30', 'desc_mfp_vec31', 'desc_mfp_vec32', 'desc_mfp_vec35', 'desc_mfp_vec38', 'desc_mfp_vec40', 'desc_mfp_vec43', 'desc_mfp_vec46', 'desc_mfp_vec51', 'desc_mfp_vec55', 'desc_mfp_vec57', 'desc_mfp_vec61', 'desc_mfp_vec63', 'desc_mfp_vec68', 'desc_mfp_vec69', 'desc_mfp_vec74', 'desc_mfp_vec76', 'desc_mfp_vec77', 'desc_mfp_vec78', 'desc_mfp_vec81', 'desc_mfp_vec82', 'desc_mfp_vec84', 'desc_mfp_vec85', 'desc_mfp_vec86', 'desc_mfp_vec88', 'desc_mfp_vec89', 'desc_mfp_vec92', 'desc_mfp_vec96', 'desc_mfp_vec99', 'desc_mfp_vec101', 'desc_mfp_vec106', 'desc_mfp_vec107', 'desc_mfp_vec109', 'desc_mfp_vec110', 'desc_mfp_vec113', 'desc_mfp_vec115', 'desc_mfp_vec120', 'desc_mfp_vec122', 'desc_mfp_vec124', 'desc_mfp_vec125', 'desc_mfp_vec126', 'desc_mfp_vec127', 'desc_mfp_vec130', 'desc_mfp_vec132', 'desc_mfp_vec133', 'desc_mfp_vec134', 'desc_mfp_vec135', 'desc_mfp_vec143', 'desc_mfp_vec148', 'desc_mfp_vec154', 'desc_mfp_vec155', 'desc_mfp_vec156', 'desc_mfp_vec159', 'desc_mfp_vec164', 'desc_mfp_vec168', 'desc_mfp_vec169', 'desc_mfp_vec174', 'desc_mfp_vec178', 'desc_mfp_vec179', 'desc_mfp_vec181', 'desc_mfp_vec182', 'desc_mfp_vec183', 'desc_mfp_vec184', 'desc_mfp_vec185', 'desc_mfp_vec189', 'desc_mfp_vec192', 'desc_mfp_vec195', 'desc_mfp_vec196', 'desc_mfp_vec199', 'desc_mfp_vec201', 'desc_mfp_vec204', 'desc_mfp_vec208', 'desc_mfp_vec209', 'desc_mfp_vec211', 'desc_mfp_vec213', 'desc_mfp_vec217', 'desc_mfp_vec218', 'desc_mfp_vec223', 'desc_mfp_vec226', 'desc_mfp_vec227', 'desc_mfp_vec229', 'desc_mfp_vec238', 'desc_mfp_vec245', 'desc_mfp_vec254', 'desc_mfp_vec257', 'desc_mfp_vec258', 'desc_mfp_vec260', 'desc_mfp_vec261', 'desc_mfp_vec263', 'desc_mfp_vec267', 'desc_mfp_vec269', 'desc_mfp_vec274', 'desc_mfp_vec276', 'desc_mfp_vec277', 'desc_mfp_vec280', 'desc_mfp_vec286', 'desc_mfp_vec288', 'desc_mfp_vec296', 'desc_mfp_vec299', 'desc_mfp_vec302', 'desc_mfp_vec303', 'desc_mfp_vec305', 'desc_mfp_vec306', 'desc_mfp_vec309', 'desc_mfp_vec312', 'desc_mfp_vec316', 'desc_mfp_vec317', 'desc_mfp_vec318', 'desc_mfp_vec321', 'desc_mfp_vec324', 'desc_mfp_vec327', 'desc_mfp_vec331', 'desc_mfp_vec335', 'desc_mfp_vec336', 'desc_mfp_vec337', 'desc_mfp_vec347', 'desc_mfp_vec348', 'desc_mfp_vec349', 'desc_mfp_vec351', 'desc_mfp_vec355', 'desc_mfp_vec359', 'desc_mfp_vec363', 'desc_mfp_vec365', 'desc_mfp_vec368', 'desc_mfp_vec369', 'desc_mfp_vec372', 'desc_mfp_vec373', 'desc_mfp_vec374', 'desc_mf ...
# Highly correlated cols:  ['maccs_maccs_33', 'maccs_maccs_40', 'maccs_maccs_43', 'maccs_maccs_48', 'maccs_maccs_49', 'maccs_maccs_53', 'maccs_maccs_55', 'maccs_maccs_56', 'maccs_maccs_60', 'maccs_maccs_61', 'maccs_maccs_63', 'maccs_maccs_67', 'maccs_maccs_70', 'maccs_maccs_71', 'maccs_maccs_73', 'maccs_maccs_84', 'maccs_maccs_105', 'maccs_maccs_117', 'maccs_maccs_134', 'maccs_maccs_135', 'maccs_maccs_143', 'maccs_maccs_147', 'desc_MaxAbsEStateIndex', 'desc_HeavyAtomMolWt', 'desc_ExactMolWt', 'desc_NumValenceElectrons', 'desc_FpDensityMorgan2', 'desc_FpDensityMorgan3', 'desc_Chi0', 'desc_Chi0n', 'desc_Chi0v', 'desc_Chi1', 'desc_Chi1n', 'desc_Chi1v', 'desc_Chi2n', 'desc_Chi2v', 'desc_Chi3n', 'desc_Chi3v', 'desc_Chi4n', 'desc_Chi4v', 'desc_HallKierAlpha', 'desc_Kappa1', 'desc_LabuteASA', 'desc_SMR_VSA2', 'desc_SlogP_VSA6', 'desc_EState_VSA11', 'desc_VSA_EState6', 'desc_HeavyAtomCount', 'desc_NOCount', 'desc_NumAromaticCarbocycles', 'desc_NumAromaticRings', 'desc_NumHDonors', 'desc_NumRotatableBonds', 'desc_RingCount', 'desc_MolMR', 'desc_fr_ArN', 'desc_fr_COO', 'desc_fr_COO2', 'desc_fr_C_O_noCOO', 'desc_fr_Imine', 'desc_fr_NH2', 'desc_fr_Nhpyrrole', 'desc_fr_alkyl_halide', 'desc_fr_benzene', 'desc_fr_furan', 'desc_fr_ketone_Topliss', 'desc_fr_nitrile', 'desc_fr_nitro', 'desc_fr_nitro_arom', 'desc_fr_nitro_arom_nonortho', 'desc_fr_phenol', 'desc_fr_phenol_noOrthoHbond', 'desc_fr_piperdine', 'desc_fr_pyridine', 'desc_fr_urea', 'desc_mfp_vec33', 'desc_mfp_vec44', 'desc_mfp_vec45', 'desc_mfp_vec52', 'desc_mfp_vec62', 'desc_mfp_vec67', 'desc_mfp_vec80', 'desc_mfp_vec91', 'desc_mfp_vec97', 'desc_mfp_vec104', 'desc_mfp_vec105', 'desc_mfp_vec111', 'desc_mfp_vec112', 'desc_mfp_vec128', 'desc_mfp_vec129', 'desc_mfp_vec131', 'desc_mfp_vec137', 'desc_mfp_vec140', 'desc_mfp_vec141', 'desc_mfp_vec144', 'desc_mfp_vec153', 'desc_mfp_vec163', 'desc_mfp_vec165', 'desc_mfp_vec171', 'desc_mfp_vec177', 'desc_mfp_vec188', 'desc_mfp_vec197', 'desc_mfp_vec198', 'desc_mfp_vec202', 'desc_mfp_vec206', 'desc_mfp_vec207', 'desc_mfp_vec215', 'desc_mfp_vec216', 'desc_mfp_vec224', 'desc_mfp_vec234', 'desc_mfp_vec239', 'desc_mfp_vec241', 'desc_mfp_vec248', 'desc_mfp_vec256', 'desc_mfp_vec265', 'desc_mfp_vec271', 'desc_mfp_vec273', 'desc_mfp_vec281', 'desc_mfp_vec284', 'desc_mfp_vec289', 'desc_mfp_vec290', 'desc_mfp_vec293', 'desc_mfp_vec294', 'desc_mfp_vec297', 'desc_mfp_vec298', 'desc_mfp_vec304', 'desc_mfp_vec313', 'desc_mfp_vec320', 'desc_mfp_vec329', 'desc_mfp_vec334', 'desc_mfp_vec338', 'desc_mfp_vec339', 'desc_mfp_vec343', 'desc_mfp_vec345', 'desc_mfp_vec350', 'desc_mfp_vec353', 'desc_mfp_vec354', 'desc_mfp_vec356', 'desc_mfp_vec357', 'desc_mfp_vec364', 'desc_mfp_vec370', 'desc_mfp_vec371', 'desc_mfp_vec376', 'desc_mfp_vec379', 'desc_mfp_vec382', 'desc_mfp_vec383', 'desc_mfp_vec384', 'desc_mfp_vec387', 'desc_mfp_vec391', 'desc_mfp_vec396', 'desc_mfp_vec398', 'desc_mfp_vec401', 'desc_mfp_vec407', 'desc_mfp_vec408', 'desc_mfp_vec409', 'desc_mfp_vec418', 'desc_mfp_vec429', 'desc_mfp_vec430', 'desc_mfp_vec436', 'desc_mfp_vec446', 'desc_mfp_vec462', 'desc_mfp_vec466', 'desc_mfp_vec472', 'desc_mfp_vec473', 'desc_mfp_vec485', 'desc_mfp_vec487', 'desc_mfp_vec493', 'desc_mfp_vec496', 'desc_mfp_vec501', 'desc_mfp_vec504', 'desc_mfp_vec505', 'desc_mfp_vec512', 'desc_mfp_vec525', 'desc_mfp_vec527', 'desc_mfp_vec528', 'desc_mfp_vec536', 'desc_mfp_vec537', 'desc_mfp_vec544', 'desc_mfp_vec547', 'desc_mfp_vec548', 'desc_mfp_vec551', 'desc_mfp_vec555', 'desc_mfp_vec557', 'desc_mfp_vec559', 'desc_mfp_vec561', 'desc_mfp_vec564', 'desc_mfp_vec567', 'desc_mfp_vec573', 'desc_mfp_vec580', 'desc_mfp_vec582', 'desc_mfp_vec583', 'desc_mfp_vec596', 'desc_mfp_vec607', 'desc_mfp_vec610', 'desc_mfp_vec612', 'desc_mfp_vec614', 'desc_mfp_vec621', 'desc_mfp_vec622', 'desc_mfp_vec627', 'desc_mfp_vec630', 'desc_mfp_vec632', 'desc_mfp_vec633', 'desc_mfp_vec634', 'desc_mfp_vec635', 'desc_mfp_vec636', 'desc_mfp_vec637', 'desc_mfp_vec639', 'desc_mfp_vec651', 'desc_mfp_vec654', 'desc_mfp_vec656', ...
# Saved train.csv
# bit cols:  484
# remove cols:  47
# 1485
#
# === Training for target: Tg ===
# train rows: 24, valid rows: 12, ignore rows: 0
# fold: 1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 61.2778	valid_1's l1: 103.248
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 71.4382	valid_1's l1: 58.7813
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 69.4325	valid_1's l1: 54.2674
# 445
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's l1: 58.6156	valid_1's l1: 78.1866
# fold: 0, target: Tg, mae: 78.18658459035983
# train rows: 22, valid rows: 14, ignore rows: 0
# fold: 2
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 62.7842	valid_1's l1: 112.407
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 68.0968	valid_1's l1: 94.3228
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 77.4697	valid_1's l1: 37.4573
# 445
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 61.2243	valid_1's l1: 52.6844
# fold: 1, target: Tg, mae: 52.684411823357145
# RMSE for Tg: 6216.3306
# MAE for Tg: 64.4546
#
# === Training for target: FFV ===
# train rows: 45, valid rows: 25, ignore rows: 0
# fold: 1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [104]
# [16400]	training's l1: 0.000391542	valid_1's l1: 0.00589188
# [16600]	training's l1: 0.000383385	valid_1's l1: 0.00587363
# [16800]	training's l1: 0.000374838	valid_1's l1: 0.00585516
# [17000]	training's l1: 0.000366544	valid_1's l1: 0.0058386
# [17200]	training's l1: 0.000358354	valid_1's l1: 0.005823
# [17400]	training's l1: 0.000350298	valid_1's l1: 0.00580734
# [17600]	training's l1: 0.000342154	valid_1's l1: 0.00579267
# [17800]	training's l1: 0.000334603	valid_1's l1: 0.00577908
# [18000]	training's l1: 0.000327341	valid_1's l1: 0.00576447
# [18200]	training's l1: 0.000319944	valid_1's l1: 0.00574982
# [18400]	training's l1: 0.000312784	valid_1's l1: 0.00573642
# [18600]	training's l1: 0.000305939	valid_1's l1: 0.00572243
# [18800]	training's l1: 0.000299118	valid_1's l1: 0.00570928
# [19000]	training's l1: 0.00029243	valid_1's l1: 0.00569504
# [19200]	training's l1: 0.000285955	valid_1's l1: 0.005683
# [19400]	training's l1: 0.000279667	valid_1's l1: 0.00567039
# [19600]	training's l1: 0.00027354	valid_1's l1: 0.00565727
# [19800]	training's l1: 0.000267707	valid_1's l1: 0.00564431
# [20000]	training's l1: 0.000262042	valid_1's l1: 0.00563324
# Did not meet early stopping. Best iteration is:
# [19997]	training's l1: 0.000262051	valid_1's l1: 0.00563301
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0128265	valid_1's l1: 0.0195509
# [400]	training's l1: 0.00991791	valid_1's l1: 0.016906
# [600]	training's l1: 0.0082494	valid_1's l1: 0.0156034
# [800]	training's l1: 0.00715283	valid_1's l1: 0.0148843
# [1000]	training's l1: 0.00637946	valid_1's l1: 0.0138929
# [1200]	training's l1: 0.00576782	valid_1's l1: 0.0130638
# [1400]	training's l1: 0.00529314	valid_1's l1: 0.0124275
# [1600]	training's l1: 0.00488237	valid_1's l1: 0.0120552
# [1800]	training's l1: 0.00451816	valid_1's l1: 0.011728
# [2000]	training's l1: 0.00418048	valid_1's l1: 0.0115571
# [2200]	training's l1: 0.00387873	valid_1's l1: 0.0113871
# Early stopping, best iteration is:
# [2246]	training's l1: 0.00381579	valid_1's l1: 0.0113561
# 425
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 0.0185178	valid_1's l1: 0.0249663
# fold: 1, target: FFV, mae: 0.024966275663230886
# RMSE for FFV: 0.0008
# MAE for FFV: 0.0235
#
# === Training for target: Tc ===
# train rows: 42, valid rows: 41, ignore rows: 0
# fold: 1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 0.0814775	valid_1's l1: 0.0553133
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 0.0825836	valid_1's l1: 0.0668514
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 0.0632146	valid_1's l1: 0.155553
# 445
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0468543	valid_1's l1: 0.0741178
# Early stopping, best iteration is:
# [180]	training's l1: 0.04862	valid_1's l1: 0.0738681
# fold: 0, target: Tc, mae: 0.0738681419939852
# train rows: 61, valid rows: 22, ignore rows: 0
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.039659	valid_1's l1: 0.0836045
# [400]	training's l1: 0.0281382	valid_1's l1: 0.060381
# [600]	training's l1: 0.0216213	valid_1's l1: 0.0464813
# [800]	training's l1: 0.0176394	valid_1's l1: 0.0378655
# [1000]	training's l1: 0.015273	valid_1's l1: 0.0317855
# [1200]	training's l1: 0.0134129	valid_1's l1: 0.027354
# [1400]	training's l1: 0.0120586	valid_1's l1: 0.0239656
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0324713	valid_1's l1: 0.0681466
# [400]	training's l1: 0.0212375	valid_1's l1: 0.0647991
# Early stopping, best iteration is:
# [404]	training's l1: 0.0211148	valid_1's l1: 0.0646366
# fold: 1, target: Tc, mae: 0.06463663323955693
# RMSE for Tc: 0.0077
# MAE for Tc: 0.0706
#
# === Training for target: Density ===
# train rows: 42, valid rows: 37, ignore rows: 0
# fold: 1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 0.102188	valid_1's l1: 0.146789
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 0.107127	valid_1's l1: 0.0949722
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 0.114829	valid_1's l1: 0.051313
# 445
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0339501	valid_1's l1: 0.0778594
# [400]	training's l1: 0.0225851	valid_1's l1: 0.0634559
# [600]	training's l1: 0.0154753	valid_1's l1: 0.0570949
# [800]	training's l1: 0.0115607	valid_1's l1: 0.0525796
# [1000]	training's l1: 0.00888846	valid_1's l1: 0.0509846
# Early stopping, best iteration is:
# [961]	training's l1: 0.00931558	valid_1's l1: 0.0509236
# fold: 0, target: Density, mae: 0.05092358645362159
# train rows: 58, valid rows: 21, ignore rows: 0
# fold: 2
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [118]	training's l1: 0.0545878	valid_1's l1: 0.0319312
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0376244	valid_1's l1: 0.0997069
# [400]	training's l1: 0.0247014	valid_1's l1: 0.0757362
# [600]	training's l1: 0.0192125	valid_1's l1: 0.0604641
# [800]	training's l1: 0.0156308	valid_1's l1: 0.0494844
# [1000]	training's l1: 0.0130673	valid_1's l1: 0.0393959
# [1200]	training's l1: 0.0111687	valid_1's l1: 0.0320407
# [1400]	training's l1: 0.00977602	valid_1's l1: 0.0294545
# [1600]	training's l1: 0.00868521	valid_1's l1: 0.0270055
# [1800]	training's l1: 0.00781545	valid_1's l1: 0.0251087
# [2000]	training's l1: 0.00705184	valid_1's l1: 0.0233845
# [2200]	training's l1: 0.00636721	valid_1's l1: 0.0217665
# [2400]	training's l1: 0.00574336	valid_1's l1: 0.020394
# [2600]	training's l1: 0.00519776	valid_1's l1: 0.0191661
# [2800]	training's l1: 0.00473404	valid_1's l1: 0.0180833
# [3000]	training's l1: 0.00432542	valid_1's l1: 0.0170512
# [3200]	training's l1: 0.00396591	valid_1's l1: 0.0159999
# [3400]	training's l1: 0.0036629	valid_1's l1: 0.015259
# [3600]	training's l1: 0.00340322	valid_1's l1: 0.0147777
# [3800]	training's l1: 0.00315796	valid_1's l1: 0.0143123
# [4000]	training's l1: 0.00292043	valid_1's l1: 0.0139055
# [4200]	training's l1: 0.00270585	valid_1's l1: 0.0135018
# [4400]	training's l1: 0.00250843	valid_1's l1: 0.0131517
# [4600]	training's l1: 0.00233227	valid_1's l1: 0.0127793
# [4800]	training's l1: 0.00218084	valid_1's l1: 0.012353
# [5000]	training's l1: 0.00204748	valid_1's l1: 0.0119354
# [5200]	training's l1: 0.00192665	valid_1's l1: 0.0115614
# [5400]	training's l1: 0.00181102	valid_1's l1: 0.0112006
# [5600]	training's l1: 0.00171113	valid_1's l1: 0.0108623
# [5800]	training's l1: 0.00161999	valid_1's l1: 0.0105525
# [6000]	training's l1: 0.00153674	valid_1's l1: 0.0102513
# [6200]	training's l1: 0.0014593	valid_1's l1: 0.00996893
# [6400]	training's l1: 0.0013856	valid_1's l1: 0.00974577
# [6600]	training's l1: 0.00131813	valid_1's l1: 0.00955638
# [6800]	training's l1: 0.00125587	valid_1's l1: 0.0093708
# [7000]	training's l1: 0.00119787	valid_1's l1: 0.00922193
# [16800]	training's l1: 0.000394939	valid_1's l1: 0.00690501
# [17000]	training's l1: 0.000391091	valid_1's l1: 0.00689656
# [17200]	training's l1: 0.000387226	valid_1's l1: 0.00688786
# [17400]	training's l1: 0.000383379	valid_1's l1: 0.00687882
# [17600]	training's l1: 0.000379485	valid_1's l1: 0.00686931
# [17800]	training's l1: 0.000375795	valid_1's l1: 0.00686202
# [18000]	training's l1: 0.000372064	valid_1's l1: 0.00685569
# [18200]	training's l1: 0.00036884	valid_1's l1: 0.00684943
# [18400]	training's l1: 0.000366182	valid_1's l1: 0.00684334
# [18600]	training's l1: 0.00036355	valid_1's l1: 0.0068364
# [18800]	training's l1: 0.000360872	valid_1's l1: 0.00682954
# [19000]	training's l1: 0.000358168	valid_1's l1: 0.00682344
# [19200]	training's l1: 0.000355481	valid_1's l1: 0.00681818
# [19400]	training's l1: 0.000352934	valid_1's l1: 0.00681146
# [19600]	training's l1: 0.000350342	valid_1's l1: 0.00680535
# [19800]	training's l1: 0.000347797	valid_1's l1: 0.0067994
# [20000]	training's l1: 0.00034535	valid_1's l1: 0.00679361
# Did not meet early stopping. Best iteration is:
# [19999]	training's l1: 0.000345356	valid_1's l1: 0.00679361
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0378803	valid_1's l1: 0.0177332
# [400]	training's l1: 0.0217572	valid_1's l1: 0.0111726
# Early stopping, best iteration is:
# [371]	training's l1: 0.0231887	valid_1's l1: 0.0108444
# 441
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.03352	valid_1's l1: 0.0839948
# [400]	training's l1: 0.0205784	valid_1's l1: 0.0778567
# Early stopping, best iteration is:
# [371]	training's l1: 0.0214744	valid_1's l1: 0.0772828
# fold: 1, target: Density, mae: 0.07728282476050684
# RMSE for Density: 0.0068
# MAE for Density: 0.0605
#
# === Training for target: Rg ===
# train rows: 42, valid rows: 39, ignore rows: 0
# fold: 1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 5.68551	valid_1's l1: 4.70822
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 5.60044	valid_1's l1: 4.95314
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 5.10687	valid_1's l1: 7.54366
# 445
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 5.11196	valid_1's l1: 4.99222
# fold: 0, target: Rg, mae: 4.992217585003634
# train rows: 60, valid rows: 21, ignore rows: 0
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 2.23237	valid_1's l1: 2.51084
# [400]	training's l1: 1.6045	valid_1's l1: 2.37566
# [600]	training's l1: 1.25816	valid_1's l1: 2.18124
# [800]	training's l1: 1.01439	valid_1's l1: 1.99774
# [1000]	training's l1: 0.850128	valid_1's l1: 1.92761
# [1200]	training's l1: 0.722006	valid_1's l1: 1.88277
# [1400]	training's l1: 0.61768	valid_1's l1: 1.85005
# [1600]	training's l1: 0.532661	valid_1's l1: 1.80523
# [1800]	training's l1: 0.464544	valid_1's l1: 1.74671
# [2000]	training's l1: 0.406006	valid_1's l1: 1.69738
# [2200]	training's l1: 0.356038	valid_1's l1: 1.6645
# [2400]	training's l1: 0.312152	valid_1's l1: 1.63604
# [2600]	training's l1: 0.273485	valid_1's l1: 1.60641
# [2800]	training's l1: 0.240588	valid_1's l1: 1.577
# [3000]	training's l1: 0.214661	valid_1's l1: 1.53989
# [3200]	training's l1: 0.193024	valid_1's l1: 1.50497
# [3400]	training's l1: 0.174176	valid_1's l1: 1.47303
# [3600]	training's l1: 0.157571	valid_1's l1: 1.44489
# [3800]	training's l1: 0.143555	valid_1's l1: 1.41487
# [4000]	training's l1: 0.131681	valid_1's l1: 1.38731
# [4200]	training's l1: 0.121143	valid_1's l1: 1.35998
# [4400]	training's l1: 0.111414	valid_1's l1: 1.33722
# [4600]	training's l1: 0.102802	valid_1's l1: 1.31534
# [4800]	training's l1: 0.0950451	valid_1's l1: 1.29641
# [5000]	training's l1: 0.0878615	valid_1's l1: 1.28094
# [5200]	training's l1: 0.081598	valid_1's l1: 1.26615
# [5400]	training's l1: 0.0758312	valid_1's l1: 1.25155
# [5600]	training's l1: 0.07064	valid_1's l1: 1.23691
# [5800]	training's l1: 0.0658219	valid_1's l1: 1.22347
# [6000]	training's l1: 0.0615272	valid_1's l1: 1.21115
# [6200]	training's l1: 0.0577739	valid_1's l1: 1.19964
# [6400]	training's l1: 0.0542386	valid_1's l1: 1.18942
# [6600]	training's l1: 0.0510054	valid_1's l1: 1.18013
# [6800]	training's l1: 0.048131	valid_1's l1: 1.17111
# [7000]	training's l1: 0.0454217	valid_1's l1: 1.16256
# [7200]	training's l1: 0.0429569	valid_1's l1: 1.15444
# [7400]	training's l1: 0.0406996	valid_1's l1: 1.14665
# [7600]	training's l1: 0.0386557	valid_1's l1: 1.13943
# [7800]	training's l1: 0.036672	valid_1's l1: 1.13301
# [8000]	training's l1: 0.0347959	valid_1's l1: 1.12685
# [8200]	training's l1: 0.0330596	valid_1's l1: 1.12139
# [8400]	training's l1: 0.0314036	valid_1's l1: 1.11668
# [8600]	training's l1: 0.0297975	valid_1's l1: 1.11227
# [8800]	training's l1: 0.0283353	valid_1's l1: 1.10801
# [9000]	training's l1: 0.0269872	valid_1's l1: 1.10372
# [9200]	training's l1: 0.0256969	valid_1's l1: 1.09964
# [9400]	training's l1: 0.0244864	valid_1's l1: 1.09587
# [9600]	training's l1: 0.0233685	valid_1's l1: 1.09224
# [9800]	training's l1: 0.0223017	valid_1's l1: 1.08883
# [10000]	training's l1: 0.0213086	valid_1's l1: 1.08561
# [10200]	training's l1: 0.0203234	valid_1's l1: 1.08278
# [10400]	training's l1: 0.0194211	valid_1's l1: 1.08014
# [10600]	training's l1: 0.0185452	valid_1's l1: 1.07781
# [10800]	training's l1: 0.0177	valid_1's l1: 1.07569
# [11000]	training's l1: 0.0169427	valid_1's l1: 1.07358
# [11200]	training's l1: 0.0162219	valid_1's l1: 1.07169
# [11400]	training's l1: 0.0155453	valid_1's l1: 1.0701
# [11600]	training's l1: 0.0149006	valid_1's l1: 1.06872
# [11800]	training's l1: 0.0142882	valid_1's l1: 1.06745
# [12000]	training's l1: 0.0137064	valid_1's l1: 1.06618
# [12200]	training's l1: 0.0131758	valid_1's l1: 1.06489
# [12400]	training's l1: 0.0126516	valid_1's l1: 1.06368
# [12600]	training's l1: 0.0121587	valid_1's l1: 1.06254
# [12800]	training's l1: 0.0116992	valid_1's l1: 1.06135
# [13000]	training's l1: 0.0112542	valid_1's l1: 1.06037
# [13200]	training's l1: 0.010818	valid_1's l1: 1.05955
# [13400]	training's l1: 0.0104089	valid_1's l1: 1.0587
# [13600]	training's l1: 0.0100263	valid_1's l1: 1.05782
# [13800]	training's l1: 0.00964521	valid_1's l1: 1.05696
# [14000]	training's l1: 0.00928257	valid_1's l1: 1.05617
# [14200]	training's l1: 0.00893571	valid_1's l1: 1.05549
# [14400]	training's l1: 0.00860006	valid_1's l1: 1.05486
# [14600]	training's l1: 0.0082804	valid_1's l1: 1.05423
# [14800]	training's l1: 0.00797148	valid_1's l1: 1.05359
# [15000]	training's l1: 0.00767565	valid_1's l1: 1.05301
# [15200]	training's l1: 0.0073912	valid_1's l1: 1.05246
# [15400]	training's l1: 0.00712194	valid_1's l1: 1.05192
# [15600]	training's l1: 0.00686372	valid_1's l1: 1.05136
# [15800]	training's l1: 0.00661993	valid_1's l1: 1.05086
# [16000]	training's l1: 0.00638023	valid_1's l1: 1.05033
# [16200]	training's l1: 0.0061509	valid_1's l1: 1.04978
# [16400]	training's l1: 0.00593228	valid_1's l1: 1.04928
# [16600]	training's l1: 0.00571272	valid_1's l1: 1.04878
# [16800]	training's l1: 0.00551017	valid_1's l1: 1.04828
# [17000]	training's l1: 0.00531464	valid_1's l1: 1.04783
# [17200]	training's l1: 0.00512438	valid_1's l1: 1.04738
# [17400]	training's l1: 0.00493813	valid_1's l1: 1.04694
# [17600]	training's l1: 0.00476573	valid_1's l1: 1.04652
# [17800]	training's l1: 0.00460231	valid_1's l1: 1.04607
# [18000]	training's l1: 0.00444654	valid_1's l1: 1.04565
# [18200]	training's l1: 0.0042997	valid_1's l1: 1.04526
# [18400]	training's l1: 0.00415859	valid_1's l1: 1.0449
# [18600]	training's l1: 0.00402782	valid_1's l1: 1.04459
# [18800]	training's l1: 0.00390125	valid_1's l1: 1.0443
# [19000]	training's l1: 0.00378755	valid_1's l1: 1.044
# [19200]	training's l1: 0.00367941	valid_1's l1: 1.0437
# [19400]	training's l1: 0.00357348	valid_1's l1: 1.04343
# [19600]	training's l1: 0.0034701	valid_1's l1: 1.04316
# [19800]	training's l1: 0.00337081	valid_1's l1: 1.04288
# [20000]	training's l1: 0.00327498	valid_1's l1: 1.04261
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.00327498	valid_1's l1: 1.04261
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [137]	training's l1: 2.50774	valid_1's l1: 4.0595
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 2.22176	valid_1's l1: 2.06444
# [400]	training's l1: 1.54737	valid_1's l1: 1.69087
# [600]	training's l1: 1.21006	valid_1's l1: 1.59967
# Early stopping, best iteration is:
# [639]	training's l1: 1.15481	valid_1's l1: 1.59425
# 426
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.99532	valid_1's l1: 2.95861
# Early stopping, best iteration is:
# [318]	training's l1: 1.4229	valid_1's l1: 2.75336
# fold: 1, target: Rg, mae: 2.753363443377316
# RMSE for Rg: 23.1085
# MAE for Rg: 4.2086
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/kouya-takahashi/kaggle/opp2025/notebook/wandb/run-20250902_085540-fue26k8p</code>
# Syncing run <strong><a href='https://wandb.ai/ko_ya346/opp2025/runs/fue26k8p' target="_blank">exp055_lgb_debug</a></strong> to <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">https://wandb.ai/ko_ya346/opp2025</a>
#  View run at <a href='https://wandb.ai/ko_ya346/opp2025/runs/fue26k8p' target="_blank">https://wandb.ai/ko_ya346/opp2025/runs/fue26k8p</a>
# 📊 Final OOF Score (wMAE): 0.103724
# {'Tg': [2, 1], 'FFV': [5, 1], 'Tc': [180, 404], 'Density': [961, 371], 'Rg': [1, 318]}
