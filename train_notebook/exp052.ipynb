# %% [markdown]
# - -> exp051
# - 特徴量絞りこみの事前学習でも外部データ抜く

# %%
# %load_ext autotime
# %load_ext autoreload

# %%
import os

is_kaggle_notebook = os.path.exists("/kaggle/input")

# 必要パッケージをインストール
if is_kaggle_notebook:
    # !pip install /kaggle/input/rdkit-2025-3-3-cp311/rdkit-2025.3.3-cp311-cp311-manylinux_2_28_x86_64.whl
    # !pip install /kaggle/input/torch-geometric-2-6-1/torch_geometric-2.6.1-py3-none-any.whl

# %%
import copy
import json
import os
import sys
import warnings
from pathlib import Path

import wandb

import lightgbm as lgb
import numpy as np
import pandas as pd
import torch
from rdkit import rdBase
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GroupKFold, KFold, ShuffleSplit
from tqdm.auto import tqdm

from sklearn.decomposition import TruncatedSVD
from scipy import sparse

rdBase.DisableLog("rdApp.warning")
warnings.filterwarnings("ignore")

wandb.login()
# Out:
# wandb: Currently logged in as: ko_ya346 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
pr_number = 1
exp = "exp052"
debug = False
ignore_3D = True
ignore_3d_stats = True
select_feature = True
data_exp = "exp051"
notes = "特徴量選択時にも外部データ除外する"

# %%
# %autoreload 2

if is_kaggle_notebook:
    module_path = f"/kaggle/input/myproject-pr-{pr_number:04}"
    # !mkdir src
    # !cp -r $module_path/* src/
    src_path = "./"
else:
    src_path = "../"

sys.path.append(src_path)

from src.data import load_data, add_descriptors, add_descriptors_mordred, add_external_data, make_smile_canonical, add_maccs, add_augumented_gmm, add_graph_features, add_count_atoms
from src.model import train_lgb_for_target, save_lgb_model
from src.utils import NULL_FOR_SUBMISSION, generate_scaffold, score, add_scaffold_kfold, scaffold_cv_split, get_useless_cols
from src.utils.upload_kaggle_dataset import (
    create_kaggle_dataset_metadata,
    upload_kaggle_dataset,
)

# %%
model_name = "lgb"

config = {
    "debug": debug,
    "n_splits": 3,
    "num_epochs": 1000,
    "batch_size": 128,
    "drop_ratio": 0.5,
    "force_update_train": False,
    "augumented_gmm": False,
    "is_complement": True,
    "remove_external_cv": True,
}

dataset_title = f"model-{exp}"
dataset_id = f"koya346/{dataset_title}"

if is_kaggle_notebook:
    config["debug"] = False

if config["debug"]:
    config["n_splits"] = 2
    config["num_epochs"] = 10

targets = ["Tg", "FFV", "Tc", "Density", "Rg"]
org_target_cols = [f"org_{target}" for target in targets]        

# TODO: 学習パラメータ定義
params = {
    "objective": "regression",
    "metric": "mae",
    "verbosity": -1,
    "learning_rate": 0.01,
    "max_depth": 7,
    "seed": 42,
    "subsample": 0.7,
    "colsample_bytree": 0.6,
    "num_boost_round": 20000,
}

config.update(params)
pre_params = copy.deepcopy(params)
pre_params["num_boost_round"] = 300

# %%
wandb_name = f"{exp}_{model_name}" if not config["debug"] else f"{exp}_{model_name}_debug"
wandb.init(project="opp2025", name=wandb_name, config=config)
wandb.log({"Notes": notes})

# ---------------------------
# メイン処理
# ---------------------------
if config["debug"]:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp / "debug"
else:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp

model_output_path = output_path / "model_cv"
if not os.path.exists(model_output_path):
    os.makedirs(model_output_path)

if is_kaggle_notebook:
    # kaggle notebook
    data_dir = Path("/kaggle/input")
else:
    # local
    data_dir = Path("/home/kouya-takahashi/kaggle/opp2025/data/raw")

# 学習データ用意
train_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / data_exp

if os.path.exists(train_path / "train.csv") and not config["force_update_train"]:
    train = pd.read_csv(train_path / "train.csv")
else:
    train, _ = load_data(data_dir)
    # 外部データ判定用に元の目的変数を保持しておく
    # 外部データ判定は scaffold_cv_split 内で行う
    for target in targets:
        train[f"org_{target}"] = train[target]
    

    train["org_SMILES"] = train["SMILES"]
    train["SMILES"] = train["SMILES"].apply(make_smile_canonical)
    if config["debug"]:
        # 各ターゲットが欠損していないデータを30 件ずつ取り出す
        tmp_dfs = []
        for target in targets:
            cond = train[target].notnull()
            tmp_dfs.append(train[cond].iloc[:30])
        train = pd.concat(tmp_dfs).reset_index(drop=True)
    else:
        print(train.shape)
        external_data_dict = [
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset3.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset1.csv",
                "col": "Tc",
                "rename_d": {"TC_mean": "Tc"},
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset4.csv",
                "col": "FFV",
            },
            {
                "ex_path": data_dir / "tg-smiles-pid-polymer-class/TgSS_enriched_cleaned.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_dnst1.xlsx",
                "col": "Density",
                "rename_d": {"density(g/cm3)": "Density"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_tg3.xlsx",
                "col": "Tg",
                "rename_d": {"Tg [K]": "Tg"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/JCIM_sup_bigsmiles.csv",
                "col": "Tg",
                "rename_d": {"Tg (C)": "Tg"}, 
            },
        ]
        for d in external_data_dict:
            print(f"ex_path: {str(d['ex_path'])}")
            train = add_external_data(
                df=train,
                ex_path=d.get("ex_path"),
                col=d.get("col"),
                rename_d=d.get("rename_d"),
                is_complement=config["is_complement"]
            )
            print("after train.shape: ", train.shape)

    train["is_external"] = train["id"].isnull()
    train["id"] = np.arange(len(train))
    
    maccs = add_maccs(train[["id", "SMILES"]]).drop("SMILES", axis=1)
    maccs = maccs.add_prefix("maccs_")
    maccs = maccs.rename(columns={"maccs_id": "id"})
    
    # rdkit の記述子, morgan finger print
    desc = add_descriptors(train[["id", "SMILES"]], radius=2, fp_size=1024).drop("SMILES", axis=1)
    desc = desc.add_prefix("desc_")
    desc = desc.rename(columns={"desc_id": "id"})
    
    desc_mordred = add_descriptors_mordred(train[["id", "SMILES"]], num_confs=10, ignore_3D=ignore_3D, ignore_3d_stats=ignore_3d_stats).drop("SMILES", axis=1)
    desc_mordred = desc_mordred.add_prefix("desc_mordred_")
    desc_mordred = desc_mordred.rename(columns={"desc_mordred_id": "id"})
    
    graph_features = add_graph_features(train[["id", "SMILES"]])
    graph_features = graph_features.add_prefix("graph_features_")
    graph_features = graph_features.rename(columns={"graph_features_id": "id"})
    
    cnt_atoms = add_count_atoms(train[["id", "SMILES"]])
    cnt_atoms = cnt_atoms.add_prefix("cnt_atoms_")
    cnt_atoms = cnt_atoms.rename(columns={"cnt_atoms_id": "id"})
    
    for df in [maccs, desc, desc_mordred, graph_features, cnt_atoms]:
        train = train.merge(df, on="id")

    features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns
    for col in features:
        if train[col].dtype == "object":
            train[col] = pd.to_numeric(train[col], errors="coerce")
    useless_cols = get_useless_cols(train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1))
    
    train = train.drop(useless_cols, axis=1)
    
    os.makedirs(output_path, exist_ok=True)
    train.to_csv(output_path / "train.csv", index=False)
    print("Saved train.csv")

# 不要なビット列を除去
bit_cols = []
remove_cols = []

for col in train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns:
    if len(train[col].unique()) != 2:
        continue
    if np.all(train[col].unique() == np.array([0, 1])):
        bit_cols.append(col)
        p = train[col].mean()
        if p > 0.01 and p < 0.99:
            continue
        remove_cols.append(col)
print("bit cols: ", len(bit_cols))
print("remove cols: ", len(remove_cols))

train = train.drop(remove_cols, axis=1)

# 計算済の fold を突合
folds = pd.read_csv("/home/kouya-takahashi/kaggle/opp2025/data/preprocess/fold/folds.csv")
train = train.merge(folds[["SMILES", "fold"]], how="left", on="SMILES")

features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "fold", "is_external"], axis=1).columns
print(len(features))
oof_dfs = []

loss_table_wandb = wandb.Table(["exp", "model_name", "fold", "target", "mae", "mse"])
all_loss_tables = []
mae_dict = {}
all_models = {}

for idx, target_col in enumerate(targets):
    loss_tables = []
    print(f"\n=== Training for target: {target_col} ===")

    df_train = train[train[target_col].notnull()].reset_index(drop=True)
    X = df_train[features]
    y = df_train[target_col]
    oof = np.full(len(X), np.nan, dtype=float)
    
    models = []

    for fold, tr_idx, val_idx in scaffold_cv_split(df_train, target=target_col, n_splits=config["n_splits"], remove_external=config["remove_external_cv"]):
        if len(tr_idx) == 0 or len(val_idx) == 0:
            print(f"Skip fold... tr_idx: {len(tr_idx)}, val_idx: {len(val_idx)}")
            continue
        loss_table = {}
        print(f"fold: {fold + 1}")

        if select_feature:
            hits = np.zeros(X.shape[1], dtype=int)
    
            rs = ShuffleSplit(n_splits=3, train_size=0.9, random_state=42)
            for idx, (tr_in, va_in) in enumerate(rs.split(tr_idx)):
                X_tr_in, X_va_in = X.iloc[tr_in][features], X.iloc[va_in][features]
                y_tr_in, y_va_in = y.iloc[tr_in], y.iloc[va_in]
                # valid から外部データ除外
                cond_valid = df_train.iloc[va_in][f"org_{target_col}"].notnull()
                X_va_in = X_va_in[cond_valid]
                y_va_in = y_va_in[cond_valid]
                
                dtrain_in = lgb.Dataset(X_tr_in, label=y_tr_in)
                dvalid_in = lgb.Dataset(X_va_in, label=y_va_in)
                model = lgb.train(
                    params,
                    dtrain_in,
                    valid_sets=[dtrain_in, dvalid_in],
                    callbacks=[
                        lgb.early_stopping(stopping_rounds=50),
                        lgb.log_evaluation(200)
                    ]
                )
                rank = model.feature_importance("gain").argsort()[::-1]
                topk = set(rank[:int(0.3 * len(rank))])
                hits[list(topk)] += 1
            keep = hits >= 2
            use_features = features[keep]
        else:
            use_features = features
        print(len(use_features))        

        # 特徴量選択して valid データとともに学習
        X_train, X_val = X.iloc[tr_idx][use_features], X.iloc[val_idx][use_features]
        y_train, y_val = y.iloc[tr_idx], y.iloc[val_idx]

        if config["augumented_gmm"]:
            X_train, y_train = add_augumented_gmm(X_train, y_train)    
        
        dtrain = lgb.Dataset(X_train, label=y_train)
        dval = lgb.Dataset(X_val, label=y_val, reference=dtrain)

        model = lgb.train(
            params,
            dtrain,
            valid_sets=[dtrain, dval],
            callbacks=[
                lgb.early_stopping(stopping_rounds=50),
                lgb.log_evaluation(200)
            ]
        )

        save_lgb_model(model, str(model_output_path / f"model_{target_col}_{fold}.txt"))

        pred = model.predict(X_val, num_iteration=model.best_iteration)
        oof[val_idx] = pred

        mse = mean_squared_error(y_val, pred)
        mae = mean_absolute_error(y_val, pred)
        print(f"fold: {fold}, target: {target_col}, mae: {mae}")
        loss_table["fold"] = fold
        loss_table["target"] = target_col
        loss_table["mae"] = mae
        loss_table["mse"] = mse

        loss_tables.append(loss_table)
        models.append(model)

    # 評価に使うのは元データのみ
    cond = (~np.isnan(oof)) & (df_train[f"org_{target_col}"].notnull())
    y_true = y[cond]
    y_pred = oof[cond]
    score_mse = mean_squared_error(y_true, y_pred)
    score_mae = mean_absolute_error(y_true, y_pred)
    print(f"RMSE for {target_col}: {score_mse:.4f}")
    print(f"MAE for {target_col}: {score_mae:.4f}")
    mae_dict[target_col] = score_mae

    for loss_table in loss_tables:
        loss_table_wandb.add_data(exp, model_name, loss_table["fold"], loss_table["target"], loss_table["mae"], loss_table["mse"])
    all_loss_tables += loss_tables

    oof_df = pd.DataFrame({
        "id": df_train["id"].values,
        target_col: oof
    })
    oof_dfs.append(oof_df)   

    all_models[target_col] = models

wandb.log({"fold_target_losses": loss_table_wandb})
# target 毎の 平均 mae を記録
for target in targets:
    key_name = f"{target}_mean_mae"
    mae_values = mae_dict[target]
    # mae_values = [d["mae"] for d in all_loss_tables if d["target"] == target]
    wandb.log({key_name: np.mean(mae_values)})

# CV 計算
cond = ~train["is_external"]
oof_df = pd.DataFrame()

# 元の目的変数も入れておく
for target in targets:
    oof_df[f"org_{target}"] = train.loc[cond, f"org_{target}"]

oof_df["id"] = train.loc[cond, "id"]

# 正規化前の SMILES
oof_df["SMILES"] = train.loc[cond, "org_SMILES"]

for i_oof in oof_dfs:
    oof_df = oof_df.merge(i_oof, on="id", how="left")

# # 予測しなかった部分は null にしておく
# for target in targets:
#     oof_df.loc[oof_df[target] == 0, target] = np.nan

oof_df.to_csv(output_path / "oof.csv", index=False)

solution = train.loc[cond, ["id"] + org_target_cols].copy()
solution.columns = ["id"] + targets

# solution = solution.fillna(NULL_FOR_SUBMISSION)

# oof_df = oof_df.fillna(NULL_FOR_SUBMISSION)

# 評価
final_score = score(
    solution=solution,
    submission=oof_df,
)
print(f"\n📊 Final OOF Score (wMAE): {final_score:.6f}")
wandb.log({"wMAE": final_score})

# target 毎の best_iteration を保存する。保存したモデルには記録されてなかった
best_iterations = {}
for target in targets:
    target_best_iterations = [model.best_iteration for model in all_models[target]]
    best_iterations[target] = target_best_iterations
print(best_iterations)

with open(output_path / "best_iterations.json", "w") as f:
    json.dump(best_iterations, f)
# Out:
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/kouya-takahashi/kaggle/opp2025/notebook/wandb/run-20250901_151020-rogrcpla</code>
# Syncing run <strong><a href='https://wandb.ai/ko_ya346/opp2025/runs/rogrcpla' target="_blank">exp052_lgb</a></strong> to <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">https://wandb.ai/ko_ya346/opp2025</a>
#  View run at <a href='https://wandb.ai/ko_ya346/opp2025/runs/rogrcpla' target="_blank">https://wandb.ai/ko_ya346/opp2025/runs/rogrcpla</a>
# bit cols:  1138
# remove cols:  500
# 1175
#
# === Training for target: Tg ===
# train rows: 5476, valid rows: 191, ignore rows: 2577
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 31.2308	valid_1's l1: 53.465
# Early stopping, best iteration is:
# [256]	training's l1: 27.4133	valid_1's l1: 53.2308
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 31.6109	valid_1's l1: 47.7078
# [400]	training's l1: 23.0075	valid_1's l1: 44.2375
# Early stopping, best iteration is:
# [492]	training's l1: 21.3846	valid_1's l1: 43.815
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 31.649	valid_1's l1: 50.5238
# [400]	training's l1: 22.9747	valid_1's l1: 46.5593
# [600]	training's l1: 20.0561	valid_1's l1: 46.1765
# Early stopping, best iteration is:
# [641]	training's l1: 19.643	valid_1's l1: 46.1328
# 350
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 32.0224	valid_1's l1: 55.8451
# [400]	training's l1: 23.4895	valid_1's l1: 49.6779
# [600]	training's l1: 20.2242	valid_1's l1: 49.2887
# Early stopping, best iteration is:
# [634]	training's l1: 19.821	valid_1's l1: 49.1987
# fold: 0, target: Tg, mae: 49.1987401725091
# train rows: 5419, valid rows: 195, ignore rows: 2630
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 31.4324	valid_1's l1: 50.3551
# Early stopping, best iteration is:
# [300]	training's l1: 25.608	valid_1's l1: 48.6173
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 31.3751	valid_1's l1: 44.5328
# Early stopping, best iteration is:
# [307]	training's l1: 25.3344	valid_1's l1: 43.377
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 31.4232	valid_1's l1: 58.2616
# [400]	training's l1: 22.7541	valid_1's l1: 54.5357
# [600]	training's l1: 19.9159	valid_1's l1: 53.9452
# [800]	training's l1: 18.2474	valid_1's l1: 53.606
# Early stopping, best iteration is:
# [800]	training's l1: 18.2474	valid_1's l1: 53.606
# 354
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 32.988	valid_1's l1: 51.936
# [400]	training's l1: 23.4924	valid_1's l1: 50.953
# Early stopping, best iteration is:
# [357]	training's l1: 24.665	valid_1's l1: 50.9254
# fold: 1, target: Tg, mae: 50.925356685876
# train rows: 5593, valid rows: 125, ignore rows: 2526
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 31.4583	valid_1's l1: 54.5296
# [400]	training's l1: 22.9468	valid_1's l1: 52.9757
# Early stopping, best iteration is:
# [427]	training's l1: 22.3907	valid_1's l1: 52.9517
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 31.5009	valid_1's l1: 52.7018
# Early stopping, best iteration is:
# [303]	training's l1: 25.7531	valid_1's l1: 49.8504
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 31.6721	valid_1's l1: 39.1013
# [400]	training's l1: 23.1778	valid_1's l1: 38.8868
# Early stopping, best iteration is:
# [373]	training's l1: 23.8272	valid_1's l1: 38.6982
# 347
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 34.1091	valid_1's l1: 53.5535
# [400]	training's l1: 24.5915	valid_1's l1: 49.4115
# [600]	training's l1: 21.2159	valid_1's l1: 48.8526
# [800]	training's l1: 19.0849	valid_1's l1: 48.5815
# Early stopping, best iteration is:
# [857]	training's l1: 18.5807	valid_1's l1: 48.5142
# fold: 2, target: Tg, mae: 48.51423330081462
# RMSE for Tg: 4420.0541
# MAE for Tg: 49.6902
#
# === Training for target: FFV ===
# train rows: 5470, valid rows: 2263, ignore rows: 159
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.00828421	valid_1's l1: 0.00969508
# [400]	training's l1: 0.00572174	valid_1's l1: 0.00771465
# [600]	training's l1: 0.00492112	valid_1's l1: 0.00727453
# [800]	training's l1: 0.00449525	valid_1's l1: 0.00707744
# [1000]	training's l1: 0.00419679	valid_1's l1: 0.00695095
# [1200]	training's l1: 0.00395917	valid_1's l1: 0.00686906
# [1400]	training's l1: 0.00376418	valid_1's l1: 0.00679249
# [1600]	training's l1: 0.00358935	valid_1's l1: 0.00674234
# [1800]	training's l1: 0.00344306	valid_1's l1: 0.00670066
# [2000]	training's l1: 0.00329898	valid_1's l1: 0.00665727
# [2200]	training's l1: 0.00317982	valid_1's l1: 0.00663385
# [2400]	training's l1: 0.00306468	valid_1's l1: 0.00662087
# [2600]	training's l1: 0.00295146	valid_1's l1: 0.00660268
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0212368	valid_1's l1: 0.0288145
# [400]	training's l1: 0.0132967	valid_1's l1: 0.0264578
# Early stopping, best iteration is:
# [378]	training's l1: 0.0137281	valid_1's l1: 0.026388
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0210308	valid_1's l1: 0.0337363
# Early stopping, best iteration is:
# [251]	training's l1: 0.0176249	valid_1's l1: 0.0319758
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0209375	valid_1's l1: 0.0341829
# [400]	training's l1: 0.0130257	valid_1's l1: 0.0320993
# Early stopping, best iteration is:
# [476]	training's l1: 0.011812	valid_1's l1: 0.0318943
# 344
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.026052	valid_1's l1: 0.0328373
# Early stopping, best iteration is:
# [331]	training's l1: 0.0207719	valid_1's l1: 0.0316425
# fold: 0, target: Tc, mae: 0.03164246821384781
# train rows: 640, valid rows: 187, ignore rows: 39
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.020065	valid_1's l1: 0.0305948
# [400]	training's l1: 0.0128928	valid_1's l1: 0.0273074
# Early stopping, best iteration is:
# [507]	training's l1: 0.0116983	valid_1's l1: 0.0271766
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0203368	valid_1's l1: 0.0263031
# [400]	training's l1: 0.0129359	valid_1's l1: 0.0244453
# Early stopping, best iteration is:
# [448]	training's l1: 0.0123144	valid_1's l1: 0.0243516
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0197206	valid_1's l1: 0.0329662
# [400]	training's l1: 0.012474	valid_1's l1: 0.0288263
# [600]	training's l1: 0.0105336	valid_1's l1: 0.0283785
# Early stopping, best iteration is:
# [649]	training's l1: 0.0101622	valid_1's l1: 0.0283402
# 346
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0236705	valid_1's l1: 0.0336279
# [400]	training's l1: 0.017477	valid_1's l1: 0.0313988
# Early stopping, best iteration is:
# [434]	training's l1: 0.0170009	valid_1's l1: 0.0313384
# fold: 1, target: Tc, mae: 0.03133842492894324
# train rows: 700, valid rows: 114, ignore rows: 52
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0200996	valid_1's l1: 0.0250345
# Early stopping, best iteration is:
# [313]	training's l1: 0.0147474	valid_1's l1: 0.0228355
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0198302	valid_1's l1: 0.0251886
# Early stopping, best iteration is:
# [276]	training's l1: 0.015582	valid_1's l1: 0.0245078
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0196787	valid_1's l1: 0.0300881
# Early stopping, best iteration is:
# [273]	training's l1: 0.0156659	valid_1's l1: 0.029018
# 344
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0195729	valid_1's l1: 0.046885
# [400]	training's l1: 0.0127682	valid_1's l1: 0.0444642
# Early stopping, best iteration is:
# [376]	training's l1: 0.0131231	valid_1's l1: 0.0444331
# fold: 2, target: Tc, mae: 0.04443308822803871
# RMSE for Tc: 0.0021
# MAE for Tc: 0.0335
#
# === Training for target: Density ===
# train rows: 639, valid rows: 340, ignore rows: 267
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.025281	valid_1's l1: 0.023874
# [400]	training's l1: 0.0136014	valid_1's l1: 0.0205244
# Early stopping, best iteration is:
# [377]	training's l1: 0.0140141	valid_1's l1: 0.0204386
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.025091	valid_1's l1: 0.0275885
# [400]	training's l1: 0.0133717	valid_1's l1: 0.0223491
# Early stopping, best iteration is:
# [375]	training's l1: 0.0138877	valid_1's l1: 0.0221982
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0254806	valid_1's l1: 0.0255996
# [400]	training's l1: 0.013555	valid_1's l1: 0.022232
# [600]	training's l1: 0.0108706	valid_1's l1: 0.021482
# [800]	training's l1: 0.00898683	valid_1's l1: 0.0209661
# [1000]	training's l1: 0.00770617	valid_1's l1: 0.02065
# [1200]	training's l1: 0.00675065	valid_1's l1: 0.0203155
# [1400]	training's l1: 0.00588022	valid_1's l1: 0.0201552
# Early stopping, best iteration is:
# [1504]	training's l1: 0.00550216	valid_1's l1: 0.0200738
# 336
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0346658	valid_1's l1: 0.0614501
# [400]	training's l1: 0.017265	valid_1's l1: 0.0498375
# Early stopping, best iteration is:
# [487]	training's l1: 0.0156679	valid_1's l1: 0.0495518
# fold: 0, target: Density, mae: 0.049551769326804475
# train rows: 884, valid rows: 155, ignore rows: 207
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0274934	valid_1's l1: 0.0397765
# [400]	training's l1: 0.0162836	valid_1's l1: 0.0340378
# Early stopping, best iteration is:
# [525]	training's l1: 0.0144518	valid_1's l1: 0.0335346
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0277719	valid_1's l1: 0.0291452
# [400]	training's l1: 0.0167362	valid_1's l1: 0.0209187
# Early stopping, best iteration is:
# [400]	training's l1: 0.0167362	valid_1's l1: 0.0209187
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0269846	valid_1's l1: 0.0427717
# Early stopping, best iteration is:
# [347]	training's l1: 0.0165613	valid_1's l1: 0.039733
# 341
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0351726	valid_1's l1: 0.0380044
# [400]	training's l1: 0.0159591	valid_1's l1: 0.0338549
# [600]	training's l1: 0.0131236	valid_1's l1: 0.0333141
# [800]	training's l1: 0.011545	valid_1's l1: 0.0328958
# [1000]	training's l1: 0.0103717	valid_1's l1: 0.0328068
# Early stopping, best iteration is:
# [1009]	training's l1: 0.0103196	valid_1's l1: 0.0327905
# fold: 1, target: Density, mae: 0.032790510040967266
# train rows: 969, valid rows: 118, ignore rows: 159
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0280965	valid_1's l1: 0.0336587
# [400]	training's l1: 0.0159701	valid_1's l1: 0.0275616
# Early stopping, best iteration is:
# [399]	training's l1: 0.0159849	valid_1's l1: 0.0275379
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0276927	valid_1's l1: 0.0348283
# [400]	training's l1: 0.0163202	valid_1's l1: 0.0307707
# Early stopping, best iteration is:
# [411]	training's l1: 0.0161411	valid_1's l1: 0.0307408
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.028454	valid_1's l1: 0.029368
# [400]	training's l1: 0.0163264	valid_1's l1: 0.0224801
# [600]	training's l1: 0.0139274	valid_1's l1: 0.0219291
# Early stopping, best iteration is:
# [617]	training's l1: 0.0137908	valid_1's l1: 0.0218639
# 349
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0335856	valid_1's l1: 0.0478078
# [400]	training's l1: 0.0170323	valid_1's l1: 0.0440104
# [600]	training's l1: 0.0146721	valid_1's l1: 0.0435626
# Early stopping, best iteration is:
# [587]	training's l1: 0.014772	valid_1's l1: 0.0435146
# fold: 2, target: Density, mae: 0.04351462068396938
# RMSE for Density: 0.0064
# MAE for Density: 0.0442
#
# === Training for target: Rg ===
# train rows: 272, valid rows: 342, ignore rows: 0
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.3734	valid_1's l1: 1.98857
# [400]	training's l1: 0.881953	valid_1's l1: 1.85404
# Early stopping, best iteration is:
# [364]	training's l1: 0.941814	valid_1's l1: 1.84829
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.3495	valid_1's l1: 1.65925
# [400]	training's l1: 0.869036	valid_1's l1: 1.45027
# [600]	training's l1: 0.638436	valid_1's l1: 1.39017
# [800]	training's l1: 0.486178	valid_1's l1: 1.36382
# Early stopping, best iteration is:
# [847]	training's l1: 0.458232	valid_1's l1: 1.36024
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.33566	valid_1's l1: 2.13833
# Early stopping, best iteration is:
# [338]	training's l1: 0.937567	valid_1's l1: 2.09014
# 345
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.32901	valid_1's l1: 2.39384
# [400]	training's l1: 0.839066	valid_1's l1: 2.08732
# [600]	training's l1: 0.620185	valid_1's l1: 2.05719
# [800]	training's l1: 0.477723	valid_1's l1: 2.04007
# Early stopping, best iteration is:
# [851]	training's l1: 0.451431	valid_1's l1: 2.03952
# fold: 0, target: Rg, mae: 2.039524712471801
# train rows: 459, valid rows: 155, ignore rows: 0
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.15081	valid_1's l1: 2.12514
# [400]	training's l1: 0.731191	valid_1's l1: 1.9764
# Early stopping, best iteration is:
# [446]	training's l1: 0.692209	valid_1's l1: 1.97297
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.20386	valid_1's l1: 1.46809
# [400]	training's l1: 0.769085	valid_1's l1: 1.21454
# Early stopping, best iteration is:
# [522]	training's l1: 0.663761	valid_1's l1: 1.20873
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.17981	valid_1's l1: 1.752
# [400]	training's l1: 0.742869	valid_1's l1: 1.63412
# Early stopping, best iteration is:
# [379]	training's l1: 0.762681	valid_1's l1: 1.63222
# 337
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.24787	valid_1's l1: 1.98698
# [400]	training's l1: 0.812969	valid_1's l1: 1.81549
# [600]	training's l1: 0.658394	valid_1's l1: 1.77807
# Early stopping, best iteration is:
# [704]	training's l1: 0.596602	valid_1's l1: 1.76995
# fold: 1, target: Rg, mae: 1.7699506319430138
# train rows: 497, valid rows: 117, ignore rows: 0
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.19317	valid_1's l1: 1.9246
# [400]	training's l1: 0.787929	valid_1's l1: 1.69317
# [600]	training's l1: 0.642547	valid_1's l1: 1.66308
# Early stopping, best iteration is:
# [619]	training's l1: 0.63081	valid_1's l1: 1.66033
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.18734	valid_1's l1: 2.06815
# [400]	training's l1: 0.788094	valid_1's l1: 1.75368
# [600]	training's l1: 0.646238	valid_1's l1: 1.66344
# [800]	training's l1: 0.549868	valid_1's l1: 1.62183
# [1000]	training's l1: 0.478724	valid_1's l1: 1.60289
# Early stopping, best iteration is:
# [1021]	training's l1: 0.472005	valid_1's l1: 1.60195
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.17813	valid_1's l1: 1.96741
# Early stopping, best iteration is:
# [308]	training's l1: 0.879947	valid_1's l1: 1.845
# 345
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.1502	valid_1's l1: 2.62591
# [400]	training's l1: 0.758575	valid_1's l1: 2.45637
# Early stopping, best iteration is:
# [362]	training's l1: 0.789793	valid_1's l1: 2.45338
# fold: 2, target: Rg, mae: 2.4533821759939642
# RMSE for Rg: 8.2694
# MAE for Rg: 2.0503
#
# 📊 Final OOF Score (wMAE): 0.057400
# {'Tg': [634, 357, 857], 'FFV': [2223, 7205, 6300], 'Tc': [331, 434, 376], 'Density': [487, 1009, 587], 'Rg': [851, 704, 362]}
