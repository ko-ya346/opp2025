# %% [markdown]
# - -> exp052
# - アスタリスク取り除いて特徴量生成

# %%
# %load_ext autotime
# %load_ext autoreload

# %%
import os

is_kaggle_notebook = os.path.exists("/kaggle/input")

# 必要パッケージをインストール
if is_kaggle_notebook:
    # !pip install /kaggle/input/rdkit-2025-3-3-cp311/rdkit-2025.3.3-cp311-cp311-manylinux_2_28_x86_64.whl
    # !pip install /kaggle/input/torch-geometric-2-6-1/torch_geometric-2.6.1-py3-none-any.whl

# %%
import copy
import json
import os
import sys
import warnings
from pathlib import Path

import wandb

import lightgbm as lgb
import numpy as np
import pandas as pd
import torch
from rdkit import rdBase
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GroupKFold, KFold, ShuffleSplit
from tqdm.auto import tqdm

from sklearn.decomposition import TruncatedSVD
from scipy import sparse

rdBase.DisableLog("rdApp.warning")
warnings.filterwarnings("ignore")

wandb.login()
# Out:
# wandb: Currently logged in as: ko_ya346 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
pr_number = 1
exp = "exp053"
debug = True
ignore_3D = True
ignore_3d_stats = True
select_feature = True
data_exp = "exp053"
remove_asterisk = True
notes = "アスタリスク除去"

# %%
# %autoreload 2

if is_kaggle_notebook:
    module_path = f"/kaggle/input/myproject-pr-{pr_number:04}"
    # !mkdir src
    # !cp -r $module_path/* src/
    src_path = "./"
else:
    src_path = "../"

sys.path.append(src_path)

from src.data import load_data, add_descriptors, add_descriptors_mordred, add_external_data, make_smile_canonical, add_maccs, add_augumented_gmm, add_graph_features, add_count_atoms
from src.model import train_lgb_for_target, save_lgb_model
from src.utils import NULL_FOR_SUBMISSION, generate_scaffold, score, add_scaffold_kfold, scaffold_cv_split, get_useless_cols, cap_stars_with_H
from src.utils.upload_kaggle_dataset import (
    create_kaggle_dataset_metadata,
    upload_kaggle_dataset,
)

# %%
model_name = "lgb"

config = {
    "debug": debug,
    "n_splits": 3,
    "num_epochs": 1000,
    "batch_size": 128,
    "drop_ratio": 0.5,
    "force_update_train": False,
    "augumented_gmm": False,
    "is_complement": True,
    "remove_external_cv": True,
}

dataset_title = f"model-{exp}"
dataset_id = f"koya346/{dataset_title}"

if is_kaggle_notebook:
    config["debug"] = False

if config["debug"]:
    config["n_splits"] = 2
    config["num_epochs"] = 10

targets = ["Tg", "FFV", "Tc", "Density", "Rg"]
org_target_cols = [f"org_{target}" for target in targets]        

# TODO: 学習パラメータ定義
params = {
    "objective": "regression",
    "metric": "mae",
    "verbosity": -1,
    "learning_rate": 0.01,
    "max_depth": 7,
    "seed": 42,
    "subsample": 0.7,
    "colsample_bytree": 0.6,
    "num_boost_round": 20000,
}

config.update(params)
pre_params = copy.deepcopy(params)
pre_params["num_boost_round"] = 300

# %%
wandb_name = f"{exp}_{model_name}" if not config["debug"] else f"{exp}_{model_name}_debug"
wandb.init(project="opp2025", name=wandb_name, config=config)
wandb.log({"Notes": notes})

# ---------------------------
# メイン処理
# ---------------------------
if config["debug"]:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp / "debug"
else:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp

model_output_path = output_path / "model_cv"
if not os.path.exists(model_output_path):
    os.makedirs(model_output_path)

if is_kaggle_notebook:
    # kaggle notebook
    data_dir = Path("/kaggle/input")
else:
    # local
    data_dir = Path("/home/kouya-takahashi/kaggle/opp2025/data/raw")

# 学習データ用意
train_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / data_exp

if os.path.exists(train_path / "train.csv") and not config["force_update_train"]:
    train = pd.read_csv(train_path / "train.csv")
else:
    train, _ = load_data(data_dir)
    # 外部データ判定用に元の目的変数を保持しておく
    # 外部データ判定は scaffold_cv_split 内で行う
    for target in targets:
        train[f"org_{target}"] = train[target]
    

    train["org_SMILES"] = train["SMILES"]
    train["SMILES"] = train["SMILES"].apply(make_smile_canonical)
    if config["debug"]:
        # 各ターゲットが欠損していないデータを30 件ずつ取り出す
        tmp_dfs = []
        for target in targets:
            cond = train[target].notnull()
            tmp_dfs.append(train[cond].iloc[:30])
        train = pd.concat(tmp_dfs).reset_index(drop=True)
    else:
        print(train.shape)
        external_data_dict = [
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset3.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset1.csv",
                "col": "Tc",
                "rename_d": {"TC_mean": "Tc"},
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset4.csv",
                "col": "FFV",
            },
            {
                "ex_path": data_dir / "tg-smiles-pid-polymer-class/TgSS_enriched_cleaned.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_dnst1.xlsx",
                "col": "Density",
                "rename_d": {"density(g/cm3)": "Density"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_tg3.xlsx",
                "col": "Tg",
                "rename_d": {"Tg [K]": "Tg"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/JCIM_sup_bigsmiles.csv",
                "col": "Tg",
                "rename_d": {"Tg (C)": "Tg"}, 
            },
        ]
        for d in external_data_dict:
            print(f"ex_path: {str(d['ex_path'])}")
            train = add_external_data(
                df=train,
                ex_path=d.get("ex_path"),
                col=d.get("col"),
                rename_d=d.get("rename_d"),
                is_complement=config["is_complement"]
            )
            print("after train.shape: ", train.shape)

    train["is_external"] = train["id"].isnull()
    train["id"] = np.arange(len(train))
    train["SMILES_cap"] = train["SMILES"].apply(cap_stars_with_H)
    if remove_asterisk:
        smiles_col = "SMILES_cap"
    else:
        smiles_col = "SMILES"
    maccs = add_maccs(train[["id", smiles_col]], col=smiles_col).drop(smiles_col, axis=1)
    maccs = maccs.add_prefix("maccs_")
    maccs = maccs.rename(columns={"maccs_id": "id"})
    
    # rdkit の記述子, morgan finger print
    desc = add_descriptors(train[["id", smiles_col]], radius=2, fp_size=1024, col=smiles_col).drop(smiles_col, axis=1)
    desc = desc.add_prefix("desc_")
    desc = desc.rename(columns={"desc_id": "id"})
    
    desc_mordred = add_descriptors_mordred(train[["id", smiles_col]], num_confs=10, ignore_3D=ignore_3D, ignore_3d_stats=ignore_3d_stats, col=smiles_col).drop(smiles_col, axis=1)
    desc_mordred = desc_mordred.add_prefix("desc_mordred_")
    desc_mordred = desc_mordred.rename(columns={"desc_mordred_id": "id"})
    
    graph_features = add_graph_features(train[["id", smiles_col]], col=smiles_col).drop(smiles_col, axis=1)
    graph_features = graph_features.add_prefix("graph_features_")
    graph_features = graph_features.rename(columns={"graph_features_id": "id"})
    
    cnt_atoms = add_count_atoms(train[["id", smiles_col]], col=smiles_col).drop(smiles_col, axis=1)
    cnt_atoms = cnt_atoms.add_prefix("cnt_atoms_")
    cnt_atoms = cnt_atoms.rename(columns={"cnt_atoms_id": "id"})
    
    for df in [maccs, desc, desc_mordred, graph_features, cnt_atoms]:
        train = train.merge(df, on="id")
    train = train.drop("SMILES_cap", axis=1)
    
    features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns
    for col in features:
        if train[col].dtype == "object":
            train[col] = pd.to_numeric(train[col], errors="coerce")
    useless_cols = get_useless_cols(train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1))
    
    train = train.drop(useless_cols, axis=1)
    
    os.makedirs(output_path, exist_ok=True)
    train.to_csv(output_path / "train.csv", index=False)
    print("Saved train.csv")

# 不要なビット列を除去
bit_cols = []
remove_cols = []

for col in train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns:
    if len(train[col].unique()) != 2:
        continue
    if np.all(train[col].unique() == np.array([0, 1])):
        bit_cols.append(col)
        p = train[col].mean()
        if p > 0.01 and p < 0.99:
            continue
        remove_cols.append(col)
print("bit cols: ", len(bit_cols))
print("remove cols: ", len(remove_cols))

train = train.drop(remove_cols, axis=1)

# 計算済の fold を突合
folds = pd.read_csv("/home/kouya-takahashi/kaggle/opp2025/data/preprocess/fold/folds.csv")
train = train.merge(folds[["SMILES", "fold"]], how="left", on="SMILES")

features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "fold", "is_external"], axis=1).columns
print(len(features))
oof_dfs = []

loss_table_wandb = wandb.Table(["exp", "model_name", "fold", "target", "mae", "mse"])
all_loss_tables = []
mae_dict = {}
all_models = {}

for idx, target_col in enumerate(targets):
    loss_tables = []
    print(f"\n=== Training for target: {target_col} ===")

    df_train = train[train[target_col].notnull()].reset_index(drop=True)
    X = df_train[features]
    y = df_train[target_col]
    oof = np.full(len(X), np.nan, dtype=float)
    
    models = []

    for fold, tr_idx, val_idx in scaffold_cv_split(df_train, target=target_col, n_splits=config["n_splits"], remove_external=config["remove_external_cv"]):
        if len(tr_idx) == 0 or len(val_idx) == 0:
            print(f"Skip fold... tr_idx: {len(tr_idx)}, val_idx: {len(val_idx)}")
            continue
        loss_table = {}
        print(f"fold: {fold + 1}")

        if select_feature:
            hits = np.zeros(X.shape[1], dtype=int)
    
            rs = ShuffleSplit(n_splits=3, train_size=0.9, random_state=42)
            for idx, (tr_in, va_in) in enumerate(rs.split(tr_idx)):
                X_tr_in, X_va_in = X.iloc[tr_in][features], X.iloc[va_in][features]
                y_tr_in, y_va_in = y.iloc[tr_in], y.iloc[va_in]
                # valid から外部データ除外
                cond_valid = df_train.iloc[va_in][f"org_{target_col}"].notnull()
                X_va_in = X_va_in[cond_valid]
                y_va_in = y_va_in[cond_valid]
                
                dtrain_in = lgb.Dataset(X_tr_in, label=y_tr_in)
                dvalid_in = lgb.Dataset(X_va_in, label=y_va_in)
                model = lgb.train(
                    params,
                    dtrain_in,
                    valid_sets=[dtrain_in, dvalid_in],
                    callbacks=[
                        lgb.early_stopping(stopping_rounds=50),
                        lgb.log_evaluation(200)
                    ]
                )
                rank = model.feature_importance("gain").argsort()[::-1]
                topk = set(rank[:int(0.3 * len(rank))])
                hits[list(topk)] += 1
            keep = hits >= 2
            use_features = features[keep]
        else:
            use_features = features
        print(len(use_features))        

        # 特徴量選択して valid データとともに学習
        X_train, X_val = X.iloc[tr_idx][use_features], X.iloc[val_idx][use_features]
        y_train, y_val = y.iloc[tr_idx], y.iloc[val_idx]

        if config["augumented_gmm"]:
            X_train, y_train = add_augumented_gmm(X_train, y_train)    
        
        dtrain = lgb.Dataset(X_train, label=y_train)
        dval = lgb.Dataset(X_val, label=y_val, reference=dtrain)

        model = lgb.train(
            params,
            dtrain,
            valid_sets=[dtrain, dval],
            callbacks=[
                lgb.early_stopping(stopping_rounds=50),
                lgb.log_evaluation(200)
            ]
        )

        save_lgb_model(model, str(model_output_path / f"model_{target_col}_{fold}.txt"))

        pred = model.predict(X_val, num_iteration=model.best_iteration)
        oof[val_idx] = pred

        mse = mean_squared_error(y_val, pred)
        mae = mean_absolute_error(y_val, pred)
        print(f"fold: {fold}, target: {target_col}, mae: {mae}")
        loss_table["fold"] = fold
        loss_table["target"] = target_col
        loss_table["mae"] = mae
        loss_table["mse"] = mse

        loss_tables.append(loss_table)
        models.append(model)

    # 評価に使うのは元データのみ
    cond = (~np.isnan(oof)) & (df_train[f"org_{target_col}"].notnull())
    y_true = y[cond]
    y_pred = oof[cond]
    score_mse = mean_squared_error(y_true, y_pred)
    score_mae = mean_absolute_error(y_true, y_pred)
    print(f"RMSE for {target_col}: {score_mse:.4f}")
    print(f"MAE for {target_col}: {score_mae:.4f}")
    mae_dict[target_col] = score_mae

    for loss_table in loss_tables:
        loss_table_wandb.add_data(exp, model_name, loss_table["fold"], loss_table["target"], loss_table["mae"], loss_table["mse"])
    all_loss_tables += loss_tables

    oof_df = pd.DataFrame({
        "id": df_train["id"].values,
        target_col: oof
    })
    oof_dfs.append(oof_df)   

    all_models[target_col] = models

wandb.log({"fold_target_losses": loss_table_wandb})
# target 毎の 平均 mae を記録
for target in targets:
    key_name = f"{target}_mean_mae"
    mae_values = mae_dict[target]
    # mae_values = [d["mae"] for d in all_loss_tables if d["target"] == target]
    wandb.log({key_name: np.mean(mae_values)})

# CV 計算
cond = ~train["is_external"]
oof_df = pd.DataFrame()

# 元の目的変数も入れておく
for target in targets:
    oof_df[f"org_{target}"] = train.loc[cond, f"org_{target}"]

oof_df["id"] = train.loc[cond, "id"]

# 正規化前の SMILES
oof_df["SMILES"] = train.loc[cond, "org_SMILES"]

for i_oof in oof_dfs:
    oof_df = oof_df.merge(i_oof, on="id", how="left")

# # 予測しなかった部分は null にしておく
# for target in targets:
#     oof_df.loc[oof_df[target] == 0, target] = np.nan

oof_df.to_csv(output_path / "oof.csv", index=False)

solution = train.loc[cond, ["id"] + org_target_cols].copy()
solution.columns = ["id"] + targets

# solution = solution.fillna(NULL_FOR_SUBMISSION)

# oof_df = oof_df.fillna(NULL_FOR_SUBMISSION)

# 評価
final_score = score(
    solution=solution,
    submission=oof_df,
)
print(f"\n📊 Final OOF Score (wMAE): {final_score:.6f}")
wandb.log({"wMAE": final_score})

# target 毎の best_iteration を保存する。保存したモデルには記録されてなかった
best_iterations = {}
for target in targets:
    target_best_iterations = [model.best_iteration for model in all_models[target]]
    best_iterations[target] = target_best_iterations
print(best_iterations)

with open(output_path / "best_iterations.json", "w") as f:
    json.dump(best_iterations, f)
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Notes</td><td>アスタリスク除去</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">exp053_lgb_debug</strong> at: <a href='https://wandb.ai/ko_ya346/opp2025/runs/uv3usv9w' target="_blank">https://wandb.ai/ko_ya346/opp2025/runs/uv3usv9w</a><br> View project at: <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">https://wandb.ai/ko_ya346/opp2025</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250901_152410-uv3usv9w/logs</code>
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/kouya-takahashi/kaggle/opp2025/notebook/wandb/run-20250901_152520-la2m3a47</code>
# Syncing run <strong><a href='https://wandb.ai/ko_ya346/opp2025/runs/la2m3a47' target="_blank">exp053_lgb_debug</a></strong> to <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">https://wandb.ai/ko_ya346/opp2025</a>
#  View run at <a href='https://wandb.ai/ko_ya346/opp2025/runs/la2m3a47' target="_blank">https://wandb.ai/ko_ya346/opp2025/runs/la2m3a47</a>
# *=C=C=C(COS(=O)(=O)c1ccc(OC)cc1)C(=*)COS(=O)(=O)c1ccc(OC)cc1: Explicit valence for atom # 0 H, 2, is greater than permitted
# Generating maccs:   0%|          | 0/150 [00:00<?, ?it/s]
# Generating descriptors:   0%|          | 0/150 [00:00<?, ?it/s]
# mordred desc:   0%|          | 0/150 [00:00<?, ?it/s]
# Unique=1 col: ['maccs_maccs_0', 'maccs_maccs_1', 'maccs_maccs_2', 'maccs_maccs_3', 'maccs_maccs_4', 'maccs_maccs_5', 'maccs_maccs_6', 'maccs_maccs_7', 'maccs_maccs_8', 'maccs_maccs_9', 'maccs_maccs_10', 'maccs_maccs_11', 'maccs_maccs_12', 'maccs_maccs_13', 'maccs_maccs_15', 'maccs_maccs_16', 'maccs_maccs_18', 'maccs_maccs_19', 'maccs_maccs_20', 'maccs_maccs_21', 'maccs_maccs_22', 'maccs_maccs_25', 'maccs_maccs_26', 'maccs_maccs_27', 'maccs_maccs_28', 'maccs_maccs_30', 'maccs_maccs_31', 'maccs_maccs_35', 'maccs_maccs_68', 'maccs_maccs_166', 'desc_NumRadicalElectrons', 'desc_SMR_VSA8', 'desc_SlogP_VSA9', 'desc_fr_C_S', 'desc_fr_HOCCN', 'desc_fr_N_O', 'desc_fr_Ndealkylation1', 'desc_fr_Ndealkylation2', 'desc_fr_amidine', 'desc_fr_azide', 'desc_fr_azo', 'desc_fr_barbitur', 'desc_fr_benzodiazepine', 'desc_fr_diazo', 'desc_fr_dihydropyridine', 'desc_fr_epoxide', 'desc_fr_guanido', 'desc_fr_hdrzine', 'desc_fr_hdrzone', 'desc_fr_imidazole', 'desc_fr_isocyan', 'desc_fr_isothiocyan', 'desc_fr_lactam', 'desc_fr_lactone', 'desc_fr_morpholine', 'desc_fr_nitroso', 'desc_fr_oxazole', 'desc_fr_oxime', 'desc_fr_phos_acid', 'desc_fr_phos_ester', 'desc_fr_piperzine', 'desc_fr_prisulfonamd', 'desc_fr_quatN', 'desc_fr_sulfonamd', 'desc_fr_tetrazole', 'desc_fr_thiocyan', 'desc_mfp_vec6', 'desc_mfp_vec7', 'desc_mfp_vec12', 'desc_mfp_vec16', 'desc_mfp_vec17', 'desc_mfp_vec18', 'desc_mfp_vec20', 'desc_mfp_vec22', 'desc_mfp_vec30', 'desc_mfp_vec32', 'desc_mfp_vec35', 'desc_mfp_vec38', 'desc_mfp_vec46', 'desc_mfp_vec48', 'desc_mfp_vec49', 'desc_mfp_vec51', 'desc_mfp_vec52', 'desc_mfp_vec55', 'desc_mfp_vec61', 'desc_mfp_vec63', 'desc_mfp_vec68', 'desc_mfp_vec69', 'desc_mfp_vec70', 'desc_mfp_vec74', 'desc_mfp_vec76', 'desc_mfp_vec77', 'desc_mfp_vec78', 'desc_mfp_vec81', 'desc_mfp_vec82', 'desc_mfp_vec83', 'desc_mfp_vec84', 'desc_mfp_vec85', 'desc_mfp_vec88', 'desc_mfp_vec89', 'desc_mfp_vec92', 'desc_mfp_vec93', 'desc_mfp_vec96', 'desc_mfp_vec99', 'desc_mfp_vec100', 'desc_mfp_vec101', 'desc_mfp_vec103', 'desc_mfp_vec107', 'desc_mfp_vec109', 'desc_mfp_vec110', 'desc_mfp_vec111', 'desc_mfp_vec113', 'desc_mfp_vec115', 'desc_mfp_vec120', 'desc_mfp_vec122', 'desc_mfp_vec125', 'desc_mfp_vec126', 'desc_mfp_vec127', 'desc_mfp_vec130', 'desc_mfp_vec133', 'desc_mfp_vec135', 'desc_mfp_vec137', 'desc_mfp_vec141', 'desc_mfp_vec143', 'desc_mfp_vec146', 'desc_mfp_vec148', 'desc_mfp_vec151', 'desc_mfp_vec154', 'desc_mfp_vec155', 'desc_mfp_vec156', 'desc_mfp_vec157', 'desc_mfp_vec159', 'desc_mfp_vec166', 'desc_mfp_vec167', 'desc_mfp_vec168', 'desc_mfp_vec172', 'desc_mfp_vec173', 'desc_mfp_vec174', 'desc_mfp_vec177', 'desc_mfp_vec178', 'desc_mfp_vec179', 'desc_mfp_vec181', 'desc_mfp_vec182', 'desc_mfp_vec183', 'desc_mfp_vec184', 'desc_mfp_vec187', 'desc_mfp_vec189', 'desc_mfp_vec192', 'desc_mfp_vec195', 'desc_mfp_vec196', 'desc_mfp_vec199', 'desc_mfp_vec200', 'desc_mfp_vec201', 'desc_mfp_vec204', 'desc_mfp_vec211', 'desc_mfp_vec217', 'desc_mfp_vec218', 'desc_mfp_vec220', 'desc_mfp_vec238', 'desc_mfp_vec241', 'desc_mfp_vec245', 'desc_mfp_vec246', 'desc_mfp_vec248', 'desc_mfp_vec253', 'desc_mfp_vec254', 'desc_mfp_vec257', 'desc_mfp_vec264', 'desc_mfp_vec269', 'desc_mfp_vec273', 'desc_mfp_vec274', 'desc_mfp_vec277', 'desc_mfp_vec279', 'desc_mfp_vec280', 'desc_mfp_vec286', 'desc_mfp_vec296', 'desc_mfp_vec297', 'desc_mfp_vec299', 'desc_mfp_vec300', 'desc_mfp_vec302', 'desc_mfp_vec303', 'desc_mfp_vec305', 'desc_mfp_vec308', 'desc_mfp_vec311', 'desc_mfp_vec312', 'desc_mfp_vec316', 'desc_mfp_vec317', 'desc_mfp_vec318', 'desc_mfp_vec320', 'desc_mfp_vec321', 'desc_mfp_vec324', 'desc_mfp_vec327', 'desc_mfp_vec328', 'desc_mfp_vec331', 'desc_mfp_vec335', 'desc_mfp_vec336', 'desc_mfp_vec337', 'desc_mfp_vec340', 'desc_mfp_vec347', 'desc_mfp_vec348', 'desc_mfp_vec349', 'desc_mfp_vec351', 'desc_mfp_vec355', 'desc_mfp_vec363', 'desc_mfp_vec365', 'desc_mfp_vec368', 'desc_mfp_vec369', 'desc_mfp_vec370', 'desc_mfp_vec371', 'desc_mfp_vec372', 'desc_mfp_vec374', 'desc_mfp_vec380', 'desc_mfp_vec38 ...
# Highly correlated cols:  ['maccs_maccs_33', 'maccs_maccs_40', 'maccs_maccs_44', 'maccs_maccs_48', 'maccs_maccs_49', 'maccs_maccs_53', 'maccs_maccs_55', 'maccs_maccs_56', 'maccs_maccs_58', 'maccs_maccs_60', 'maccs_maccs_61', 'maccs_maccs_63', 'maccs_maccs_70', 'maccs_maccs_71', 'maccs_maccs_73', 'maccs_maccs_91', 'maccs_maccs_105', 'maccs_maccs_117', 'maccs_maccs_122', 'maccs_maccs_130', 'maccs_maccs_134', 'maccs_maccs_135', 'maccs_maccs_143', 'maccs_maccs_147', 'desc_MaxAbsEStateIndex', 'desc_HeavyAtomMolWt', 'desc_ExactMolWt', 'desc_NumValenceElectrons', 'desc_MaxAbsPartialCharge', 'desc_FpDensityMorgan2', 'desc_Chi0', 'desc_Chi0n', 'desc_Chi0v', 'desc_Chi1', 'desc_Chi1n', 'desc_Chi1v', 'desc_Chi2n', 'desc_Chi2v', 'desc_Chi3n', 'desc_Chi3v', 'desc_Chi4n', 'desc_Chi4v', 'desc_HallKierAlpha', 'desc_Kappa1', 'desc_LabuteASA', 'desc_SMR_VSA2', 'desc_SlogP_VSA6', 'desc_EState_VSA11', 'desc_VSA_EState6', 'desc_HeavyAtomCount', 'desc_NOCount', 'desc_NumAromaticCarbocycles', 'desc_NumAromaticRings', 'desc_NumRotatableBonds', 'desc_RingCount', 'desc_MolMR', 'desc_fr_Al_OH_noTert', 'desc_fr_COO2', 'desc_fr_C_O_noCOO', 'desc_fr_Imine', 'desc_fr_Nhpyrrole', 'desc_fr_SH', 'desc_fr_alkyl_halide', 'desc_fr_benzene', 'desc_fr_furan', 'desc_fr_nitrile', 'desc_fr_nitro', 'desc_fr_nitro_arom', 'desc_fr_nitro_arom_nonortho', 'desc_fr_phenol', 'desc_fr_phenol_noOrthoHbond', 'desc_fr_piperdine', 'desc_fr_pyridine', 'desc_fr_term_acetylene', 'desc_fr_urea', 'desc_mfp_vec0', 'desc_mfp_vec27', 'desc_mfp_vec28', 'desc_mfp_vec33', 'desc_mfp_vec44', 'desc_mfp_vec45', 'desc_mfp_vec59', 'desc_mfp_vec67', 'desc_mfp_vec80', 'desc_mfp_vec91', 'desc_mfp_vec95', 'desc_mfp_vec97', 'desc_mfp_vec104', 'desc_mfp_vec105', 'desc_mfp_vec112', 'desc_mfp_vec129', 'desc_mfp_vec131', 'desc_mfp_vec142', 'desc_mfp_vec149', 'desc_mfp_vec153', 'desc_mfp_vec164', 'desc_mfp_vec165', 'desc_mfp_vec176', 'desc_mfp_vec188', 'desc_mfp_vec194', 'desc_mfp_vec197', 'desc_mfp_vec198', 'desc_mfp_vec202', 'desc_mfp_vec205', 'desc_mfp_vec206', 'desc_mfp_vec207', 'desc_mfp_vec209', 'desc_mfp_vec215', 'desc_mfp_vec216', 'desc_mfp_vec226', 'desc_mfp_vec227', 'desc_mfp_vec229', 'desc_mfp_vec230', 'desc_mfp_vec236', 'desc_mfp_vec239', 'desc_mfp_vec244', 'desc_mfp_vec256', 'desc_mfp_vec260', 'desc_mfp_vec262', 'desc_mfp_vec267', 'desc_mfp_vec270', 'desc_mfp_vec278', 'desc_mfp_vec284', 'desc_mfp_vec288', 'desc_mfp_vec292', 'desc_mfp_vec294', 'desc_mfp_vec306', 'desc_mfp_vec323', 'desc_mfp_vec326', 'desc_mfp_vec338', 'desc_mfp_vec339', 'desc_mfp_vec343', 'desc_mfp_vec345', 'desc_mfp_vec350', 'desc_mfp_vec354', 'desc_mfp_vec356', 'desc_mfp_vec359', 'desc_mfp_vec364', 'desc_mfp_vec366', 'desc_mfp_vec373', 'desc_mfp_vec377', 'desc_mfp_vec379', 'desc_mfp_vec387', 'desc_mfp_vec395', 'desc_mfp_vec397', 'desc_mfp_vec409', 'desc_mfp_vec414', 'desc_mfp_vec419', 'desc_mfp_vec429', 'desc_mfp_vec436', 'desc_mfp_vec437', 'desc_mfp_vec442', 'desc_mfp_vec446', 'desc_mfp_vec448', 'desc_mfp_vec451', 'desc_mfp_vec452', 'desc_mfp_vec457', 'desc_mfp_vec462', 'desc_mfp_vec465', 'desc_mfp_vec466', 'desc_mfp_vec480', 'desc_mfp_vec482', 'desc_mfp_vec483', 'desc_mfp_vec485', 'desc_mfp_vec487', 'desc_mfp_vec493', 'desc_mfp_vec502', 'desc_mfp_vec504', 'desc_mfp_vec505', 'desc_mfp_vec506', 'desc_mfp_vec519', 'desc_mfp_vec522', 'desc_mfp_vec527', 'desc_mfp_vec528', 'desc_mfp_vec537', 'desc_mfp_vec538', 'desc_mfp_vec541', 'desc_mfp_vec544', 'desc_mfp_vec547', 'desc_mfp_vec548', 'desc_mfp_vec550', 'desc_mfp_vec553', 'desc_mfp_vec555', 'desc_mfp_vec559', 'desc_mfp_vec561', 'desc_mfp_vec564', 'desc_mfp_vec580', 'desc_mfp_vec582', 'desc_mfp_vec583', 'desc_mfp_vec586', 'desc_mfp_vec589', 'desc_mfp_vec594', 'desc_mfp_vec605', 'desc_mfp_vec609', 'desc_mfp_vec610', 'desc_mfp_vec611', 'desc_mfp_vec614', 'desc_mfp_vec621', 'desc_mfp_vec622', 'desc_mfp_vec627', 'desc_mfp_vec628', 'desc_mfp_vec629', 'desc_mfp_vec630', 'desc_mfp_vec634', 'desc_mfp_vec635', 'desc_mfp_vec636', 'desc_mfp_vec648', 'desc_mfp_vec651', 'desc_mfp_vec654', 'desc_m ...
# Saved train.csv
# bit cols:  469
# remove cols:  51
# 1055
#
# === Training for target: Tg ===
# train rows: 24, valid rows: 12, ignore rows: 0
# fold: 1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 61.2778	valid_1's l1: 103.248
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: 71.4382	valid_1's l1: 58.7813
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l1: