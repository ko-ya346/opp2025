# %% [markdown]
# - -> exp046
# - mordred 特徴量再評価

# %%
# %load_ext autotime
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os

is_kaggle_notebook = os.path.exists("/kaggle/input")

# 必要パッケージをインストール
if is_kaggle_notebook:
    # !pip install /kaggle/input/rdkit-2025-3-3-cp311/rdkit-2025.3.3-cp311-cp311-manylinux_2_28_x86_64.whl
    # !pip install /kaggle/input/torch-geometric-2-6-1/torch_geometric-2.6.1-py3-none-any.whl

# %%
import copy
import json
import os
import sys
import warnings
from pathlib import Path

import wandb

import lightgbm as lgb
import numpy as np
import pandas as pd
import torch
from rdkit import rdBase
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GroupKFold, KFold, ShuffleSplit
from tqdm.auto import tqdm

from sklearn.decomposition import TruncatedSVD
from scipy import sparse

rdBase.DisableLog("rdApp.warning")
warnings.filterwarnings("ignore")

wandb.login()
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# True

# %%
pr_number = 1
debug = False

# %%
# %autoreload 2

if is_kaggle_notebook:
    module_path = f"/kaggle/input/myproject-pr-{pr_number:04}"
    # !mkdir src
    # !cp -r $module_path/* src/
    src_path = "./"
else:
    src_path = "../"

sys.path.append(src_path)

from src.data import load_data, add_descriptors, add_descriptors_mordred, add_external_data, make_smile_canonical, add_maccs, add_augumented_gmm, add_graph_features, add_count_atoms
from src.model import train_lgb_for_target, save_lgb_model
from src.utils import NULL_FOR_SUBMISSION, generate_scaffold, score, add_scaffold_kfold, scaffold_cv_split, get_useless_cols
from src.utils.upload_kaggle_dataset import (
    create_kaggle_dataset_metadata,
    upload_kaggle_dataset,
)

# %%
# !mkdir ../outputs/exp045
# !cp ../outputs/exp044/train.csv ../outputs/exp044/train.csv

# !rm ../outputs/exp045/train.csv

# %%
exp = "exp046"
notes = "gain で特徴量削減"
model_name = "lgb"

config = {
    "debug": debug,
    "n_splits": 3,
    "num_epochs": 1000,
    "batch_size": 128,
    "drop_ratio": 0.5,
    "force_update_train": True,
    "augumented_gmm": False,
    "is_complement": True,
    "remove_external_cv": True,
}

dataset_title = f"model-{exp}"
dataset_id = f"koya346/{dataset_title}"

if is_kaggle_notebook:
    config["debug"] = False

if config["debug"]:
    config["n_splits"] = 2
    config["num_epochs"] = 10

targets = ["Tg", "FFV", "Tc", "Density", "Rg"]
org_target_cols = [f"org_{target}" for target in targets]        

# TODO: 学習パラメータ定義
params = {
    "objective": "regression",
    "metric": "mae",
    "verbosity": -1,
    "learning_rate": 0.01,
    "max_depth": 7,
    "seed": 42,
    "subsample": 0.7,
    "colsample_bytree": 0.6,
    "num_boost_round": 20000,
}

config.update(params)
pre_params = copy.deepcopy(params)
pre_params["num_boost_round"] = 300

# %%
wandb_name = f"{exp}_{model_name}" if not config["debug"] else f"{exp}_{model_name}_debug"
wandb.init(project="opp2025", name=wandb_name, config=config)
wandb.log({"Notes": notes})

# ---------------------------
# メイン処理
# ---------------------------
if config["debug"]:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp / "debug"
else:
    output_path = Path("/home/kouya-takahashi/kaggle/opp2025/outputs") / exp

model_output_path = output_path / "model_cv"
if not os.path.exists(model_output_path):
    os.makedirs(model_output_path)

if is_kaggle_notebook:
    # kaggle notebook
    data_dir = Path("/kaggle/input")
else:
    # local
    data_dir = Path("/home/kouya-takahashi/kaggle/opp2025/data/raw")

# 学習データ用意

if os.path.exists(output_path / "train.csv") and not config["force_update_train"]:
    train = pd.read_csv(output_path / "train.csv")
else:
    train, _ = load_data(data_dir)
    # 外部データ判定用に元の目的変数を保持しておく
    # 外部データ判定は scaffold_cv_split 内で行う
    for target in targets:
        train[f"org_{target}"] = train[target]
    

    train["org_SMILES"] = train["SMILES"]
    train["SMILES"] = train["SMILES"].apply(make_smile_canonical)
    if config["debug"]:
        # 各ターゲットが欠損していないデータを30 件ずつ取り出す
        tmp_dfs = []
        for target in targets:
            cond = train[target].notnull()
            tmp_dfs.append(train[cond].iloc[:30])
        train = pd.concat(tmp_dfs).reset_index(drop=True)
    else:
        print(train.shape)
        external_data_dict = [
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset3.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset1.csv",
                "col": "Tc",
                "rename_d": {"TC_mean": "Tc"},
            },
            {
                "ex_path": data_dir / "neurips-open-polymer-prediction-2025/train_supplement/dataset4.csv",
                "col": "FFV",
            },
            {
                "ex_path": data_dir / "tg-smiles-pid-polymer-class/TgSS_enriched_cleaned.csv",
                "col": "Tg",
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_dnst1.xlsx",
                "col": "Density",
                "rename_d": {"density(g/cm3)": "Density"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/data_tg3.xlsx",
                "col": "Tg",
                "rename_d": {"Tg [K]": "Tg"}, 
            },
            {
                "ex_path": data_dir / "smiles-extra-data/JCIM_sup_bigsmiles.csv",
                "col": "Tg",
                "rename_d": {"Tg (C)": "Tg"}, 
            },
        ]
        for d in external_data_dict:
            print(f"ex_path: {str(d['ex_path'])}")
            train = add_external_data(
                df=train,
                ex_path=d.get("ex_path"),
                col=d.get("col"),
                rename_d=d.get("rename_d"),
                is_complement=config["is_complement"]
            )
            print("after train.shape: ", train.shape)

    train["is_external"] = train["id"].isnull()
    train = add_maccs(train)

    # rdkit の記述子, morgan finger print
    train = add_descriptors(train, radius=2, fp_size=1024)
    train = add_descriptors_mordred(train, num_confs=10, ignore_3D=False)

    new_cols = []
    seen = {}
    for col in train.columns:
        if col in seen:
            seen[col] += 1
            new_cols.append(f"{col}_{seen[col]}")
        else:
            seen[col] = 0
            new_cols.append(col)
    
    train.columns = new_cols
    
    # グラフ特徴量
    train = add_graph_features(train)
    train = add_count_atoms(train)
    
    train["id"] = np.arange(len(train))
    features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns
    for col in features:
        if train[col].dtype == "object":
            train[col] = pd.to_numeric(train[col], errors="coerce")
    useless_cols = get_useless_cols(train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1))
    
    train = train.drop(useless_cols, axis=1)
    
    os.makedirs(output_path, exist_ok=True)
    train.to_csv(output_path / "train.csv", index=False)
    print("Saved train.csv")

# 不要なビット列を除去
bit_cols = []
remove_cols = []

for col in train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "is_external"], axis=1).columns:
    if len(train[col].unique()) != 2:
        continue
    if np.all(train[col].unique() == np.array([0, 1])):
        bit_cols.append(col)
        p = train[col].mean()
        if p > 0.01 and p < 0.99:
            continue
        remove_cols.append(col)
print("bit cols: ", len(bit_cols))
print("remove cols: ", len(remove_cols))

train = train.drop(remove_cols, axis=1)

# 計算済の fold を突合
folds = pd.read_csv("/home/kouya-takahashi/kaggle/opp2025/data/preprocess/fold/folds.csv")
train = train.merge(folds[["SMILES", "fold"]], how="left", on="SMILES")

features = train.drop(targets + org_target_cols + ["id", "org_SMILES", "SMILES", "fold", "is_external"], axis=1).columns
print(len(features))
oof_dfs = []

loss_table_wandb = wandb.Table(["exp", "model_name", "fold", "target", "mae", "mse"])
all_loss_tables = []
mae_dict = {}
all_models = {}

for idx, target_col in enumerate(targets):
    loss_tables = []
    print(f"\n=== Training for target: {target_col} ===")

    df_train = train[train[target_col].notnull()].reset_index(drop=True)
    X = df_train[features]
    y = df_train[target_col]
    oof = np.full(len(X), np.nan, dtype=float)
    
    models = []

    for fold, tr_idx, val_idx in scaffold_cv_split(df_train, target=target_col, n_splits=config["n_splits"], remove_external=config["remove_external_cv"]):
        if len(tr_idx) == 0 or len(val_idx) == 0:
            print(f"Skip fold... tr_idx: {len(tr_idx)}, val_idx: {len(val_idx)}")
            continue
        loss_table = {}
        print(f"fold: {fold + 1}")
        hits = np.zeros(X.shape[1], dtype=int)

        rs = ShuffleSplit(n_splits=3, train_size=0.9, random_state=42)
        for idx, (tr_in, va_in) in enumerate(rs.split(tr_idx)):
            X_tr_in, X_va_in = X.iloc[tr_in][features], X.iloc[va_in][features]
            y_tr_in, y_va_in = y.iloc[tr_in], y.iloc[va_in]
            dtrain_in = lgb.Dataset(X_tr_in, label=y_tr_in)
            dvalid_in = lgb.Dataset(X_va_in, label=y_va_in)
            model = lgb.train(
                params,
                dtrain_in,
                valid_sets=[dtrain_in, dvalid_in],
                callbacks=[
                    lgb.early_stopping(stopping_rounds=50),
                    lgb.log_evaluation(200)
                ]
            )
            rank = model.feature_importance("gain").argsort()[::-1]
            topk = set(rank[:int(0.3 * len(rank))])
            hits[list(topk)] += 1
        keep = hits >= 2
        use_features = features[keep]
        print(len(use_features))        

        # 特徴量選択して valid データとともに学習
        X_train, X_val = X.iloc[tr_idx][use_features], X.iloc[val_idx][use_features]
        y_train, y_val = y.iloc[tr_idx], y.iloc[val_idx]

        if config["augumented_gmm"]:
            X_train, y_train = add_augumented_gmm(X_train, y_train)    
        
        dtrain = lgb.Dataset(X_train, label=y_train)
        dval = lgb.Dataset(X_val, label=y_val, reference=dtrain)

        model = lgb.train(
            params,
            dtrain,
            valid_sets=[dtrain, dval],
            callbacks=[
                lgb.early_stopping(stopping_rounds=50),
                lgb.log_evaluation(200)
            ]
        )

        save_lgb_model(model, str(model_output_path / f"model_{target_col}_{fold}.txt"))

        pred = model.predict(X_val, num_iteration=model.best_iteration)
        oof[val_idx] = pred

        mse = mean_squared_error(y_val, pred)
        mae = mean_absolute_error(y_val, pred)
        print(f"fold: {fold}, target: {target_col}, mae: {mae}")
        loss_table["fold"] = fold
        loss_table["target"] = target_col
        loss_table["mae"] = mae
        loss_table["mse"] = mse

        loss_tables.append(loss_table)
        models.append(model)

    # 評価に使うのは元データのみ
    cond = (~np.isnan(oof)) & (df_train[f"org_{target_col}"].notnull())
    y_true = y[cond]
    y_pred = oof[cond]
    score_mse = mean_squared_error(y_true, y_pred)
    score_mae = mean_absolute_error(y_true, y_pred)
    print(f"RMSE for {target_col}: {score_mse:.4f}")
    print(f"MAE for {target_col}: {score_mae:.4f}")
    mae_dict[target_col] = score_mae

    for loss_table in loss_tables:
        loss_table_wandb.add_data(exp, model_name, loss_table["fold"], loss_table["target"], loss_table["mae"], loss_table["mse"])
    all_loss_tables += loss_tables

    oof_df = pd.DataFrame({
        "id": df_train["id"].values,
        target_col: oof
    })
    oof_dfs.append(oof_df)   

    all_models[target_col] = models

wandb.log({"fold_target_losses": loss_table_wandb})
# target 毎の 平均 mae を記録
for target in targets:
    key_name = f"{target}_mean_mae"
    mae_values = mae_dict[target]
    # mae_values = [d["mae"] for d in all_loss_tables if d["target"] == target]
    wandb.log({key_name: np.mean(mae_values)})

# CV 計算
cond = ~train["is_external"]
oof_df = pd.DataFrame()

# 元の目的変数も入れておく
for target in targets:
    oof_df[f"org_{target}"] = train.loc[cond, f"org_{target}"]

oof_df["id"] = train.loc[cond, "id"]

# 正規化前の SMILES
oof_df["SMILES"] = train.loc[cond, "org_SMILES"]

for i_oof in oof_dfs:
    oof_df = oof_df.merge(i_oof, on="id", how="left")

# # 予測しなかった部分は null にしておく
# for target in targets:
#     oof_df.loc[oof_df[target] == 0, target] = np.nan

oof_df.to_csv(output_path / "oof.csv", index=False)

solution = train.loc[cond, ["id"] + org_target_cols].copy()
solution.columns = ["id"] + targets

# solution = solution.fillna(NULL_FOR_SUBMISSION)

# oof_df = oof_df.fillna(NULL_FOR_SUBMISSION)

# 評価
final_score = score(
    solution=solution,
    submission=oof_df,
)
print(f"\n📊 Final OOF Score (wMAE): {final_score:.6f}")
wandb.log({"wMAE": final_score})

# target 毎の best_iteration を保存する。保存したモデルには記録されてなかった
best_iterations = {}
for target in targets:
    target_best_iterations = [model.best_iteration for model in all_models[target]]
    best_iterations[target] = target_best_iterations
print(best_iterations)

with open(output_path / "best_iterations.json", "w") as f:
    json.dump(best_iterations, f)
# Out:
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/kouya-takahashi/kaggle/opp2025/notebook/wandb/run-20250826_013538-npemtf4u</code>
# Syncing run <strong><a href='https://wandb.ai/ko_ya346/opp2025/runs/npemtf4u' target="_blank">exp046_lgb</a></strong> to <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ko_ya346/opp2025' target="_blank">https://wandb.ai/ko_ya346/opp2025</a>
#  View run at <a href='https://wandb.ai/ko_ya346/opp2025/runs/npemtf4u' target="_blank">https://wandb.ai/ko_ya346/opp2025/runs/npemtf4u</a>
# bit cols:  1117
# remove cols:  479
# 837
#
# === Training for target: Tg ===
# train rows: 5476, valid rows: 191, ignore rows: 2577
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 33.6336	valid_1's l1: 38.2179
# [400]	training's l1: 24.9716	valid_1's l1: 32.4668
# [600]	training's l1: 22.1145	valid_1's l1: 31.031
# [800]	training's l1: 20.6161	valid_1's l1: 30.4352
# [1000]	training's l1: 19.4274	valid_1's l1: 29.98
# [1200]	training's l1: 18.505	valid_1's l1: 29.6758
# [1400]	training's l1: 17.6875	valid_1's l1: 29.4169
# [1600]	training's l1: 16.8921	valid_1's l1: 29.1527
# [1800]	training's l1: 16.1533	valid_1's l1: 28.918
# [2000]	training's l1: 15.4929	valid_1's l1: 28.7828
# [2200]	training's l1: 14.825	valid_1's l1: 28.607
# [2400]	training's l1: 14.2415	valid_1's l1: 28.4969
# [2600]	training's l1: 13.6351	valid_1's l1: 28.3703
# [2800]	training's l1: 13.1152	valid_1's l1: 28.2761
# [3000]	training's l1: 12.582	valid_1's l1: 28.2211
# [3200]	training's l1: 12.1462	valid_1's l1: 28.1834
# [3400]	training's l1: 11.7166	valid_1's l1: 28.1334
# Early stopping, best iteration is:
# [3454]	training's l1: 11.6127	valid_1's l1: 28.1301
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 33.9726	valid_1's l1: 37.1005
# [400]	training's l1: 25.2943	valid_1's l1: 30.2212
# [600]	training's l1: 22.5739	valid_1's l1: 28.7714
# [800]	training's l1: 21.0185	valid_1's l1: 28.1069
# [1000]	training's l1: 19.7806	valid_1's l1: 27.5825
# [1200]	training's l1: 18.7682	valid_1's l1: 27.1819
# [1400]	training's l1: 17.8185	valid_1's l1: 26.8327
# [1600]	training's l1: 16.9718	valid_1's l1: 26.5128
# [1800]	training's l1: 16.15	valid_1's l1: 26.2021
# [2000]	training's l1: 15.4579	valid_1's l1: 25.9471
# [2200]	training's l1: 14.7655	valid_1's l1: 25.7355
# [2400]	training's l1: 14.157	valid_1's l1: 25.5386
# [2600]	training's l1: 13.6058	valid_1's l1: 25.38
# [2800]	training's l1: 13.1221	valid_1's l1: 25.2457
# [3000]	training's l1: 12.6712	valid_1's l1: 25.1189
# [3200]	training's l1: 12.2381	valid_1's l1: 24.9932
# [3400]	training's l1: 11.8378	valid_1's l1: 24.9051
# [3600]	training's l1: 11.4215	valid_1's l1: 24.8059
# [3800]	training's l1: 11.0666	valid_1's l1: 24.7319
# [4000]	training's l1: 10.7212	valid_1's l1: 24.6647
# [4200]	training's l1: 10.3583	valid_1's l1: 24.626
# [4400]	training's l1: 10.0179	valid_1's l1: 24.566
# Early stopping, best iteration is:
# [4508]	training's l1: 9.83144	valid_1's l1: 24.5421
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 34.0934	valid_1's l1: 36.2217
# [400]	training's l1: 25.3083	valid_1's l1: 29.193
# [600]	training's l1: 22.5179	valid_1's l1: 27.3148
# [800]	training's l1: 21.0281	valid_1's l1: 26.499
# [1000]	training's l1: 19.8171	valid_1's l1: 26.0002
# [1200]	training's l1: 18.8077	valid_1's l1: 25.6704
# [1400]	training's l1: 17.9195	valid_1's l1: 25.3953
# [1600]	training's l1: 17.1102	valid_1's l1: 25.217
# [1800]	training's l1: 16.376	valid_1's l1: 25.0265
# [2000]	training's l1: 15.6979	valid_1's l1: 24.872
# [2200]	training's l1: 14.9815	valid_1's l1: 24.7681
# [2400]	training's l1: 14.3695	valid_1's l1: 24.6851
# [2600]	training's l1: 13.7998	valid_1's l1: 24.5712
# [2800]	training's l1: 13.2815	valid_1's l1: 24.5211
# Early stopping, best iteration is:
# [2867]	training's l1: 13.1303	valid_1's l1: 24.5056
# 249
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 34.0424	valid_1's l1: 64.2428
# [400]	training's l1: 25.6674	valid_1's l1: 56.2081
# [600]	training's l1: 22.5427	valid_1's l1: 54.7298
# [800]	training's l1: 20.6403	valid_1's l1: 54.156
# Early stopping, best iteration is:
# [822]	training's l1: 20.465	valid_1's l1: 54.0898
# fold: 0, target: Tg, mae: 54.089753914503554
# train rows: 5419, valid rows: 195, ignore rows: 2630
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 33.7297	valid_1's l1: 37.134
# [400]	training's l1: 24.9388	valid_1's l1: 30.8897
# [600]	training's l1: 22.1828	valid_1's l1: 29.235
# [800]	training's l1: 20.6839	valid_1's l1: 28.4005
# [1000]	training's l1: 19.4975	valid_1's l1: 27.805
# [1200]	training's l1: 18.4554	valid_1's l1: 27.3046
# [1400]	training's l1: 17.523	valid_1's l1: 27.0027
# [1600]	training's l1: 16.7229	valid_1's l1: 26.7535
# [1800]	training's l1: 16.0142	valid_1's l1: 26.5701
# [2000]	training's l1: 15.3227	valid_1's l1: 26.4033
# [2200]	training's l1: 14.7081	valid_1's l1: 26.2364
# [2400]	training's l1: 14.1121	valid_1's l1: 26.1045
# [2600]	training's l1: 13.5344	valid_1's l1: 25.9957
# Early stopping, best iteration is:
# [2741]	training's l1: 13.1318	valid_1's l1: 25.9138
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 33.9115	valid_1's l1: 37.3569
# [400]	training's l1: 25.1319	valid_1's l1: 30.3841
# [600]	training's l1: 22.4033	valid_1's l1: 29.0553
# [800]	training's l1: 20.8106	valid_1's l1: 28.421
# [1000]	training's l1: 19.6697	valid_1's l1: 28.0919
# [1200]	training's l1: 18.7331	valid_1's l1: 27.8183
# [1400]	training's l1: 17.8302	valid_1's l1: 27.5558
# [1600]	training's l1: 17.0161	valid_1's l1: 27.345
# [1800]	training's l1: 16.2274	valid_1's l1: 27.1825
# [2000]	training's l1: 15.5614	valid_1's l1: 27.0526
# [2200]	training's l1: 14.9209	valid_1's l1: 26.9333
# Early stopping, best iteration is:
# [2261]	training's l1: 14.6822	valid_1's l1: 26.8841
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 33.9603	valid_1's l1: 35.869
# [400]	training's l1: 25.2102	valid_1's l1: 29.739
# [600]	training's l1: 22.4724	valid_1's l1: 28.1141
# [800]	training's l1: 20.9773	valid_1's l1: 27.3953
# [1000]	training's l1: 19.6862	valid_1's l1: 26.8211
# [1200]	training's l1: 18.687	valid_1's l1: 26.4609
# [1400]	training's l1: 17.8142	valid_1's l1: 26.1959
# [1600]	training's l1: 17.0423	valid_1's l1: 25.9743
# [1800]	training's l1: 16.2993	valid_1's l1: 25.8243
# [2000]	training's l1: 15.5689	valid_1's l1: 25.6772
# [2200]	training's l1: 14.9033	valid_1's l1: 25.5654
# [2400]	training's l1: 14.3283	valid_1's l1: 25.4512
# [2600]	training's l1: 13.7086	valid_1's l1: 25.3598
# Early stopping, best iteration is:
# [2703]	training's l1: 13.4178	valid_1's l1: 25.3373
# 247
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 35.1585	valid_1's l1: 55.8577
# [400]	training's l1: 25.9684	valid_1's l1: 53.9814
# [600]	training's l1: 22.8817	valid_1's l1: 53.6507
# Early stopping, best iteration is:
# [552]	training's l1: 23.4582	valid_1's l1: 53.5901
# fold: 1, target: Tg, mae: 53.59005453137473
# train rows: 5593, valid rows: 125, ignore rows: 2526
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 33.8611	valid_1's l1: 38.4523
# [400]	training's l1: 25.1908	valid_1's l1: 31.9411
# [600]	training's l1: 22.5268	valid_1's l1: 30.3958
# [800]	training's l1: 21.0213	valid_1's l1: 29.5903
# [1000]	training's l1: 19.8718	valid_1's l1: 28.9969
# [1200]	training's l1: 18.921	valid_1's l1: 28.5203
# [1400]	training's l1: 18.057	valid_1's l1: 28.1395
# [1600]	training's l1: 17.2863	valid_1's l1: 27.788
# [1800]	training's l1: 16.5084	valid_1's l1: 27.4384
# [2000]	training's l1: 15.7928	valid_1's l1: 27.1704
# [2200]	training's l1: 15.1947	valid_1's l1: 26.9863
# [2400]	training's l1: 14.5703	valid_1's l1: 26.8278
# [2600]	training's l1: 14.0469	valid_1's l1: 26.6779
# [2800]	training's l1: 13.5383	valid_1's l1: 26.5489
# [3000]	training's l1: 13.0305	valid_1's l1: 26.4291
# [3200]	training's l1: 12.5442	valid_1's l1: 26.3327
# [3400]	training's l1: 12.1263	valid_1's l1: 26.2542
# [3600]	training's l1: 11.7063	valid_1's l1: 26.1633
# [3800]	training's l1: 11.3256	valid_1's l1: 26.1006
# [4000]	training's l1: 10.9578	valid_1's l1: 26.0365
# [4200]	training's l1: 10.6233	valid_1's l1: 25.961
# [4400]	training's l1: 10.2632	valid_1's l1: 25.8999
# Early stopping, best iteration is:
# [4409]	training's l1: 10.2466	valid_1's l1: 25.8992
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 34.0324	valid_1's l1: 36.5706
# [400]	training's l1: 25.265	valid_1's l1: 30.4786
# [600]	training's l1: 22.6826	valid_1's l1: 29.0812
# [800]	training's l1: 21.2605	valid_1's l1: 28.4712
# [1000]	training's l1: 20.0857	valid_1's l1: 28.0805
# [1200]	training's l1: 19.1515	valid_1's l1: 27.8078
# [1400]	training's l1: 18.2246	valid_1's l1: 27.6207
# [1600]	training's l1: 17.3701	valid_1's l1: 27.4166
# [1800]	training's l1: 16.5804	valid_1's l1: 27.2126
# [2000]	training's l1: 15.8833	valid_1's l1: 27.0724
# [2200]	training's l1: 15.2505	valid_1's l1: 27.0032
# [2400]	training's l1: 14.6364	valid_1's l1: 26.916
# [2600]	training's l1: 14.0904	valid_1's l1: 26.8624
# [2800]	training's l1: 13.5538	valid_1's l1: 26.7791
# Early stopping, best iteration is:
# [2839]	training's l1: 13.461	valid_1's l1: 26.7648
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 34.2133	valid_1's l1: 36.1167
# [400]	training's l1: 25.4583	valid_1's l1: 29.4066
# [600]	training's l1: 22.6645	valid_1's l1: 27.7402
# [800]	training's l1: 21.1187	valid_1's l1: 27.0275
# [1000]	training's l1: 19.8807	valid_1's l1: 26.5743
# [1200]	training's l1: 18.8626	valid_1's l1: 26.1827
# [1400]	training's l1: 17.914	valid_1's l1: 25.8071
# [1600]	training's l1: 17.0251	valid_1's l1: 25.5736
# [1800]	training's l1: 16.195	valid_1's l1: 25.3593
# [2000]	training's l1: 15.4583	valid_1's l1: 25.238
# [2200]	training's l1: 14.8286	valid_1's l1: 25.1631
# [2400]	training's l1: 14.236	valid_1's l1: 25.036
# [2600]	training's l1: 13.6909	valid_1's l1: 24.9094
# [2800]	training's l1: 13.214	valid_1's l1: 24.8685
# [3000]	training's l1: 12.7602	valid_1's l1: 24.8263
# Early stopping, best iteration is:
# [3009]	training's l1: 12.7434	valid_1's l1: 24.8236
# 251
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 36.5517	valid_1's l1: 54.7932
# [400]	training's l1: 27.207	valid_1's l1: 49.9763
# [600]	training's l1: 23.8578	valid_1's l1: 48.9123
# [800]	training's l1: 21.7848	valid_1's l1: 48.308
# [1000]	training's l1: 20.2656	valid_1's l1: 47.997
# Early stopping, best iteration is:
# [1084]	training's l1: 19.729	valid_1's l1: 47.8536
# fold: 2, target: Tg, mae: 47.853578447426955
# RMSE for Tg: 4812.8504
# MAE for Tg: 52.3736
#
# === Training for target: FFV ===
# train rows: 5470, valid rows: 2263, ignore rows: 159
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.009152	valid_1's l1: 0.0105213
# [400]	training's l1: 0.00658807	valid_1's l1: 0.0084073
# [600]	training's l1: 0.00567073	valid_1's l1: 0.00776769
# [800]	training's l1: 0.00510977	valid_1's l1: 0.0073603
# [1000]	training's l1: 0.00472968	valid_1's l1: 0.00709773
# [1200]	training's l1: 0.00443634	valid_1's l1: 0.00693297
# [1400]	training's l1: 0.00420059	valid_1's l1: 0.0067973
# [1600]	training's l1: 0.00401881	valid_1's l1: 0.0066847
# [1800]	training's l1: 0.00385582	valid_1's l1: 0.00660907
# [2000]	training's l1: 0.00370195	valid_1's l1: 0.00653383
# [2200]	training's l1: 0.00356404	valid_1's l1: 0.00647426
# [2400]	training's l1: 0.00343669	valid_1's l1: 0.00642175
# [2600]	training's l1: 0.00332786	valid_1's l1: 0.00637749
# [2800]	training's l1: 0.00321969	valid_1's l1: 0.00633479
# [3000]	training's l1: 0.00310254	valid_1's l1: 0.00629032
# [3200]	training's l1: 0.00298736	valid_1's l1: 0.00625584
# [3400]	training's l1: 0.00287687	valid_1's l1: 0.00622376
# [3600]	training's l1: 0.00278309	valid_1's l1: 0.00618937
# [3800]	training's l1: 0.00268827	valid_1's l1: 0.00616168
# [4000]	training's l1: 0.00259756	valid_1's l1: 0.00613855
# [4200]	training's l1: 0.00250688	valid_1's l1: 0.00611931
# [4400]	training's l1: 0.00242876	valid_1's l1: 0.00610246
# [4600]	training's l1: 0.00234833	valid_1's l1: 0.00609252
# [4800]	training's l1: 0.00227175	valid_1's l1: 0.00607661
# [5000]	training's l1: 0.00220218	valid_1's l1: 0.00606221
# [5200]	training's l1: 0.00213891	valid_1's l1: 0.00605144
# [5400]	training's l1: 0.00208083	valid_1's l1: 0.00604174
# [5600]	training's l1: 0.00201886	valid_1's l1: 0.00603447
# [5800]	training's l1: 0.00195739	valid_1's l1: 0.00602474
# [6000]	training's l1: 0.0018984	valid_1's l1: 0.00601553
# [6200]	training's l1: 0.00184093	valid_1's l1: 0.0060075
# Early stopping, best iteration is:
# [6216]	training's l1: 0.00183739	valid_1's l1: 0.00600713
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.00918978	valid_1's l1: 0.0100215
# [400]	training's l1: 0.00672085	valid_1's l1: 0.00803168
# [600]	training's l1: 0.00579481	valid_1's l1: 0.0073898
# [800]	training's l1: 0.00523761	valid_1's l1: 0.00701171
# [1000]	training's l1: 0.00479995	valid_1's l1: 0.0067197
# [1200]	training's l1: 0.00447714	valid_1's l1: 0.00657608
# [1400]	training's l1: 0.00422815	valid_1's l1: 0.0064713
# [1600]	training's l1: 0.00401967	valid_1's l1: 0.0063877
# [1800]	training's l1: 0.00385522	valid_1's l1: 0.00632673
# [2000]	training's l1: 0.00369567	valid_1's l1: 0.00625873
# [2200]	training's l1: 0.00355221	valid_1's l1: 0.00620745
# [2400]	training's l1: 0.00338661	valid_1's l1: 0.00613355
# [2600]	training's l1: 0.00325749	valid_1's l1: 0.00609118
# [2800]	training's l1: 0.00313088	valid_1's l1: 0.00604472
# [3000]	training's l1: 0.00300887	valid_1's l1: 0.00600597
# [3200]	training's l1: 0.00289617	valid_1's l1: 0.00597519
# [3400]	training's l1: 0.00280157	valid_1's l1: 0.00594824
# [3600]	training's l1: 0.00270321	valid_1's l1: 0.00592186
# [3800]	training's l1: 0.00261054	valid_1's l1: 0.00590514
# [4000]	training's l1: 0.0025213	valid_1's l1: 0.00587839
# [4200]	training's l1: 0.00243983	valid_1's l1: 0.0058584
# [4400]	training's l1: 0.00235896	valid_1's l1: 0.00583855
# Early stopping, best iteration is:
# [4511]	training's l1: 0.00231495	valid_1's l1: 0.00582685
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.00901121	valid_1's l1: 0.0121225
# [400]	training's l1: 0.00648731	valid_1's l1: 0.00973989
# [600]	training's l1: 0.00548525	valid_1's l1: 0.00894379
# [800]	training's l1: 0.0049324	valid_1's l1: 0.00848677
# [1000]	training's l1: 0.0046048	valid_1's l1: 0.00820836
# [1200]	training's l1: 0.0043477	valid_1's l1: 0.00800843
# [1400]	training's l1: 0.00412445	valid_1's l1: 0.00786155
# [1600]	training's l1: 0.00393283	valid_1's l1: 0.00774652
# [1800]	training's l1: 0.00376288	valid_1's l1: 0.00765228
# [2000]	training's l1: 0.00361638	valid_1's l1: 0.0075658
# [2200]	training's l1: 0.00347938	valid_1's l1: 0.00748559
# [2400]	training's l1: 0.00336523	valid_1's l1: 0.00742735
# [2600]	training's l1: 0.00325592	valid_1's l1: 0.00737801
# [2800]	training's l1: 0.0031548	valid_1's l1: 0.00733588
# [3000]	training's l1: 0.00304964	valid_1's l1: 0.00728552
# [3200]	training's l1: 0.00295447	valid_1's l1: 0.00724413
# [3400]	training's l1: 0.00286065	valid_1's l1: 0.00720915
# [3600]	training's l1: 0.00277891	valid_1's l1: 0.00718055
# [3800]	training's l1: 0.00269946	valid_1's l1: 0.00715103
# [4000]	training's l1: 0.00261791	valid_1's l1: 0.00713087
# [4200]	training's l1: 0.00253362	valid_1's l1: 0.0071116
# [4400]	training's l1: 0.00245324	valid_1's l1: 0.00708535
# [4600]	training's l1: 0.00237327	valid_1's l1: 0.0070578
# [4800]	training's l1: 0.0023051	valid_1's l1: 0.00703735
# [5000]	training's l1: 0.00222985	valid_1's l1: 0.00701744
# [5200]	training's l1: 0.00216291	valid_1's l1: 0.00700209
# [5400]	training's l1: 0.00209763	valid_1's l1: 0.00698461
# [5600]	training's l1: 0.00203295	valid_1's l1: 0.0069654
# [5800]	training's l1: 0.00197463	valid_1's l1: 0.00695077
# [6000]	training's l1: 0.00191245	valid_1's l1: 0.00693433
# [6200]	training's l1: 0.00184727	valid_1's l1: 0.00691957
# [6400]	training's l1: 0.00178751	valid_1's l1: 0.00690781
# [6600]	training's l1: 0.00173053	valid_1's l1: 0.00689374
# [6800]	training's l1: 0.00167682	valid_1's l1: 0.00688605
# [7000]	training's l1: 0.00162748	valid_1's l1: 0.00688049
# [7200]	training's l1: 0.00158197	valid_1's l1: 0.00687247
# [7400]	training's l1: 0.00153759	valid_1's l1: 0.00686661
# Early stopping, best iteration is:
# [7505]	training's l1: 0.00151745	valid_1's l1: 0.00686097
# 251
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.00822959	valid_1's l1: 0.0129232
# [400]	training's l1: 0.00591963	valid_1's l1: 0.0115071
# [600]	training's l1: 0.00517876	valid_1's l1: 0.011164
# [800]	training's l1: 0.00476158	valid_1's l1: 0.0110443
# [1000]	training's l1: 0.00447629	valid_1's l1: 0.0109292
# [1200]	training's l1: 0.00423999	valid_1's l1: 0.0107927
# [1400]	training's l1: 0.00403328	valid_1's l1: 0.0107127
# Early stopping, best iteration is:
# [1397]	training's l1: 0.00403657	valid_1's l1: 0.0107102
# fold: 0, target: FFV, mae: 0.010710244225019748
# train rows: 5224, valid rows: 2373, ignore rows: 295
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.00915211	valid_1's l1: 0.00992144
# [400]	training's l1: 0.00663523	valid_1's l1: 0.0078377
# [600]	training's l1: 0.00567817	valid_1's l1: 0.00708715
# [800]	training's l1: 0.00512534	valid_1's l1: 0.00675005
# [1000]	training's l1: 0.00475687	valid_1's l1: 0.00653304
# [1200]	training's l1: 0.00450022	valid_1's l1: 0.00640978
# [1400]	training's l1: 0.00427286	valid_1's l1: 0.00631302
# [1600]	training's l1: 0.00407855	valid_1's l1: 0.0062265
# [1800]	training's l1: 0.00390092	valid_1's l1: 0.00615696
# [2000]	training's l1: 0.00375369	valid_1's l1: 0.00609918
# [2200]	training's l1: 0.00361656	valid_1's l1: 0.00604276
# [2400]	training's l1: 0.00349532	valid_1's l1: 0.00600828
# [2600]	training's l1: 0.00337604	valid_1's l1: 0.00596686
# [2800]	training's l1: 0.00327347	valid_1's l1: 0.00593451
# [3000]	training's l1: 0.00317248	valid_1's l1: 0.00590664
# [3200]	training's l1: 0.00307591	valid_1's l1: 0.00587188
# [3400]	training's l1: 0.00298461	valid_1's l1: 0.00584975
# [3600]	training's l1: 0.00289419	valid_1's l1: 0.00581945
# [3800]	training's l1: 0.00281932	valid_1's l1: 0.00580288
# [4000]	training's l1: 0.00274717	valid_1's l1: 0.0057822
# [4200]	training's l1: 0.00268	valid_1's l1: 0.0057687
# [4400]	training's l1: 0.00260608	valid_1's l1: 0.00574788
# [4600]	training's l1: 0.002538	valid_1's l1: 0.00573201
# [4800]	training's l1: 0.00247168	valid_1's l1: 0.00571744
# [5000]	training's l1: 0.00240132	valid_1's l1: 0.00569905
# [5200]	training's l1: 0.00233677	valid_1's l1: 0.00568229
# [5400]	training's l1: 0.0022801	valid_1's l1: 0.00566571
# [5600]	training's l1: 0.00222992	valid_1's l1: 0.0056564
# [5800]	training's l1: 0.00217851	valid_1's l1: 0.00564357
# [6000]	training's l1: 0.00212364	valid_1's l1: 0.00563558
# [6200]	training's l1: 0.00207358	valid_1's l1: 0.00562352
# [6400]	training's l1: 0.00201489	valid_1's l1: 0.00560991
# [6600]	training's l1: 0.00196133	valid_1's l1: 0.00560377
# [6800]	training's l1: 0.00190483	valid_1's l1: 0.00559108
# [7000]	training's l1: 0.0018608	valid_1's l1: 0.00558133
# [7200]	training's l1: 0.00181258	valid_1's l1: 0.00557422
# Early stopping, best iteration is:
# [7168]	training's l1: 0.00182082	valid_1's l1: 0.00557352
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.00913833	valid_1's l1: 0.0104607
# [400]	training's l1: 0.00659448	valid_1's l1: 0.00871424
# [600]	training's l1: 0.00566931	valid_1's l1: 0.00811485
# [800]	training's l1: 0.00511527	valid_1's l1: 0.00777715
# [1000]	training's l1: 0.00473949	valid_1's l1: 0.0075708
# [1200]	training's l1: 0.00446256	valid_1's l1: 0.00745511
# [1400]	training's l1: 0.00423966	valid_1's l1: 0.0073613
# [1600]	training's l1: 0.00405017	valid_1's l1: 0.00726396
# [1800]	training's l1: 0.00387198	valid_1's l1: 0.00717196
# [2000]	training's l1: 0.00371545	valid_1's l1: 0.00711437
# [2200]	training's l1: 0.00357199	valid_1's l1: 0.00706955
# [2400]	training's l1: 0.00343472	valid_1's l1: 0.00703559
# [2600]	training's l1: 0.00331119	valid_1's l1: 0.00699638
# [2800]	training's l1: 0.00320165	valid_1's l1: 0.0069579
# [3000]	training's l1: 0.003091	valid_1's l1: 0.0069301
# [3200]	training's l1: 0.00298255	valid_1's l1: 0.00689602
# [3400]	training's l1: 0.00287895	valid_1's l1: 0.00687396
# [3600]	training's l1: 0.00278522	valid_1's l1: 0.00685977
# [3800]	training's l1: 0.00269223	valid_1's l1: 0.00683598
# [4000]	training's l1: 0.0026153	valid_1's l1: 0.00682059
# [4200]	training's l1: 0.0025336	valid_1's l1: 0.00680717
# [4400]	training's l1: 0.00245847	valid_1's l1: 0.00679535
# [4600]	training's l1: 0.00238382	valid_1's l1: 0.00677909
# [4800]	training's l1: 0.00230937	valid_1's l1: 0.00677173
# [5000]	training's l1: 0.00224571	valid_1's l1: 0.00676285
# [5200]	training's l1: 0.00218387	valid_1's l1: 0.0067489
# [5400]	training's l1: 0.00211793	valid_1's l1: 0.00673996
# [5600]	training's l1: 0.00205208	valid_1's l1: 0.00672873
# [5800]	training's l1: 0.00199614	valid_1's l1: 0.00672122
# Early stopping, best iteration is:
# [5926]	training's l1: 0.00195562	valid_1's l1: 0.00671534
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.00912459	valid_1's l1: 0.0108078
# [400]	training's l1: 0.00656893	valid_1's l1: 0.00886749
# [600]	training's l1: 0.00562642	valid_1's l1: 0.00822825
# [800]	training's l1: 0.00506059	valid_1's l1: 0.00785674
# [1000]	training's l1: 0.00465071	valid_1's l1: 0.00761763
# [1200]	training's l1: 0.00438193	valid_1's l1: 0.00746679
# [1400]	training's l1: 0.00415487	valid_1's l1: 0.00735438
# [1600]	training's l1: 0.00395366	valid_1's l1: 0.0072718
# [1800]	training's l1: 0.00376835	valid_1's l1: 0.00719108
# [2000]	training's l1: 0.0035944	valid_1's l1: 0.00712611
# [2200]	training's l1: 0.0034296	valid_1's l1: 0.00707497
# [2400]	training's l1: 0.00327915	valid_1's l1: 0.00701817
# [2600]	training's l1: 0.00315284	valid_1's l1: 0.00696279
# [2800]	training's l1: 0.00302993	valid_1's l1: 0.00690773
# [3000]	training's l1: 0.00292097	valid_1's l1: 0.00687669
# [3200]	training's l1: 0.00282165	valid_1's l1: 0.00684623
# [3400]	training's l1: 0.00272704	valid_1's l1: 0.00681703
# [3600]	training's l1: 0.00263762	valid_1's l1: 0.00678979
# [3800]	training's l1: 0.0025618	valid_1's l1: 0.00677655
# [4000]	training's l1: 0.00248507	valid_1's l1: 0.00676109
# [4200]	training's l1: 0.00240983	valid_1's l1: 0.00674336
# [4400]	training's l1: 0.00234239	valid_1's l1: 0.00673212
# [4600]	training's l1: 0.00227583	valid_1's l1: 0.00672025
# [4800]	training's l1: 0.0022045	valid_1's l1: 0.00670674
# [5000]	training's l1: 0.00213716	valid_1's l1: 0.00669447
# [5200]	training's l1: 0.00207404	valid_1's l1: 0.00668621
# Early stopping, best iteration is:
# [5178]	training's l1: 0.00208034	valid_1's l1: 0.00668539
# 253
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.00891548	valid_1's l1: 0.0109678
# [400]	training's l1: 0.00646638	valid_1's l1: 0.00937538
# [600]	training's l1: 0.00554318	valid_1's l1: 0.00886827
# [800]	training's l1: 0.00497924	valid_1's l1: 0.00859951
# [1000]	training's l1: 0.00457614	valid_1's l1: 0.00841507
# [1200]	training's l1: 0.00425992	valid_1's l1: 0.00827411
# [1400]	training's l1: 0.00400288	valid_1's l1: 0.00817748
# [1600]	training's l1: 0.00379445	valid_1's l1: 0.00809174
# [1800]	training's l1: 0.00360833	valid_1's l1: 0.00802889
# [2000]	training's l1: 0.00343704	valid_1's l1: 0.00796773
# [2200]	training's l1: 0.00329323	valid_1's l1: 0.0079208
# [2400]	training's l1: 0.00316655	valid_1's l1: 0.00788709
# [2600]	training's l1: 0.00304919	valid_1's l1: 0.00785339
# [2800]	training's l1: 0.00294266	valid_1's l1: 0.00782653
# [3000]	training's l1: 0.00284283	valid_1's l1: 0.00780043
# [3200]	training's l1: 0.00274599	valid_1's l1: 0.00777891
# [3400]	training's l1: 0.00265622	valid_1's l1: 0.00775875
# [3600]	training's l1: 0.00256405	valid_1's l1: 0.00774299
# [3800]	training's l1: 0.00247584	valid_1's l1: 0.00772704
# [4000]	training's l1: 0.00239422	valid_1's l1: 0.0077156
# [4200]	training's l1: 0.00229433	valid_1's l1: 0.00769858
# [4400]	training's l1: 0.00220553	valid_1's l1: 0.00768586
# [4600]	training's l1: 0.00212408	valid_1's l1: 0.00767649
# [4800]	training's l1: 0.00204844	valid_1's l1: 0.00766685
# [5000]	training's l1: 0.00197417	valid_1's l1: 0.00765972
# [5200]	training's l1: 0.00192376	valid_1's l1: 0.00765236
# [5400]	training's l1: 0.00186301	valid_1's l1: 0.00764529
# Early stopping, best iteration is:
# [5445]	training's l1: 0.00184976	valid_1's l1: 0.00764409
# fold: 1, target: FFV, mae: 0.007644087808332536
# train rows: 5090, valid rows: 2394, ignore rows: 408
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.00921964	valid_1's l1: 0.00980818
# [400]	training's l1: 0.00659732	valid_1's l1: 0.00768818
# [600]	training's l1: 0.00566065	valid_1's l1: 0.00707712
# [800]	training's l1: 0.00509336	valid_1's l1: 0.00677835
# [1000]	training's l1: 0.00472741	valid_1's l1: 0.00660661
# [1200]	training's l1: 0.00446211	valid_1's l1: 0.00650808
# [1400]	training's l1: 0.00423109	valid_1's l1: 0.00640892
# [1600]	training's l1: 0.0040456	valid_1's l1: 0.00633223
# [1800]	training's l1: 0.00388666	valid_1's l1: 0.00626169
# [2000]	training's l1: 0.0037514	valid_1's l1: 0.00620333
# [2200]	training's l1: 0.00362524	valid_1's l1: 0.00614722
# [2400]	training's l1: 0.00350168	valid_1's l1: 0.00609652
# [2600]	training's l1: 0.00338892	valid_1's l1: 0.00605182
# [2800]	training's l1: 0.00327872	valid_1's l1: 0.00600453
# [3000]	training's l1: 0.0031782	valid_1's l1: 0.00597701
# [3200]	training's l1: 0.00308734	valid_1's l1: 0.00595321
# [3400]	training's l1: 0.00299829	valid_1's l1: 0.00592914
# [3600]	training's l1: 0.00291281	valid_1's l1: 0.00590962
# [3800]	training's l1: 0.00282817	valid_1's l1: 0.00588964
# [4000]	training's l1: 0.00275313	valid_1's l1: 0.00586257
# [4200]	training's l1: 0.00268181	valid_1's l1: 0.00584207
# [4400]	training's l1: 0.00261076	valid_1's l1: 0.00581943
# [4600]	training's l1: 0.00254045	valid_1's l1: 0.00580979
# [4800]	training's l1: 0.0024722	valid_1's l1: 0.00579539
# Early stopping, best iteration is:
# [4878]	training's l1: 0.00244816	valid_1's l1: 0.00579346
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.00913536	valid_1's l1: 0.0102043
# [400]	training's l1: 0.00648936	valid_1's l1: 0.00833036
# [600]	training's l1: 0.00550327	valid_1's l1: 0.00779733
# [800]	training's l1: 0.00496891	valid_1's l1: 0.00751361
# [1000]	training's l1: 0.00459998	valid_1's l1: 0.00734338
# [1200]	training's l1: 0.00433025	valid_1's l1: 0.00723498
# [1400]	training's l1: 0.00410667	valid_1's l1: 0.00715649
# [1600]	training's l1: 0.00390243	valid_1's l1: 0.00706381
# [1800]	training's l1: 0.00373195	valid_1's l1: 0.00701152
# [2000]	training's l1: 0.00357261	valid_1's l1: 0.0069556
# [2200]	training's l1: 0.00343096	valid_1's l1: 0.00692315
# [2400]	training's l1: 0.00331037	valid_1's l1: 0.00688952
# [2600]	training's l1: 0.0032017	valid_1's l1: 0.00684784
# [2800]	training's l1: 0.00310494	valid_1's l1: 0.00681333
# [3000]	training's l1: 0.00301022	valid_1's l1: 0.0067869
# [3200]	training's l1: 0.00292323	valid_1's l1: 0.00676561
# [3400]	training's l1: 0.0028461	valid_1's l1: 0.00674615
# [3600]	training's l1: 0.00277399	valid_1's l1: 0.00671874
# [3800]	training's l1: 0.00270065	valid_1's l1: 0.00669757
# [4000]	training's l1: 0.00263929	valid_1's l1: 0.00668072
# [4200]	training's l1: 0.00257816	valid_1's l1: 0.00666323
# [4400]	training's l1: 0.00251845	valid_1's l1: 0.00664829
# [4600]	training's l1: 0.00246591	valid_1's l1: 0.00663429
# [4800]	training's l1: 0.00240982	valid_1's l1: 0.00662696
# [5000]	training's l1: 0.00235576	valid_1's l1: 0.00661858
# [5200]	training's l1: 0.00229481	valid_1's l1: 0.00660919
# [5400]	training's l1: 0.0022413	valid_1's l1: 0.0065987
# [5600]	training's l1: 0.0021876	valid_1's l1: 0.00658733
# [5800]	training's l1: 0.00213484	valid_1's l1: 0.00657696
# [6000]	training's l1: 0.00208367	valid_1's l1: 0.0065699
# Early stopping, best iteration is:
# [6098]	training's l1: 0.00205573	valid_1's l1: 0.00656489
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.00919133	valid_1's l1: 0.00988993
# [400]	training's l1: 0.00665375	valid_1's l1: 0.00758131
# [600]	training's l1: 0.0057144	valid_1's l1: 0.00693781
# [800]	training's l1: 0.00518962	valid_1's l1: 0.00664906
# [1000]	training's l1: 0.00482791	valid_1's l1: 0.00647562
# [1200]	training's l1: 0.00456444	valid_1's l1: 0.00636278
# [1400]	training's l1: 0.00434473	valid_1's l1: 0.00627216
# [1600]	training's l1: 0.00414437	valid_1's l1: 0.00618884
# [1800]	training's l1: 0.00396611	valid_1's l1: 0.00612151
# [2000]	training's l1: 0.00380998	valid_1's l1: 0.00606839
# [2200]	training's l1: 0.00367918	valid_1's l1: 0.00603197
# [2400]	training's l1: 0.00355594	valid_1's l1: 0.00600275
# [2600]	training's l1: 0.00344116	valid_1's l1: 0.00597366
# [2800]	training's l1: 0.00334351	valid_1's l1: 0.00595431
# [3000]	training's l1: 0.00324633	valid_1's l1: 0.00593712
# [3200]	training's l1: 0.00315166	valid_1's l1: 0.00591745
# [3400]	training's l1: 0.00306658	valid_1's l1: 0.00589869
# [3600]	training's l1: 0.00298201	valid_1's l1: 0.00588237
# [3800]	training's l1: 0.00289902	valid_1's l1: 0.00586847
# [4000]	training's l1: 0.00281976	valid_1's l1: 0.00585633
# [4200]	training's l1: 0.00274543	valid_1's l1: 0.00584978
# [4400]	training's l1: 0.00267605	valid_1's l1: 0.00583892
# Early stopping, best iteration is:
# [4522]	training's l1: 0.0026377	valid_1's l1: 0.00583288
# 251
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0093049	valid_1's l1: 0.00982438
# [400]	training's l1: 0.00671447	valid_1's l1: 0.00801662
# [600]	training's l1: 0.00572218	valid_1's l1: 0.00737032
# [800]	training's l1: 0.00513118	valid_1's l1: 0.00705982
# [1000]	training's l1: 0.00470568	valid_1's l1: 0.00686269
# [1200]	training's l1: 0.00439906	valid_1's l1: 0.00672295
# [1400]	training's l1: 0.00412558	valid_1's l1: 0.00661864
# [1600]	training's l1: 0.00389551	valid_1's l1: 0.00652522
# [1800]	training's l1: 0.00369162	valid_1's l1: 0.00644647
# [2000]	training's l1: 0.00351976	valid_1's l1: 0.00639407
# [2200]	training's l1: 0.00338145	valid_1's l1: 0.00634599
# [2400]	training's l1: 0.00324885	valid_1's l1: 0.00630376
# [2600]	training's l1: 0.00311337	valid_1's l1: 0.00626503
# [2800]	training's l1: 0.00298625	valid_1's l1: 0.0062396
# [3000]	training's l1: 0.00288052	valid_1's l1: 0.00622206
# [3200]	training's l1: 0.00277372	valid_1's l1: 0.00619912
# [3400]	training's l1: 0.00267842	valid_1's l1: 0.00618489
# [3600]	training's l1: 0.00257386	valid_1's l1: 0.00616442
# [3800]	training's l1: 0.00247557	valid_1's l1: 0.00614336
# [4000]	training's l1: 0.00238951	valid_1's l1: 0.00613269
# [4200]	training's l1: 0.00230736	valid_1's l1: 0.0061208
# [4400]	training's l1: 0.0022351	valid_1's l1: 0.00611502
# [4600]	training's l1: 0.00215282	valid_1's l1: 0.00610666
# [4800]	training's l1: 0.00207908	valid_1's l1: 0.00610116
# [5000]	training's l1: 0.00201045	valid_1's l1: 0.00609358
# [5200]	training's l1: 0.00194499	valid_1's l1: 0.00608407
# [5400]	training's l1: 0.00188879	valid_1's l1: 0.0060776
# Early stopping, best iteration is:
# [5463]	training's l1: 0.00187133	valid_1's l1: 0.00607605
# fold: 2, target: FFV, mae: 0.00607604695840606
# RMSE for FFV: 0.0002
# MAE for FFV: 0.0081
#
# === Training for target: Tc ===
# train rows: 392, valid rows: 436, ignore rows: 38
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.024497	valid_1's l1: 0.028943
# [400]	training's l1: 0.0171679	valid_1's l1: 0.0241034
# Early stopping, best iteration is:
# [418]	training's l1: 0.0168958	valid_1's l1: 0.0240467
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0237534	valid_1's l1: 0.0338217
# [400]	training's l1: 0.0163951	valid_1's l1: 0.0320925
# Early stopping, best iteration is:
# [415]	training's l1: 0.0161635	valid_1's l1: 0.0320557
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0241059	valid_1's l1: 0.032503
# Early stopping, best iteration is:
# [340]	training's l1: 0.0177615	valid_1's l1: 0.0309065
# 252
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0292644	valid_1's l1: 0.0343734
# [400]	training's l1: 0.0233353	valid_1's l1: 0.032868
# [600]	training's l1: 0.0201979	valid_1's l1: 0.0324106
# [800]	training's l1: 0.0179797	valid_1's l1: 0.0321702
# [1000]	training's l1: 0.0164299	valid_1's l1: 0.0317298
# Early stopping, best iteration is:
# [1068]	training's l1: 0.0160169	valid_1's l1: 0.0316654
# fold: 0, target: Tc, mae: 0.03166536701083254
# train rows: 640, valid rows: 187, ignore rows: 39
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0230863	valid_1's l1: 0.0306524
# [400]	training's l1: 0.016521	valid_1's l1: 0.0255865
# Early stopping, best iteration is:
# [457]	training's l1: 0.0158276	valid_1's l1: 0.025466
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0231097	valid_1's l1: 0.0269572
# [400]	training's l1: 0.0166076	valid_1's l1: 0.0254529
# Early stopping, best iteration is:
# [352]	training's l1: 0.0173724	valid_1's l1: 0.0253597
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0225362	valid_1's l1: 0.0340403
# [400]	training's l1: 0.0159417	valid_1's l1: 0.0298252
# [600]	training's l1: 0.0142547	valid_1's l1: 0.0291026
# [800]	training's l1: 0.0130328	valid_1's l1: 0.0288533
# Early stopping, best iteration is:
# [917]	training's l1: 0.0123833	valid_1's l1: 0.028788
# 241
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0262165	valid_1's l1: 0.0373702
# [400]	training's l1: 0.0199931	valid_1's l1: 0.0312168
# [600]	training's l1: 0.0179466	valid_1's l1: 0.0301163
# [800]	training's l1: 0.0166526	valid_1's l1: 0.0297335
# Early stopping, best iteration is:
# [809]	training's l1: 0.0166129	valid_1's l1: 0.029694
# fold: 1, target: Tc, mae: 0.029694049566920403
# train rows: 700, valid rows: 114, ignore rows: 52
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0226025	valid_1's l1: 0.0261049
# [400]	training's l1: 0.016208	valid_1's l1: 0.0243684
# [600]	training's l1: 0.0143989	valid_1's l1: 0.0239536
# [800]	training's l1: 0.013255	valid_1's l1: 0.0236998
# [1000]	training's l1: 0.0123081	valid_1's l1: 0.0235706
# Early stopping, best iteration is:
# [991]	training's l1: 0.0123544	valid_1's l1: 0.0235369
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0223358	valid_1's l1: 0.0266673
# Early stopping, best iteration is:
# [237]	training's l1: 0.020167	valid_1's l1: 0.0264153
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0224353	valid_1's l1: 0.0301775
# Early stopping, best iteration is:
# [285]	training's l1: 0.0184675	valid_1's l1: 0.0294529
# 246
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0223051	valid_1's l1: 0.0475057
# [400]	training's l1: 0.0160387	valid_1's l1: 0.0440699
# Early stopping, best iteration is:
# [433]	training's l1: 0.0156666	valid_1's l1: 0.0439567
# fold: 2, target: Tc, mae: 0.04395667465951433
# RMSE for Tc: 0.0022
# MAE for Tc: 0.0331
#
# === Training for target: Density ===
# train rows: 639, valid rows: 340, ignore rows: 267
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0329306	valid_1's l1: 0.0286745
# [400]	training's l1: 0.0212895	valid_1's l1: 0.0255107
# [600]	training's l1: 0.0182273	valid_1's l1: 0.0248571
# [800]	training's l1: 0.016391	valid_1's l1: 0.0242061
# [1000]	training's l1: 0.014848	valid_1's l1: 0.0237562
# [1200]	training's l1: 0.0136495	valid_1's l1: 0.0233793
# [1400]	training's l1: 0.0126524	valid_1's l1: 0.0231877
# [1600]	training's l1: 0.0117711	valid_1's l1: 0.0229247
# [1800]	training's l1: 0.01096	valid_1's l1: 0.0228032
# Early stopping, best iteration is:
# [1897]	training's l1: 0.0106056	valid_1's l1: 0.0227177
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0323418	valid_1's l1: 0.0372563
# [400]	training's l1: 0.020765	valid_1's l1: 0.0325248
# Early stopping, best iteration is:
# [352]	training's l1: 0.0219395	valid_1's l1: 0.0323901
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0327517	valid_1's l1: 0.0321164
# [400]	training's l1: 0.0210418	valid_1's l1: 0.0257304
# [600]	training's l1: 0.0178827	valid_1's l1: 0.0248218
# [800]	training's l1: 0.015998	valid_1's l1: 0.0240276
# [1000]	training's l1: 0.0146003	valid_1's l1: 0.0235077
# [1200]	training's l1: 0.0134543	valid_1's l1: 0.0229178
# [1400]	training's l1: 0.0125466	valid_1's l1: 0.0223382
# [1600]	training's l1: 0.0116892	valid_1's l1: 0.0218345
# [1800]	training's l1: 0.0108247	valid_1's l1: 0.0214697
# [2000]	training's l1: 0.00994798	valid_1's l1: 0.0210354
# [2200]	training's l1: 0.00920626	valid_1's l1: 0.0207441
# [2400]	training's l1: 0.00848116	valid_1's l1: 0.0204627
# [2600]	training's l1: 0.00785124	valid_1's l1: 0.020259
# [2800]	training's l1: 0.00723064	valid_1's l1: 0.0201462
# [3000]	training's l1: 0.00668623	valid_1's l1: 0.0199721
# [3200]	training's l1: 0.00616921	valid_1's l1: 0.0198938
# Early stopping, best iteration is:
# [3322]	training's l1: 0.00585831	valid_1's l1: 0.0198379
# 230
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0378596	valid_1's l1: 0.0806196
# [400]	training's l1: 0.021482	valid_1's l1: 0.0650691
# [600]	training's l1: 0.0176546	valid_1's l1: 0.0635112
# Early stopping, best iteration is:
# [557]	training's l1: 0.0183021	valid_1's l1: 0.0634032
# fold: 0, target: Density, mae: 0.06340322006913826
# train rows: 884, valid rows: 155, ignore rows: 207
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0332457	valid_1's l1: 0.0379683
# Early stopping, best iteration is:
# [348]	training's l1: 0.0229339	valid_1's l1: 0.0310991
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0339798	valid_1's l1: 0.0428094
# [400]	training's l1: 0.0230209	valid_1's l1: 0.0333611
# [600]	training's l1: 0.0197671	valid_1's l1: 0.0306817
# [800]	training's l1: 0.017891	valid_1's l1: 0.0299846
# [1000]	training's l1: 0.0163814	valid_1's l1: 0.0297896
# Early stopping, best iteration is:
# [962]	training's l1: 0.0166274	valid_1's l1: 0.0297307
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0325321	valid_1's l1: 0.0467789
# [400]	training's l1: 0.0210352	valid_1's l1: 0.0397304
# [600]	training's l1: 0.0178456	valid_1's l1: 0.037154
# [800]	training's l1: 0.0161583	valid_1's l1: 0.0367814
# Early stopping, best iteration is:
# [775]	training's l1: 0.0163674	valid_1's l1: 0.036763
# 232
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0422095	valid_1's l1: 0.0452937
# [400]	training's l1: 0.023104	valid_1's l1: 0.0412362
# Early stopping, best iteration is:
# [407]	training's l1: 0.022916	valid_1's l1: 0.0411786
# fold: 1, target: Density, mae: 0.041178579980462544
# train rows: 969, valid rows: 118, ignore rows: 159
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0342814	valid_1's l1: 0.0486345
# [400]	training's l1: 0.0221079	valid_1's l1: 0.040967
# [600]	training's l1: 0.019288	valid_1's l1: 0.0381967
# [800]	training's l1: 0.0175902	valid_1's l1: 0.0369897
# [1000]	training's l1: 0.016058	valid_1's l1: 0.0361944
# [1200]	training's l1: 0.0147638	valid_1's l1: 0.0358571
# Early stopping, best iteration is:
# [1241]	training's l1: 0.0145207	valid_1's l1: 0.0358006
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0343264	valid_1's l1: 0.0522384
# [400]	training's l1: 0.0218597	valid_1's l1: 0.0442279
# [600]	training's l1: 0.0189176	valid_1's l1: 0.0429975
# [800]	training's l1: 0.0170547	valid_1's l1: 0.0418489
# Early stopping, best iteration is:
# [835]	training's l1: 0.0167876	valid_1's l1: 0.0417315
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0346676	valid_1's l1: 0.053082
# [400]	training's l1: 0.0227321	valid_1's l1: 0.0379919
# [600]	training's l1: 0.0198805	valid_1's l1: 0.0341688
# [800]	training's l1: 0.0179756	valid_1's l1: 0.0323683
# [1000]	training's l1: 0.0163852	valid_1's l1: 0.0315756
# [1200]	training's l1: 0.014943	valid_1's l1: 0.0311134
# [1400]	training's l1: 0.0138347	valid_1's l1: 0.0308638
# Early stopping, best iteration is:
# [1474]	training's l1: 0.0134621	valid_1's l1: 0.0308116
# 242
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 0.0401183	valid_1's l1: 0.059457
# [400]	training's l1: 0.0228396	valid_1's l1: 0.0570946
# [600]	training's l1: 0.019485	valid_1's l1: 0.0552702
# Early stopping, best iteration is:
# [644]	training's l1: 0.018968	valid_1's l1: 0.0551399
# fold: 2, target: Density, mae: 0.055139862757440455
# RMSE for Density: 0.0098
# MAE for Density: 0.0562
#
# === Training for target: Rg ===
# train rows: 272, valid rows: 342, ignore rows: 0
# fold: 1
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.50622	valid_1's l1: 1.792
# Early stopping, best iteration is:
# [283]	training's l1: 1.26729	valid_1's l1: 1.72267
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.51775	valid_1's l1: 1.61413
# Early stopping, best iteration is:
# [304]	training's l1: 1.22607	valid_1's l1: 1.52379
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.45327	valid_1's l1: 2.05659
# Early stopping, best iteration is:
# [202]	training's l1: 1.44634	valid_1's l1: 2.0547
# 253
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.46849	valid_1's l1: 2.33129
# [400]	training's l1: 1.03001	valid_1's l1: 2.02256
# [600]	training's l1: 0.817005	valid_1's l1: 1.98332
# Early stopping, best iteration is:
# [652]	training's l1: 0.772711	valid_1's l1: 1.97928
# fold: 0, target: Rg, mae: 1.9792790797294133
# train rows: 459, valid rows: 155, ignore rows: 0
# fold: 2
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.34695	valid_1's l1: 2.16038
# Early stopping, best iteration is:
# [329]	training's l1: 1.04188	valid_1's l1: 2.03044
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.39293	valid_1's l1: 1.65171
# [400]	training's l1: 1.02092	valid_1's l1: 1.46108
# Early stopping, best iteration is:
# [373]	training's l1: 1.05011	valid_1's l1: 1.45675
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.40569	valid_1's l1: 1.61329
# [400]	training's l1: 1.01972	valid_1's l1: 1.51762
# [600]	training's l1: 0.871237	valid_1's l1: 1.49459
# Early stopping, best iteration is:
# [646]	training's l1: 0.841732	valid_1's l1: 1.4887
# 247
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.41165	valid_1's l1: 1.88566
# [400]	training's l1: 1.01902	valid_1's l1: 1.70725
# Early stopping, best iteration is:
# [409]	training's l1: 1.01153	valid_1's l1: 1.70507
# fold: 1, target: Rg, mae: 1.7050661132384257
# train rows: 497, valid rows: 117, ignore rows: 0
# fold: 3
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.36551	valid_1's l1: 1.98754
# [400]	training's l1: 1.00068	valid_1's l1: 1.85368
# [600]	training's l1: 0.841342	valid_1's l1: 1.8139
# [800]	training's l1: 0.721911	valid_1's l1: 1.80148
# Early stopping, best iteration is:
# [816]	training's l1: 0.714816	valid_1's l1: 1.79966
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.36684	valid_1's l1: 2.16277
# [400]	training's l1: 1.03145	valid_1's l1: 1.92368
# [600]	training's l1: 0.884876	valid_1's l1: 1.87633
# [800]	training's l1: 0.775813	valid_1's l1: 1.83289
# [1000]	training's l1: 0.68811	valid_1's l1: 1.79821
# [1200]	training's l1: 0.625668	valid_1's l1: 1.7762
# [1400]	training's l1: 0.569274	valid_1's l1: 1.75549
# [1600]	training's l1: 0.520614	valid_1's l1: 1.74038
# [1800]	training's l1: 0.477112	valid_1's l1: 1.73405
# [2000]	training's l1: 0.437683	valid_1's l1: 1.72665
# [2200]	training's l1: 0.402952	valid_1's l1: 1.71711
# Early stopping, best iteration is:
# [2295]	training's l1: 0.389027	valid_1's l1: 1.7143
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.35847	valid_1's l1: 1.95772
# [400]	training's l1: 0.996961	valid_1's l1: 1.83434
# Early stopping, best iteration is:
# [451]	training's l1: 0.95179	valid_1's l1: 1.81137
# 251
# Training until validation scores don't improve for 50 rounds
# [200]	training's l1: 1.27184	valid_1's l1: 2.7992
# [400]	training's l1: 0.928243	valid_1's l1: 2.55153
# Early stopping, best iteration is:
# [451]	training's l1: 0.893683	valid_1's l1: 2.5423
# fold: 2, target: Rg, mae: 2.5422998965139927
# RMSE for Rg: 8.3372
# MAE for Rg: 2.0173
#
# 📊 Final OOF Score (wMAE): 0.060144
# {'Tg': [822, 552, 1084], 'FFV': [1397, 5445, 5463], 'Tc': [1068, 809, 433], 'Density': [557, 407, 644], 'Rg': [652, 409, 451]}
